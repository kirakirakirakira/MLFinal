# %% [markdown]
# **数据预处理**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

need_date_time_columns=1 #是否需要时间作为特征
columns_to_drop=[] #需要删除的列
df = pd.read_csv('data//train.csv', parse_dates=['DateTime'])
# 转换所有应为数值的列为 float（防止字符串类型报错）
numeric_cols = [
    'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]

# 强制转换为 float，如果有无法解析的值，设置为 NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
df.dropna(subset=numeric_cols, inplace=True)

df=df.drop(columns=columns_to_drop)
# 添加日期列
df['Date'] = df['DateTime'].dt.date  # 只保留年月日部分

# 计算 sub_metering_remainder（每分钟）
df['sub_metering_remainder'] = (df['Global_active_power'] * 1000 / 60) - (
    df['Sub_metering_1'] + df['Sub_metering_2'] + df['Sub_metering_3'])

# 定义日级聚合函数
daily_agg = {
    'Global_active_power': lambda x: x.sum() / 60,
    'Global_reactive_power': lambda x: x.sum() / 60,
    'Sub_metering_1': 'sum',  # 已是 Wh，每分钟累计可以直接 sum
    'Sub_metering_2': 'sum',
    'Sub_metering_3': 'sum',
    'sub_metering_remainder': 'sum',

    'Voltage': 'mean',  # 电压波动，均值即可
    'Global_intensity': 'mean',  # 电流均值也合理

    'RR': 'first',  # 天气指标，一天一个值即可
    'NBJRR1': 'first',
    'NBJRR5': 'first',
    'NBJRR10': 'first',
    'NBJBROU': 'first'
}
for col in columns_to_drop:
    daily_agg.pop(col, None)

# 按日期聚合
df_daily = df.groupby('Date').agg(daily_agg).reset_index()


# 可以选择将日期列转回 datetime 类型
if need_date_time_columns==1:
    df_daily['Date'] = pd.to_datetime(df_daily['Date'])
    df_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
    df_daily['day_of_month'] = df_daily['Date'].dt.day
    df_daily['month'] = df_daily['Date'].dt.month
    df_daily['quarter'] = df_daily['Date'].dt.quarter
# 查看结果
print("预处理后日级数据：")
print(df_daily.info())
print(df_daily.head())
feature_cols = [col for col in df_daily.columns if col != 'Date']
scaler = MinMaxScaler()
df_daily_scaled = df_daily.copy()
df_daily_scaled[feature_cols] = scaler.fit_transform(df_daily[feature_cols])
print(df_daily_scaled.head())
# Out:
# 预处理后日级数据：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    746 non-null    datetime64[ns]
#  1   Global_active_power     746 non-null    float64
#  2   Global_reactive_power   746 non-null    float64
#  3   Sub_metering_1          746 non-null    float64
#  4   Sub_metering_2          746 non-null    float64
#  5   Sub_metering_3          746 non-null    float64
#  6   sub_metering_remainder  746 non-null    float64
#  7   Voltage                 746 non-null    float64
#  8   Global_intensity        746 non-null    float64
#  9   RR                      746 non-null    float64
#  10  NBJRR1                  746 non-null    float64
#  11  NBJRR5                  746 non-null    float64
#  12  NBJRR10                 746 non-null    float64
#  13  NBJBROU                 746 non-null    float64
#  14  day_of_week             746 non-null    int32
#  15  day_of_month            746 non-null    int32
#  16  month                   746 non-null    int32
#  17  quarter                 746 non-null    int32
# dtypes: datetime64[ns](1), float64(13), int32(4)
# memory usage: 93.4 KB
# None
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16            20.152933               0.582033             0.0
# 1 2006-12-17            56.507667               3.766767          2033.0
# 2 2006-12-18            36.730433               2.696533          1063.0
# 3 2006-12-19            27.769900               2.515700           839.0
# 4 2006-12-20            37.095800               2.683300             0.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0           546.0          4926.0            14680.933333  236.243763
# 1          4187.0         13341.0            36946.666667  240.087028
# 2          2621.0         14018.0            19028.433333  241.231694
# 3          7602.0          6197.0            13131.900000  241.999313
# 4          2648.0         14063.0            20384.800000  242.308062
#
#    Global_intensity     RR  NBJRR1  NBJRR5  NBJRR10  NBJBROU  day_of_week  \
# 0         13.082828  63.75   9.333   5.667    2.167    0.167            5
# 1          9.999028  63.75   9.333   5.667    2.167    0.167            6
# 2          6.421667  63.75   9.333   5.667    2.167    0.167            0
# 3          4.926389  63.75   9.333   5.667    2.167    0.167            1
# 4          6.467361  63.75   9.333   5.667    2.167    0.167            2
#
#    day_of_month  month  quarter
# 0            16     12        4
# 1            17     12        4
# 2            18     12        4
# 3            19     12        4
# 4            20     12        4
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             0.249742               0.082334        0.000000
# 1 2006-12-17             0.708897               0.573033        0.196501
# 2 2006-12-18             0.459114               0.408133        0.102745
# 3 2006-12-19             0.345944               0.380271        0.081094
# 4 2006-12-20             0.463728               0.406094        0.000000
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder   Voltage  \
# 0        0.045090        0.252499                0.233317  0.371797
# 1        0.345776        0.683838                0.596096  0.648958
# 2        0.216451        0.718540                0.304152  0.731507
# 3        0.627798        0.317648                0.208079  0.786865
# 4        0.218680        0.720847                0.326251  0.809131
#
#    Global_intensity        RR    NBJRR1    NBJRR5  NBJRR10  NBJBROU  \
# 0          0.928499  0.395727  0.480759  0.767727   0.4925   0.4175
# 1          0.695226  0.395727  0.480759  0.767727   0.4925   0.4175
# 2          0.424618  0.395727  0.480759  0.767727   0.4925   0.4175
# 3          0.311508  0.395727  0.480759  0.767727   0.4925   0.4175
# 4          0.428075  0.395727  0.480759  0.767727   0.4925   0.4175
#
#    day_of_week  day_of_month  month  quarter
# 0     0.833333      0.500000    1.0      1.0
# 1     1.000000      0.533333    1.0      1.0
# 2     0.000000      0.566667    1.0      1.0
# 3     0.166667      0.600000    1.0      1.0
# 4     0.333333      0.633333    1.0      1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target_col = 'Global_active_power'
# 计算皮尔逊相关系数矩阵
corr_matrix = df_daily[feature_cols + [target_col]].corr()

# 可视化热力图
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title("Pearson Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import mutual_info_regression

X = df_daily[feature_cols]
y = df_daily[target_col]

mi_scores = mutual_info_regression(X, y, random_state=0)
mi_series = pd.Series(mi_scores, index=feature_cols).sort_values(ascending=False)

# 可视化
plt.figure(figsize=(10, 5))
mi_series.plot(kind='bar', color='darkorange')
plt.title(f'Mutual Information with Target: {target_col}')
plt.ylabel('MI Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **构造监督学习数据集**

# %%
def create_supervised_data(df, input_window=90, output_window=90, target_col='Global_active_power'):
    """
    构造用于多变量时间序列预测的监督学习样本
    参数：
        df: 已按天聚合的 DataFrame，包含时间序列特征
        input_window: 输入时间步长（例如 90）
        output_window: 预测步长（例如 90 或 365）
        target_col: 预测目标列
    返回：
        X: shape = [样本数, input_window, 特征数]
        y: shape = [样本数, output_window]
    """
    data = df.copy()
    feature_cols = [col for col in data.columns if col != 'Date']

    X_list = []
    y_list = []

    for i in range(len(data) - input_window - output_window + 1):
        x_window = data[feature_cols].iloc[i : i + input_window].values
        y_window = data[target_col].iloc[i + input_window : i + input_window + output_window].values

        if not (np.isnan(x_window).any() or np.isnan(y_window).any()):
            X_list.append(x_window)
            y_list.append(y_window)

    X = np.array(X_list)
    y = np.array(y_list)
    return X, y

# %% [markdown]
# LSTM模型设计+训练

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow.keras.backend as K
from tensorflow.keras.losses import Huber
def mae_with_derivative(y_true, y_pred):
    mae = K.mean(K.abs(y_pred - y_true))
    # 一阶差分
    diff_true = y_true[:, 1:] - y_true[:, :-1]
    diff_pred = y_pred[:, 1:] - y_pred[:, :-1]
    diff_loss = K.mean(K.abs(diff_true - diff_pred))
    return mae + 0.5 * diff_loss  # 你可以调节这个系数


def build_lstm_model(input_timesteps, num_features, output_timesteps):
    model = Sequential()
    model.add(LSTM(256, return_sequences=True, input_shape=(input_timesteps, num_features)))
    model.add(Dropout(0.1))
    model.add(LSTM(256, return_sequences=False))
    model.add(Dropout(0.1))
    # model.add(LSTM(512, return_sequences=False))
    # model.add(Dropout(0.2))
    model.add(Dense(output_timesteps))  # 默认线性激活
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model
from tensorflow.keras.callbacks import EarlyStopping
def train_lstm_model(X_train, y_train, X_val, y_val,
                     input_timesteps, num_features, output_timesteps,
                     epochs=50, batch_size=64, n_runs=5):
    from tensorflow.keras import backend as K
    all_loss_per_run = []
    mse_list = []
    mae_list = []
    best_model = None
    best_mse = float('inf')
    # model=None
    for run in range(n_runs):
        print(f"\n===== Run {run+1}/{n_runs} =====")
        model = build_lstm_model(input_timesteps, num_features, output_timesteps)

        early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

        history=model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),  # 显式验证集
            callbacks=[early_stopping],
            verbose=2
        )
        loss_list = history.history['loss']
        all_loss_per_run.append(loss_list)
        # 验证集评估（用于模型选择）
        loss, mae = model.evaluate(X_val, y_val, verbose=0)
        mse = loss

        print(f"Run {run+1} - MSE: {mse:.6f}, MAE: {mae:.6f}")

        mse_list.append(mse)
        mae_list.append(mae)

        if mse < best_mse:
            best_mse = mse
            best_model = model

        K.clear_session()

    results = {
        'mse_mean': np.mean(mse_list),
        'mse_std': np.std(mse_list),
        'mae_mean': np.mean(mae_list),
        'mae_std': np.std(mae_list),
    }

    print("\n===== Summary =====")
    print(f"MSE mean: {results['mse_mean']:.6f}, std: {results['mse_std']:.6f}")
    print(f"MAE mean: {results['mae_mean']:.6f}, std: {results['mae_std']:.6f}")

    return best_model, all_loss_per_run

def plot_avg_training_loss(all_loss_per_run):
    # 对齐不同 run 的 epoch 长度（考虑 early stopping）
    min_epochs = min(len(losses) for losses in all_loss_per_run)

    # 截断并转置为 (min_epochs, n_runs)
    truncated_losses = np.array([losses[:min_epochs] for losses in all_loss_per_run])

    # 平均
    avg_loss = np.mean(truncated_losses, axis=0)

    # 画图
    plt.figure(figsize=(8, 5))
    plt.plot(avg_loss, label='Average Training Loss', color='blue')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (MSE)')
    plt.title('Average Training Loss over Epochs')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 开始训练

# %%
#parameters
epochs=50
batch_size=16
n_nums=5
input_window = 90
output_window = 90
target_col = 'Global_active_power'
print("epochs:", epochs)
print("batch_size:", batch_size)
print("n_nums:", n_nums)
X_full, y_full = create_supervised_data(df_daily_scaled, input_window, output_window, target_col)
x_df = pd.DataFrame(X_full[0], columns=feature_cols)
y_series = pd.Series(y_full[0], name='Global_active_power')

# print("第", 0, "组 X（输入窗口）:")
# print(x_df)
#
# print("\n第", 0, "组 y（输出窗口）:")
# print(y_series)
print(f"X shape: {X_full.shape}, y shape: {y_full.shape}")
print(f"原始日级数据总天数: {df_daily.shape[0]}")
print(f"用于建模的样本数: {len(X_full)}")

# 划分训练集和验证集
train_ratio = 0.9
split_idx = int(len(X_full) * train_ratio)
X_train, X_val = X_full[:split_idx], X_full[split_idx:]
y_train, y_val = y_full[:split_idx], y_full[split_idx:]

print(f"训练集样本数: {len(X_train)}, 验证集样本数: {len(X_val)}")

num_features = X_train.shape[2]

model, history = train_lstm_model(
    X_train, y_train, X_val, y_val,
    input_window, num_features, output_window,
    epochs=epochs, batch_size=batch_size, n_runs=n_nums
)
# Out:
# epochs: 50
# batch_size: 16
# n_nums: 5
# X shape: (567, 90, 17), y shape: (567, 90)
# 原始日级数据总天数: 746
# 用于建模的样本数: 567
# 训练集样本数: 510, 验证集样本数: 57
#
# ===== Run 1/5 =====
# Epoch 1/50
# C:\code\MLFinal\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 - 4s - 127ms/step - loss: 0.0223 - mae: 0.1137 - val_loss: 0.0152 - val_mae: 0.0937
# Epoch 2/50
# 32/32 - 3s - 107ms/step - loss: 0.0117 - mae: 0.0843 - val_loss: 0.0120 - val_mae: 0.0818
# Epoch 3/50
# 32/32 - 4s - 116ms/step - loss: 0.0103 - mae: 0.0790 - val_loss: 0.0137 - val_mae: 0.0950
# Epoch 4/50
# 32/32 - 5s - 147ms/step - loss: 0.0096 - mae: 0.0767 - val_loss: 0.0141 - val_mae: 0.0973
# Epoch 5/50
# 32/32 - 4s - 140ms/step - loss: 0.0091 - mae: 0.0745 - val_loss: 0.0134 - val_mae: 0.0938
# Epoch 6/50
# 32/32 - 3s - 107ms/step - loss: 0.0083 - mae: 0.0714 - val_loss: 0.0115 - val_mae: 0.0842
# Epoch 7/50
# 32/32 - 5s - 142ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0119 - val_mae: 0.0861
# Epoch 8/50
# 32/32 - 4s - 116ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0116 - val_mae: 0.0850
# Epoch 9/50
# 32/32 - 4s - 121ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0112 - val_mae: 0.0836
# Epoch 10/50
# 32/32 - 3s - 94ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0112 - val_mae: 0.0832
# Epoch 11/50
# 32/32 - 3s - 93ms/step - loss: 0.0075 - mae: 0.0682 - val_loss: 0.0123 - val_mae: 0.0875
# Epoch 12/50
# 32/32 - 4s - 118ms/step - loss: 0.0075 - mae: 0.0677 - val_loss: 0.0107 - val_mae: 0.0801
# Epoch 13/50
# 32/32 - 4s - 126ms/step - loss: 0.0073 - mae: 0.0668 - val_loss: 0.0104 - val_mae: 0.0777
# Epoch 14/50
# 32/32 - 3s - 107ms/step - loss: 0.0071 - mae: 0.0660 - val_loss: 0.0112 - val_mae: 0.0834
# Epoch 15/50
# 32/32 - 3s - 95ms/step - loss: 0.0070 - mae: 0.0657 - val_loss: 0.0105 - val_mae: 0.0794
# Epoch 16/50
# 32/32 - 3s - 109ms/step - loss: 0.0070 - mae: 0.0653 - val_loss: 0.0111 - val_mae: 0.0828
# Epoch 17/50
# 32/32 - 4s - 114ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.0104 - val_mae: 0.0777
# Epoch 18/50
# 32/32 - 4s - 138ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0107 - val_mae: 0.0784
# Epoch 19/50
# 32/32 - 4s - 132ms/step - loss: 0.0069 - mae: 0.0650 - val_loss: 0.0108 - val_mae: 0.0821
# Epoch 20/50
# 32/32 - 4s - 111ms/step - loss: 0.0068 - mae: 0.0644 - val_loss: 0.0109 - val_mae: 0.0809
# Epoch 21/50
# 32/32 - 3s - 106ms/step - loss: 0.0066 - mae: 0.0639 - val_loss: 0.0109 - val_mae: 0.0813
# Epoch 22/50
# 32/32 - 3s - 106ms/step - loss: 0.0065 - mae: 0.0634 - val_loss: 0.0112 - val_mae: 0.0825
# Epoch 23/50
# 32/32 - 3s - 108ms/step - loss: 0.0064 - mae: 0.0628 - val_loss: 0.0104 - val_mae: 0.0774
# Epoch 24/50
# 32/32 - 4s - 115ms/step - loss: 0.0063 - mae: 0.0622 - val_loss: 0.0107 - val_mae: 0.0799
# Epoch 25/50
# 32/32 - 4s - 126ms/step - loss: 0.0064 - mae: 0.0630 - val_loss: 0.0102 - val_mae: 0.0768
# Epoch 26/50
# 32/32 - 5s - 152ms/step - loss: 0.0061 - mae: 0.0615 - val_loss: 0.0109 - val_mae: 0.0812
# Epoch 27/50
# 32/32 - 4s - 136ms/step - loss: 0.0060 - mae: 0.0611 - val_loss: 0.0112 - val_mae: 0.0814
# Epoch 28/50
# 32/32 - 4s - 125ms/step - loss: 0.0060 - mae: 0.0608 - val_loss: 0.0111 - val_mae: 0.0808
# Epoch 29/50
# 32/32 - 3s - 99ms/step - loss: 0.0059 - mae: 0.0604 - val_loss: 0.0106 - val_mae: 0.0798
# Epoch 30/50
# 32/32 - 3s - 94ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0106 - val_mae: 0.0773
# Epoch 31/50
# 32/32 - 3s - 90ms/step - loss: 0.0058 - mae: 0.0598 - val_loss: 0.0127 - val_mae: 0.0872
# Epoch 32/50
# 32/32 - 3s - 81ms/step - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0107 - val_mae: 0.0769
# Epoch 33/50
# 32/32 - 3s - 86ms/step - loss: 0.0056 - mae: 0.0586 - val_loss: 0.0104 - val_mae: 0.0776
# Epoch 34/50
# 32/32 - 3s - 80ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0117 - val_mae: 0.0814
# Epoch 35/50
# 32/32 - 2s - 73ms/step - loss: 0.0055 - mae: 0.0582 - val_loss: 0.0106 - val_mae: 0.0787
# Epoch 36/50
# 32/32 - 2s - 71ms/step - loss: 0.0054 - mae: 0.0581 - val_loss: 0.0111 - val_mae: 0.0797
# Epoch 37/50
# 32/32 - 2s - 71ms/step - loss: 0.0054 - mae: 0.0581 - val_loss: 0.0108 - val_mae: 0.0801
# Epoch 38/50
# 32/32 - 2s - 72ms/step - loss: 0.0054 - mae: 0.0579 - val_loss: 0.0108 - val_mae: 0.0790
# Epoch 39/50
# 32/32 - 2s - 73ms/step - loss: 0.0053 - mae: 0.0577 - val_loss: 0.0106 - val_mae: 0.0780
# Epoch 40/50
# 32/32 - 2s - 72ms/step - loss: 0.0054 - mae: 0.0579 - val_loss: 0.0103 - val_mae: 0.0762
# Epoch 41/50
# 32/32 - 2s - 73ms/step - loss: 0.0052 - mae: 0.0572 - val_loss: 0.0103 - val_mae: 0.0758
# Epoch 42/50
# 32/32 - 2s - 72ms/step - loss: 0.0052 - mae: 0.0571 - val_loss: 0.0107 - val_mae: 0.0776
# Epoch 43/50
# 32/32 - 2s - 72ms/step - loss: 0.0051 - mae: 0.0566 - val_loss: 0.0110 - val_mae: 0.0773
# Epoch 44/50
# 32/32 - 2s - 73ms/step - loss: 0.0052 - mae: 0.0567 - val_loss: 0.0099 - val_mae: 0.0749
# Epoch 45/50
# 32/32 - 2s - 73ms/step - loss: 0.0051 - mae: 0.0562 - val_loss: 0.0100 - val_mae: 0.0735
# Epoch 46/50
# 32/32 - 2s - 71ms/step - loss: 0.0051 - mae: 0.0564 - val_loss: 0.0105 - val_mae: 0.0777
# Epoch 47/50
# 32/32 - 2s - 72ms/step - loss: 0.0051 - mae: 0.0564 - val_loss: 0.0106 - val_mae: 0.0769
# Epoch 48/50
# 32/32 - 2s - 72ms/step - loss: 0.0051 - mae: 0.0562 - val_loss: 0.0100 - val_mae: 0.0752
# Epoch 49/50
# 32/32 - 2s - 74ms/step - loss: 0.0050 - mae: 0.0557 - val_loss: 0.0100 - val_mae: 0.0740
# Epoch 50/50
# 32/32 - 2s - 72ms/step - loss: 0.0050 - mae: 0.0560 - val_loss: 0.0105 - val_mae: 0.0763
# Run 1 - MSE: 0.009935, MAE: 0.074861
# WARNING:tensorflow:From C:\code\MLFinal\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# ===== Run 2/5 =====
# Epoch 1/50
# 32/32 - 4s - 112ms/step - loss: 0.0245 - mae: 0.1194 - val_loss: 0.0209 - val_mae: 0.1184
# Epoch 2/50
# 32/32 - 2s - 73ms/step - loss: 0.0123 - mae: 0.0862 - val_loss: 0.0149 - val_mae: 0.0934
# Epoch 3/50
# 32/32 - 2s - 73ms/step - loss: 0.0105 - mae: 0.0797 - val_loss: 0.0149 - val_mae: 0.0993
# Epoch 4/50
# 32/32 - 2s - 72ms/step - loss: 0.0098 - mae: 0.0777 - val_loss: 0.0164 - val_mae: 0.1038
# Epoch 5/50
# 32/32 - 2s - 71ms/step - loss: 0.0092 - mae: 0.0750 - val_loss: 0.0137 - val_mae: 0.0922
# Epoch 6/50
# 32/32 - 2s - 72ms/step - loss: 0.0086 - mae: 0.0726 - val_loss: 0.0111 - val_mae: 0.0785
# Epoch 7/50
# 32/32 - 2s - 72ms/step - loss: 0.0082 - mae: 0.0711 - val_loss: 0.0109 - val_mae: 0.0809
# Epoch 8/50
# 32/32 - 3s - 85ms/step - loss: 0.0080 - mae: 0.0700 - val_loss: 0.0115 - val_mae: 0.0800
# Epoch 9/50
# 32/32 - 3s - 98ms/step - loss: 0.0079 - mae: 0.0700 - val_loss: 0.0107 - val_mae: 0.0779
# Epoch 10/50
# 32/32 - 2s - 74ms/step - loss: 0.0077 - mae: 0.0692 - val_loss: 0.0114 - val_mae: 0.0778
# Epoch 11/50
# 32/32 - 2s - 72ms/step - loss: 0.0076 - mae: 0.0683 - val_loss: 0.0114 - val_mae: 0.0763
# Epoch 12/50
# 32/32 - 3s - 95ms/step - loss: 0.0075 - mae: 0.0678 - val_loss: 0.0103 - val_mae: 0.0752
# Epoch 13/50
# 32/32 - 3s - 96ms/step - loss: 0.0075 - mae: 0.0679 - val_loss: 0.0108 - val_mae: 0.0789
# Epoch 14/50
# 32/32 - 2s - 76ms/step - loss: 0.0073 - mae: 0.0668 - val_loss: 0.0105 - val_mae: 0.0758
# Epoch 15/50
# 32/32 - 2s - 77ms/step - loss: 0.0073 - mae: 0.0669 - val_loss: 0.0123 - val_mae: 0.0807
# Epoch 16/50
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0114 - val_mae: 0.0775
# Epoch 17/50
# 32/32 - 2s - 71ms/step - loss: 0.0070 - mae: 0.0656 - val_loss: 0.0144 - val_mae: 0.0830
# Epoch 18/50
# 32/32 - 3s - 84ms/step - loss: 0.0070 - mae: 0.0653 - val_loss: 0.0143 - val_mae: 0.0860
# Epoch 19/50
# 32/32 - 2s - 75ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0134 - val_mae: 0.0819
# Epoch 20/50
# 32/32 - 2s - 75ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0122 - val_mae: 0.0789
# Epoch 21/50
# 32/32 - 2s - 74ms/step - loss: 0.0066 - mae: 0.0638 - val_loss: 0.0120 - val_mae: 0.0771
# Epoch 22/50
# 32/32 - 3s - 79ms/step - loss: 0.0066 - mae: 0.0637 - val_loss: 0.0124 - val_mae: 0.0795
# Epoch 23/50
# 32/32 - 3s - 90ms/step - loss: 0.0065 - mae: 0.0633 - val_loss: 0.0109 - val_mae: 0.0757
# Epoch 24/50
# 32/32 - 3s - 91ms/step - loss: 0.0063 - mae: 0.0625 - val_loss: 0.0134 - val_mae: 0.0815
# Epoch 25/50
# 32/32 - 3s - 90ms/step - loss: 0.0064 - mae: 0.0625 - val_loss: 0.0141 - val_mae: 0.0820
# Epoch 26/50
# 32/32 - 3s - 90ms/step - loss: 0.0064 - mae: 0.0628 - val_loss: 0.0136 - val_mae: 0.0830
# Epoch 27/50
# 32/32 - 3s - 91ms/step - loss: 0.0063 - mae: 0.0623 - val_loss: 0.0122 - val_mae: 0.0778
# Epoch 28/50
# 32/32 - 3s - 91ms/step - loss: 0.0062 - mae: 0.0616 - val_loss: 0.0134 - val_mae: 0.0826
# Epoch 29/50
# 32/32 - 3s - 80ms/step - loss: 0.0061 - mae: 0.0611 - val_loss: 0.0128 - val_mae: 0.0786
# Epoch 30/50
# 32/32 - 2s - 72ms/step - loss: 0.0060 - mae: 0.0606 - val_loss: 0.0146 - val_mae: 0.0857
# Epoch 31/50
# 32/32 - 2s - 77ms/step - loss: 0.0059 - mae: 0.0601 - val_loss: 0.0132 - val_mae: 0.0798
# Epoch 32/50
# 32/32 - 3s - 88ms/step - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0126 - val_mae: 0.0801
# Run 2 - MSE: 0.010348, MAE: 0.075190
#
# ===== Run 3/5 =====
# Epoch 1/50
# 32/32 - 5s - 169ms/step - loss: 0.0236 - mae: 0.1168 - val_loss: 0.0214 - val_mae: 0.1203
# Epoch 2/50
# 32/32 - 3s - 90ms/step - loss: 0.0124 - mae: 0.0864 - val_loss: 0.0192 - val_mae: 0.1123
# Epoch 3/50
# 32/32 - 3s - 91ms/step - loss: 0.0110 - mae: 0.0818 - val_loss: 0.0122 - val_mae: 0.0823
# Epoch 4/50
# 32/32 - 3s - 92ms/step - loss: 0.0100 - mae: 0.0782 - val_loss: 0.0136 - val_mae: 0.0947
# Epoch 5/50
# 32/32 - 3s - 90ms/step - loss: 0.0095 - mae: 0.0761 - val_loss: 0.0123 - val_mae: 0.0864
# Epoch 6/50
# 32/32 - 3s - 90ms/step - loss: 0.0087 - mae: 0.0728 - val_loss: 0.0121 - val_mae: 0.0854
# Epoch 7/50
# 32/32 - 2s - 77ms/step - loss: 0.0085 - mae: 0.0719 - val_loss: 0.0132 - val_mae: 0.0921
# Epoch 8/50
# 32/32 - 3s - 81ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0119 - val_mae: 0.0848
# Epoch 9/50
# 32/32 - 3s - 89ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0113 - val_mae: 0.0827
# Epoch 10/50
# 32/32 - 3s - 92ms/step - loss: 0.0079 - mae: 0.0696 - val_loss: 0.0115 - val_mae: 0.0841
# Epoch 11/50
# 32/32 - 3s - 93ms/step - loss: 0.0076 - mae: 0.0685 - val_loss: 0.0115 - val_mae: 0.0827
# Epoch 12/50
# 32/32 - 3s - 98ms/step - loss: 0.0074 - mae: 0.0674 - val_loss: 0.0115 - val_mae: 0.0842
# Epoch 13/50
# 32/32 - 3s - 93ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0127 - val_mae: 0.0851
# Epoch 14/50
# 32/32 - 3s - 94ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0105 - val_mae: 0.0760
# Epoch 15/50
# 32/32 - 3s - 97ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0106 - val_mae: 0.0781
# Epoch 16/50
# 32/32 - 3s - 97ms/step - loss: 0.0070 - mae: 0.0654 - val_loss: 0.0105 - val_mae: 0.0776
# Epoch 17/50
# 32/32 - 3s - 94ms/step - loss: 0.0069 - mae: 0.0648 - val_loss: 0.0107 - val_mae: 0.0773
# Epoch 18/50
# 32/32 - 3s - 100ms/step - loss: 0.0069 - mae: 0.0648 - val_loss: 0.0111 - val_mae: 0.0800
# Epoch 19/50
# 32/32 - 5s - 171ms/step - loss: 0.0067 - mae: 0.0641 - val_loss: 0.0107 - val_mae: 0.0767
# Epoch 20/50
# 32/32 - 5s - 156ms/step - loss: 0.0067 - mae: 0.0641 - val_loss: 0.0109 - val_mae: 0.0786
# Epoch 21/50
# 32/32 - 5s - 152ms/step - loss: 0.0065 - mae: 0.0633 - val_loss: 0.0103 - val_mae: 0.0756
# Epoch 22/50
# 32/32 - 4s - 138ms/step - loss: 0.0065 - mae: 0.0630 - val_loss: 0.0110 - val_mae: 0.0764
# Epoch 23/50
# 32/32 - 5s - 149ms/step - loss: 0.0065 - mae: 0.0634 - val_loss: 0.0107 - val_mae: 0.0787
# Epoch 24/50
# 32/32 - 5s - 158ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0111 - val_mae: 0.0810
# Epoch 25/50
# 32/32 - 5s - 144ms/step - loss: 0.0063 - mae: 0.0623 - val_loss: 0.0107 - val_mae: 0.0765
# Epoch 26/50
# 32/32 - 4s - 136ms/step - loss: 0.0062 - mae: 0.0619 - val_loss: 0.0112 - val_mae: 0.0768
# Epoch 27/50
# 32/32 - 4s - 136ms/step - loss: 0.0062 - mae: 0.0618 - val_loss: 0.0114 - val_mae: 0.0774
# Epoch 28/50
# 32/32 - 4s - 128ms/step - loss: 0.0060 - mae: 0.0611 - val_loss: 0.0113 - val_mae: 0.0770
# Epoch 29/50
# 32/32 - 5s - 148ms/step - loss: 0.0059 - mae: 0.0603 - val_loss: 0.0115 - val_mae: 0.0780
# Epoch 30/50
# 32/32 - 6s - 181ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0131 - val_mae: 0.0821
# Epoch 31/50
# 32/32 - 4s - 137ms/step - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0114 - val_mae: 0.0808
# Epoch 32/50
# 32/32 - 4s - 133ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0118 - val_mae: 0.0801
# Epoch 33/50
# 32/32 - 4s - 131ms/step - loss: 0.0057 - mae: 0.0590 - val_loss: 0.0113 - val_mae: 0.0776
# Epoch 34/50
# 32/32 - 5s - 162ms/step - loss: 0.0055 - mae: 0.0584 - val_loss: 0.0115 - val_mae: 0.0790
# Epoch 35/50
# 32/32 - 5s - 162ms/step - loss: 0.0055 - mae: 0.0583 - val_loss: 0.0118 - val_mae: 0.0786
# Epoch 36/50
# 32/32 - 5s - 162ms/step - loss: 0.0055 - mae: 0.0586 - val_loss: 0.0113 - val_mae: 0.0783
# Epoch 37/50
# 32/32 - 4s - 136ms/step - loss: 0.0054 - mae: 0.0578 - val_loss: 0.0118 - val_mae: 0.0808
# Epoch 38/50
# 32/32 - 4s - 137ms/step - loss: 0.0053 - mae: 0.0573 - val_loss: 0.0113 - val_mae: 0.0782
# Epoch 39/50
# 32/32 - 5s - 141ms/step - loss: 0.0053 - mae: 0.0573 - val_loss: 0.0115 - val_mae: 0.0802
# Epoch 40/50
# 32/32 - 4s - 135ms/step - loss: 0.0053 - mae: 0.0573 - val_loss: 0.0113 - val_mae: 0.0778
# Epoch 41/50
# 32/32 - 4s - 135ms/step - loss: 0.0052 - mae: 0.0569 - val_loss: 0.0113 - val_mae: 0.0781
# Run 3 - MSE: 0.010269, MAE: 0.075587
#
# ===== Run 4/5 =====
# Epoch 1/50
# 32/32 - 8s - 263ms/step - loss: 0.0236 - mae: 0.1165 - val_loss: 0.0203 - val_mae: 0.1149
# Epoch 2/50
# 32/32 - 4s - 127ms/step - loss: 0.0119 - mae: 0.0847 - val_loss: 0.0130 - val_mae: 0.0854
# Epoch 3/50
# 32/32 - 5s - 151ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0115 - val_mae: 0.0824
# Epoch 4/50
# 32/32 - 4s - 123ms/step - loss: 0.0100 - mae: 0.0784 - val_loss: 0.0117 - val_mae: 0.0836
# Epoch 5/50
# 32/32 - 4s - 133ms/step - loss: 0.0093 - mae: 0.0753 - val_loss: 0.0117 - val_mae: 0.0817
# Epoch 6/50
# 32/32 - 4s - 131ms/step - loss: 0.0091 - mae: 0.0745 - val_loss: 0.0121 - val_mae: 0.0854
# Epoch 7/50
# 32/32 - 4s - 133ms/step - loss: 0.0083 - mae: 0.0711 - val_loss: 0.0118 - val_mae: 0.0859
# Epoch 8/50
# 32/32 - 4s - 132ms/step - loss: 0.0080 - mae: 0.0700 - val_loss: 0.0111 - val_mae: 0.0814
# Epoch 9/50
# 32/32 - 4s - 137ms/step - loss: 0.0078 - mae: 0.0693 - val_loss: 0.0106 - val_mae: 0.0787
# Epoch 10/50
# 32/32 - 4s - 129ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0106 - val_mae: 0.0797
# Epoch 11/50
# 32/32 - 4s - 129ms/step - loss: 0.0076 - mae: 0.0684 - val_loss: 0.0109 - val_mae: 0.0813
# Epoch 12/50
# 32/32 - 4s - 128ms/step - loss: 0.0076 - mae: 0.0684 - val_loss: 0.0104 - val_mae: 0.0780
# Epoch 13/50
# 32/32 - 3s - 106ms/step - loss: 0.0075 - mae: 0.0677 - val_loss: 0.0105 - val_mae: 0.0784
# Epoch 14/50
# 32/32 - 2s - 72ms/step - loss: 0.0074 - mae: 0.0674 - val_loss: 0.0107 - val_mae: 0.0791
# Epoch 15/50
# 32/32 - 2s - 72ms/step - loss: 0.0072 - mae: 0.0664 - val_loss: 0.0105 - val_mae: 0.0760
# Epoch 16/50
# 32/32 - 2s - 72ms/step - loss: 0.0072 - mae: 0.0662 - val_loss: 0.0108 - val_mae: 0.0806
# Epoch 17/50
# 32/32 - 2s - 72ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.0105 - val_mae: 0.0789
# Epoch 18/50
# 32/32 - 2s - 72ms/step - loss: 0.0068 - mae: 0.0646 - val_loss: 0.0103 - val_mae: 0.0744
# Epoch 19/50
# 32/32 - 2s - 71ms/step - loss: 0.0068 - mae: 0.0647 - val_loss: 0.0101 - val_mae: 0.0768
# Epoch 20/50
# 32/32 - 2s - 70ms/step - loss: 0.0068 - mae: 0.0646 - val_loss: 0.0103 - val_mae: 0.0762
# Epoch 21/50
# 32/32 - 2s - 71ms/step - loss: 0.0069 - mae: 0.0650 - val_loss: 0.0106 - val_mae: 0.0780
# Epoch 22/50
# 32/32 - 2s - 71ms/step - loss: 0.0068 - mae: 0.0644 - val_loss: 0.0103 - val_mae: 0.0769
# Epoch 23/50
# 32/32 - 2s - 72ms/step - loss: 0.0065 - mae: 0.0629 - val_loss: 0.0101 - val_mae: 0.0766
# Epoch 24/50
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0629 - val_loss: 0.0099 - val_mae: 0.0747
# Epoch 25/50
# 32/32 - 2s - 72ms/step - loss: 0.0064 - mae: 0.0626 - val_loss: 0.0102 - val_mae: 0.0754
# Epoch 26/50
# 32/32 - 2s - 77ms/step - loss: 0.0063 - mae: 0.0623 - val_loss: 0.0100 - val_mae: 0.0747
# Epoch 27/50
# 32/32 - 3s - 100ms/step - loss: 0.0062 - mae: 0.0619 - val_loss: 0.0102 - val_mae: 0.0772
# Epoch 28/50
# 32/32 - 6s - 188ms/step - loss: 0.0061 - mae: 0.0613 - val_loss: 0.0107 - val_mae: 0.0782
# Epoch 29/50
# 32/32 - 6s - 191ms/step - loss: 0.0060 - mae: 0.0608 - val_loss: 0.0098 - val_mae: 0.0748
# Epoch 30/50
# 32/32 - 4s - 131ms/step - loss: 0.0060 - mae: 0.0606 - val_loss: 0.0105 - val_mae: 0.0770
# Epoch 31/50
# 32/32 - 5s - 158ms/step - loss: 0.0060 - mae: 0.0609 - val_loss: 0.0103 - val_mae: 0.0764
# Epoch 32/50
# 32/32 - 5s - 163ms/step - loss: 0.0059 - mae: 0.0606 - val_loss: 0.0103 - val_mae: 0.0766
# Epoch 33/50
# 32/32 - 5s - 150ms/step - loss: 0.0057 - mae: 0.0594 - val_loss: 0.0101 - val_mae: 0.0760
# Epoch 34/50
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0098 - val_mae: 0.0746
# Epoch 35/50
# 32/32 - 3s - 84ms/step - loss: 0.0055 - mae: 0.0584 - val_loss: 0.0100 - val_mae: 0.0754
# Epoch 36/50
# 32/32 - 3s - 95ms/step - loss: 0.0056 - mae: 0.0591 - val_loss: 0.0105 - val_mae: 0.0785
# Epoch 37/50
# 32/32 - 3s - 78ms/step - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0107 - val_mae: 0.0784
# Epoch 38/50
# 32/32 - 2s - 75ms/step - loss: 0.0056 - mae: 0.0588 - val_loss: 0.0104 - val_mae: 0.0769
# Epoch 39/50
# 32/32 - 2s - 71ms/step - loss: 0.0054 - mae: 0.0579 - val_loss: 0.0103 - val_mae: 0.0765
# Epoch 40/50
# 32/32 - 2s - 71ms/step - loss: 0.0053 - mae: 0.0571 - val_loss: 0.0102 - val_mae: 0.0758
# Epoch 41/50
# 32/32 - 2s - 71ms/step - loss: 0.0052 - mae: 0.0570 - val_loss: 0.0102 - val_mae: 0.0749
# Epoch 42/50
# 32/32 - 2s - 71ms/step - loss: 0.0052 - mae: 0.0568 - val_loss: 0.0100 - val_mae: 0.0750
# Epoch 43/50
# 32/32 - 2s - 73ms/step - loss: 0.0052 - mae: 0.0570 - val_loss: 0.0102 - val_mae: 0.0751
# Epoch 44/50
# 32/32 - 2s - 73ms/step - loss: 0.0051 - mae: 0.0565 - val_loss: 0.0104 - val_mae: 0.0770
# Epoch 45/50
# 32/32 - 2s - 71ms/step - loss: 0.0051 - mae: 0.0562 - val_loss: 0.0102 - val_mae: 0.0755
# Epoch 46/50
# 32/32 - 2s - 71ms/step - loss: 0.0050 - mae: 0.0559 - val_loss: 0.0099 - val_mae: 0.0741
# Epoch 47/50
# 32/32 - 3s - 92ms/step - loss: 0.0050 - mae: 0.0558 - val_loss: 0.0098 - val_mae: 0.0742
# Epoch 48/50
# 32/32 - 2s - 77ms/step - loss: 0.0050 - mae: 0.0557 - val_loss: 0.0101 - val_mae: 0.0743
# Epoch 49/50
# 32/32 - 3s - 79ms/step - loss: 0.0050 - mae: 0.0555 - val_loss: 0.0102 - val_mae: 0.0751
# Epoch 50/50
# 32/32 - 2s - 74ms/step - loss: 0.0049 - mae: 0.0553 - val_loss: 0.0103 - val_mae: 0.0759
# Run 4 - MSE: 0.009781, MAE: 0.074623
#
# ===== Run 5/5 =====
# Epoch 1/50
# 32/32 - 4s - 116ms/step - loss: 0.0241 - mae: 0.1187 - val_loss: 0.0183 - val_mae: 0.1082
# Epoch 2/50
# 32/32 - 2s - 71ms/step - loss: 0.0119 - mae: 0.0851 - val_loss: 0.0122 - val_mae: 0.0820
# Epoch 3/50
# 32/32 - 3s - 102ms/step - loss: 0.0106 - mae: 0.0801 - val_loss: 0.0143 - val_mae: 0.0939
# Epoch 4/50
# 32/32 - 3s - 84ms/step - loss: 0.0102 - mae: 0.0788 - val_loss: 0.0130 - val_mae: 0.0874
# Epoch 5/50
# 32/32 - 2s - 73ms/step - loss: 0.0094 - mae: 0.0760 - val_loss: 0.0130 - val_mae: 0.0895
# Epoch 6/50
# 32/32 - 2s - 71ms/step - loss: 0.0086 - mae: 0.0727 - val_loss: 0.0133 - val_mae: 0.0906
# Epoch 7/50
# 32/32 - 2s - 71ms/step - loss: 0.0083 - mae: 0.0713 - val_loss: 0.0115 - val_mae: 0.0811
# Epoch 8/50
# 32/32 - 2s - 71ms/step - loss: 0.0082 - mae: 0.0713 - val_loss: 0.0126 - val_mae: 0.0871
# Epoch 9/50
# 32/32 - 2s - 71ms/step - loss: 0.0081 - mae: 0.0706 - val_loss: 0.0119 - val_mae: 0.0812
# Epoch 10/50
# 32/32 - 2s - 70ms/step - loss: 0.0078 - mae: 0.0694 - val_loss: 0.0120 - val_mae: 0.0839
# Epoch 11/50
# 32/32 - 2s - 70ms/step - loss: 0.0077 - mae: 0.0689 - val_loss: 0.0117 - val_mae: 0.0830
# Epoch 12/50
# 32/32 - 2s - 70ms/step - loss: 0.0076 - mae: 0.0683 - val_loss: 0.0115 - val_mae: 0.0811
# Epoch 13/50
# 32/32 - 2s - 73ms/step - loss: 0.0075 - mae: 0.0677 - val_loss: 0.0120 - val_mae: 0.0815
# Epoch 14/50
# 32/32 - 2s - 70ms/step - loss: 0.0074 - mae: 0.0672 - val_loss: 0.0125 - val_mae: 0.0848
# Epoch 15/50
# 32/32 - 2s - 70ms/step - loss: 0.0073 - mae: 0.0669 - val_loss: 0.0113 - val_mae: 0.0795
# Epoch 16/50
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0659 - val_loss: 0.0112 - val_mae: 0.0805
# Epoch 17/50
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0654 - val_loss: 0.0116 - val_mae: 0.0820
# Epoch 18/50
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0653 - val_loss: 0.0123 - val_mae: 0.0859
# Epoch 19/50
# 32/32 - 3s - 84ms/step - loss: 0.0071 - mae: 0.0663 - val_loss: 0.0120 - val_mae: 0.0828
# Epoch 20/50
# 32/32 - 3s - 80ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.0116 - val_mae: 0.0808
# Epoch 21/50
# 32/32 - 2s - 74ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0122 - val_mae: 0.0844
# Epoch 22/50
# 32/32 - 2s - 71ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0123 - val_mae: 0.0832
# Epoch 23/50
# 32/32 - 2s - 73ms/step - loss: 0.0068 - mae: 0.0647 - val_loss: 0.0109 - val_mae: 0.0799
# Epoch 24/50
# 32/32 - 3s - 91ms/step - loss: 0.0066 - mae: 0.0634 - val_loss: 0.0115 - val_mae: 0.0810
# Epoch 25/50
# 32/32 - 3s - 79ms/step - loss: 0.0065 - mae: 0.0628 - val_loss: 0.0125 - val_mae: 0.0840
# Epoch 26/50
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0123 - val_mae: 0.0842
# Epoch 27/50
# 32/32 - 3s - 94ms/step - loss: 0.0064 - mae: 0.0625 - val_loss: 0.0116 - val_mae: 0.0819
# Epoch 28/50
# 32/32 - 3s - 94ms/step - loss: 0.0063 - mae: 0.0619 - val_loss: 0.0119 - val_mae: 0.0818
# Epoch 29/50
# 32/32 - 3s - 79ms/step - loss: 0.0062 - mae: 0.0618 - val_loss: 0.0117 - val_mae: 0.0820
# Epoch 30/50
# 32/32 - 3s - 93ms/step - loss: 0.0060 - mae: 0.0608 - val_loss: 0.0120 - val_mae: 0.0814
# Epoch 31/50
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0609 - val_loss: 0.0112 - val_mae: 0.0797
# Epoch 32/50
# 32/32 - 2s - 71ms/step - loss: 0.0059 - mae: 0.0605 - val_loss: 0.0118 - val_mae: 0.0820
# Epoch 33/50
# 32/32 - 2s - 71ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0118 - val_mae: 0.0806
# Epoch 34/50
# 32/32 - 2s - 71ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0130 - val_mae: 0.0854
# Epoch 35/50
# 32/32 - 2s - 70ms/step - loss: 0.0057 - mae: 0.0595 - val_loss: 0.0117 - val_mae: 0.0807
# Epoch 36/50
# 32/32 - 2s - 71ms/step - loss: 0.0056 - mae: 0.0593 - val_loss: 0.0115 - val_mae: 0.0789
# Epoch 37/50
# 32/32 - 2s - 71ms/step - loss: 0.0055 - mae: 0.0583 - val_loss: 0.0113 - val_mae: 0.0792
# Epoch 38/50
# 32/32 - 2s - 73ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0120 - val_mae: 0.0813
# Epoch 39/50
# 32/32 - 2s - 71ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0128 - val_mae: 0.0839
# Epoch 40/50
# 32/32 - 2s - 74ms/step - loss: 0.0054 - mae: 0.0576 - val_loss: 0.0123 - val_mae: 0.0826
# Epoch 41/50
# 32/32 - 2s - 72ms/step - loss: 0.0054 - mae: 0.0578 - val_loss: 0.0120 - val_mae: 0.0821
# Epoch 42/50
# 32/32 - 2s - 71ms/step - loss: 0.0053 - mae: 0.0573 - val_loss: 0.0119 - val_mae: 0.0817
# Epoch 43/50
# 32/32 - 2s - 72ms/step - loss: 0.0053 - mae: 0.0572 - val_loss: 0.0118 - val_mae: 0.0805
# Run 5 - MSE: 0.010936, MAE: 0.079934
#
# ===== Summary =====
# MSE mean: 0.010254, std: 0.000400
# MAE mean: 0.076039, std: 0.001974

# %%
import matplotlib.pyplot as plt
plot_avg_training_loss(history)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 90, 256)        │       280,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 90, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 90)             │        23,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,487,056 (9.49 MB)
#  Trainable params: 829,018 (3.16 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,658,038 (6.32 MB)

# %% [markdown]
# 测试集+作图

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
df_test = pd.read_csv('data/test.csv', header=None)
from tensorflow.keras.models import load_model
# Step 2：赋完整列名（按顺序）
df_test.columns = ['DateTime']+numeric_cols
# 数值列转换（如有非数字或缺失，转为NaN）
df_test[numeric_cols] = df_test[numeric_cols].apply(pd.to_numeric, errors='coerce')
# 显式删除不需要字段
df_test = df_test.drop(columns=columns_to_drop)
df_test['DateTime'] = pd.to_datetime(df_test['DateTime'], errors='coerce')
df_test['Date'] = df_test['DateTime'].dt.date

# 计算 sub_metering_remainder
df_test['sub_metering_remainder'] = (df_test['Global_active_power'] * 1000 / 60) - (
    df_test['Sub_metering_1'] + df_test['Sub_metering_2'] + df_test['Sub_metering_3'])

# 按天聚合
df_test_daily = df_test.groupby('Date').agg(daily_agg).reset_index()
print(df_test_daily.head())
if need_date_time_columns==1:
    df_test_daily['Date'] = pd.to_datetime(df_test_daily['Date'])
    df_test_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
    df_test_daily['day_of_month'] = df_daily['Date'].dt.day
    df_test_daily['month'] = df_daily['Date'].dt.month
    df_test_daily['quarter'] = df_daily['Date'].dt.quarter
# ========== 关键修改点：丢弃含NaN的天 ==========
df_test_daily_clean = df_test_daily.dropna()
print(f"清洗后测试集天数: {len(df_test_daily_clean)}")


# 归一化（只对干净数据做）
df_test_daily_scaled = df_test_daily_clean.copy()
df_test_daily_scaled[feature_cols] = scaler.transform(df_test_daily_scaled[feature_cols])


def inverse_transform_target(scaler, feature_cols, data_1d, target_col='Global_active_power'):
    """
    把一维的目标列数据逆归一化。
    scaler: 训练时fit的Scaler
    feature_cols: 归一化时所有特征的列名列表
    data_1d: 目标列的一维归一化数据（如full_pred或full_true）
    返回：逆归一化后目标列一维数据
    """
    n = len(data_1d)
    temp = np.zeros((n, len(feature_cols)))
    # 找到目标列索引
    target_idx = feature_cols.index(target_col)
    temp[:, target_idx] = data_1d
    # 逆归一化
    inv_data = scaler.inverse_transform(temp)
    return inv_data[:, target_idx]


X_test_final, y_test_final = create_supervised_data(
    df_test_daily_scaled,
    input_window=input_window,
    output_window=output_window,
    target_col=target_col  # 一般是 'Global_active_power'
)
model = load_model('saved_model/LSTM_90_model_50_16_5.keras')
y_pred_final = model.predict(X_test_final)

# 初始化容器
total_days = input_window + (len(y_pred_final) - 1) + output_window
pred_sum = np.zeros(total_days)
true_sum = np.zeros(total_days)

# 替代平均融合：取最后一次预测
for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
    start_idx = input_window + i
    end_idx = start_idx + output_window

    pred_sum[start_idx:end_idx] = pred  # 直接覆盖
    true_sum[start_idx:end_idx] = true

# 取预测部分
full_pred = pred_sum[input_window:]
full_true = true_sum[input_window:]

# 反归一化
full_pred_inv = inverse_transform_target(scaler, feature_cols, full_pred, target_col)
full_true_inv = inverse_transform_target(scaler, feature_cols, full_true, target_col)

# 时间轴
days = np.arange(len(full_pred))

plt.rcParams.update({
    'font.size': 20,           # 全局基础字体大小
    'axes.titlesize': 24,      # 标题字体大小
    'axes.labelsize': 20,      # 坐标轴标签大小
    'xtick.labelsize': 20,     # X轴刻度标签大小
    'ytick.labelsize': 20,     # Y轴刻度标签大小
    'legend.fontsize': 20      # 图例字体大小
})

plt.figure(figsize=(14, 5))
plt.plot(days, full_true_inv, label='Ground Truth', color='blue', linewidth=2)
plt.plot(days, full_pred_inv, label='Merged Prediction', color='orange', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power(kWh)')  # 单位改成实际单位
plt.title('Merged 90-day Predictions vs Ground Truth')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
true_values_to_show = full_true_inv
pred_values_to_show = full_pred_inv

# 打印前30天（或根据需要改）
# print("Day | Ground Truth (kWh) | Merged Prediction (kWh) | Absolute Error")
# print("-" * 50)
# for i in range(min(30, len(true_values_to_show))):
#     true_val = true_values_to_show[i]
#     pred_val = pred_values_to_show[i]
#     error = abs(true_val - pred_val)
#     print(f"{i:3d} | {true_val:17.4f} | {pred_val:19.4f} | {error:14.4f}")



# MSE
mse = mean_squared_error(true_values_to_show, pred_values_to_show)

# RMSE
rmse = mse ** 0.5

# MAE
mae = mean_absolute_error(true_values_to_show, pred_values_to_show)
errors = pred_values_to_show- true_values_to_show
std_dev = np.std(errors)
print("epochs:", epochs)
print("batch_size:", batch_size)
print("n_nums:", n_nums)
print(f"测试集评估指标:")
print(f"MSE : {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE : {mae:.6f}")
print(f"预测误差标准差: {std_dev:.6f}")
# Out:
# C:\Users\16693\AppData\Local\Temp\ipykernel_40128\2684478102.py:3: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('data/test.csv', header=None)
#          Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0  2009-01-01            23.444867               1.877800           765.0
# 1  2009-01-02            38.791833               3.412167          2417.0
# 2  2009-01-03            31.891600               2.915200          6440.0
# 3  2009-01-04            32.333233               2.788967          1457.0
# 4  2009-01-05            26.733333               2.148967          1247.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0          3845.0          2803.0            16031.866667  242.836062
# 1          6018.0         11841.0            18515.833333  242.704889
# 2           328.0         10439.0            14684.600000  243.681458
# 3          5251.0          3245.0            22380.233333  244.822431
# 4           322.0          8650.0            16514.333333  244.830778
#
#    Global_intensity     RR  NBJRR1  NBJRR5  NBJRR10  NBJBROU
# 0          4.149861  51.24    10.0     4.2      1.4      0.6
# 1          6.737778  51.24    10.0     4.2      1.4      0.6
# 2          5.530833  51.24    10.0     4.2      1.4      0.6
# 3          5.633194  51.24    10.0     4.2      1.4      0.6
# 4          4.636250  51.24    10.0     4.2      1.4      0.6
# 清洗后测试集天数: 687
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# epochs: 50
# batch_size: 16
# n_nums: 5
# 测试集评估指标:
# MSE : 58.141811
# RMSE: 7.625078
# MAE : 6.044242
# 预测误差标准差: 7.603635

# %%
import json
list_data = full_pred_inv.tolist()
with open('lstm-90.json', 'w', encoding='utf-8') as f:
    json.dump(list_data, f, ensure_ascii=False, indent=2)

# %%
# model.save("saved_model//LSTM_90_model.keras") #保存模型

# %%
# def inverse_transform_target_2d(scaler, feature_cols, data_2d, target_col='Global_active_power'):
#     n_samples, n_steps = data_2d.shape
#     inv_data = np.zeros_like(data_2d)
#     target_idx = feature_cols.index(target_col)
#
#     for i in range(n_samples):
#         temp = np.zeros((n_steps, len(feature_cols)))
#         temp[:, target_idx] = data_2d[i]
#         inv_temp = scaler.inverse_transform(temp)
#         inv_data[i] = inv_temp[:, target_idx]
#     return inv_data
#
# # 调用示例
# y_test_inv = inverse_transform_target_2d(scaler, feature_cols, y_test_final)
# y_pred_inv = inverse_transform_target_2d(scaler, feature_cols, y_pred_final)
#
# days2 = np.arange(90)
# plt.figure(figsize=(14, 5))
# plt.plot(days2, y_test_inv[0], label='Ground Truth', color='blue', linewidth=2)
# plt.plot(days2, y_pred_inv[0], label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
# plt.xlabel('Day from Prediction Start')
# plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
# plt.title('90-day Predictions vs Ground Truth')
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
