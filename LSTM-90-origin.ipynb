# %% [markdown]
# **数据预处理**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# 读取数据
df = pd.read_csv('data//train.csv', parse_dates=['DateTime'])
# 转换所有应为数值的列为 float（防止字符串类型报错）
numeric_cols = [
    'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]
columns_to_drop=['RR','NBJRR5']
# 强制转换为 float，如果有无法解析的值，设置为 NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
df.dropna(subset=numeric_cols, inplace=True)

df=df.drop(columns=columns_to_drop)
# 添加日期列
df['Date'] = df['DateTime'].dt.date  # 只保留年月日部分

# 计算 sub_metering_remainder（每分钟）
df['sub_metering_remainder'] = (df['Global_active_power'] * 1000 / 60) - (
    df['Sub_metering_1'] + df['Sub_metering_2'] + df['Sub_metering_3'])

# 定义日级聚合函数
daily_agg = {
    'Global_active_power': 'mean' ,
    'Global_reactive_power': 'mean',
    'Sub_metering_1': 'sum',  # 已是 Wh，每分钟累计可以直接 sum
    'Sub_metering_2': 'sum',
    'Sub_metering_3': 'sum',
    'sub_metering_remainder': 'sum',

    'Voltage': 'mean',  # 电压波动，均值即可
    'Global_intensity': 'mean',  # 电流均值也合理

    'RR': 'first',  # 天气指标，一天一个值即可
    'NBJRR1': 'first',
    'NBJRR5': 'first',
    'NBJRR10': 'first',
    'NBJBROU': 'first'
}
for col in columns_to_drop:
    daily_agg.pop(col, None)

# 按日期聚合
df_daily = df.groupby('Date').agg(daily_agg).reset_index()

# 可以选择将日期列转回 datetime 类型
df_daily['Date'] = pd.to_datetime(df_daily['Date'])
df_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
df_daily['day_of_month'] = df_daily['Date'].dt.day
df_daily['month'] = df_daily['Date'].dt.month
df_daily['quarter'] = df_daily['Date'].dt.quarter
# 查看结果
print("预处理后日级数据：")
print(df_daily.info())
print(df_daily.head())
feature_cols = [col for col in df_daily.columns if col != 'Date']
scaler = MinMaxScaler()
df_daily_scaled = df_daily.copy()
df_daily_scaled[feature_cols] = scaler.fit_transform(df_daily[feature_cols])
print(df_daily_scaled.head())
# Out:
# 预处理后日级数据：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    746 non-null    datetime64[ns]
#  1   Global_active_power     746 non-null    float64
#  2   Global_reactive_power   746 non-null    float64
#  3   Sub_metering_1          746 non-null    float64
#  4   Sub_metering_2          746 non-null    float64
#  5   Sub_metering_3          746 non-null    float64
#  6   sub_metering_remainder  746 non-null    float64
#  7   Voltage                 746 non-null    float64
#  8   Global_intensity        746 non-null    float64
#  9   NBJRR1                  746 non-null    float64
#  10  NBJRR10                 746 non-null    float64
#  11  NBJBROU                 746 non-null    float64
#  12  day_of_week             746 non-null    int32
#  13  day_of_month            746 non-null    int32
#  14  month                   746 non-null    int32
#  15  quarter                 746 non-null    int32
# dtypes: datetime64[ns](1), float64(11), int32(4)
# memory usage: 81.7 KB
# None
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             3.053475               0.088187             0.0
# 1 2006-12-17             2.354486               0.156949          2033.0
# 2 2006-12-18             1.530435               0.112356          1063.0
# 3 2006-12-19             1.157079               0.104821           839.0
# 4 2006-12-20             1.545658               0.111804             0.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0           546.0          4926.0            14680.933333  236.243763
# 1          4187.0         13341.0            36946.666667  240.087028
# 2          2621.0         14018.0            19028.433333  241.231694
# 3          7602.0          6197.0            13131.900000  241.999313
# 4          2648.0         14063.0            20384.800000  242.308062
#
#    Global_intensity  NBJRR1  NBJRR10  NBJBROU  day_of_week  day_of_month  \
# 0         13.082828   9.333    2.167    0.167            5            16
# 1          9.999028   9.333    2.167    0.167            6            17
# 2          6.421667   9.333    2.167    0.167            0            18
# 3          4.926389   9.333    2.167    0.167            1            19
# 4          6.467361   9.333    2.167    0.167            2            20
#
#    month  quarter
# 0     12        4
# 1     12        4
# 2     12        4
# 3     12        4
# 4     12        4
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             0.916786               0.141546        0.000000
# 1 2006-12-17             0.694252               0.461964        0.196501
# 2 2006-12-18             0.431901               0.254168        0.102745
# 3 2006-12-19             0.313037               0.219057        0.081094
# 4 2006-12-20             0.436748               0.251599        0.000000
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder   Voltage  \
# 0        0.045090        0.252499                0.233317  0.371797
# 1        0.345776        0.683838                0.596096  0.648958
# 2        0.216451        0.718540                0.304152  0.731507
# 3        0.627798        0.317648                0.208079  0.786865
# 4        0.218680        0.720847                0.326251  0.809131
#
#    Global_intensity    NBJRR1  NBJRR10  NBJBROU  day_of_week  day_of_month  \
# 0          0.928499  0.480759   0.4925   0.4175     0.833333      0.500000
# 1          0.695226  0.480759   0.4925   0.4175     1.000000      0.533333
# 2          0.424618  0.480759   0.4925   0.4175     0.000000      0.566667
# 3          0.311508  0.480759   0.4925   0.4175     0.166667      0.600000
# 4          0.428075  0.480759   0.4925   0.4175     0.333333      0.633333
#
#    month  quarter
# 0    1.0      1.0
# 1    1.0      1.0
# 2    1.0      1.0
# 3    1.0      1.0
# 4    1.0      1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target_col = 'Global_active_power'
# 计算皮尔逊相关系数矩阵
corr_matrix = df_daily[feature_cols + [target_col]].corr()

# 可视化热力图
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title("Pearson Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import mutual_info_regression

X = df_daily[feature_cols]
y = df_daily[target_col]

mi_scores = mutual_info_regression(X, y, random_state=0)
mi_series = pd.Series(mi_scores, index=feature_cols).sort_values(ascending=False)

# 可视化
plt.figure(figsize=(10, 5))
mi_series.plot(kind='bar', color='darkorange')
plt.title(f'Mutual Information with Target: {target_col}')
plt.ylabel('MI Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **构造监督学习数据集**

# %%
def create_supervised_data(df, input_window=90, output_window=90, target_col='Global_active_power'):
    """
    构造用于多变量时间序列预测的监督学习样本
    参数：
        df: 已按天聚合的 DataFrame，包含时间序列特征
        input_window: 输入时间步长（例如 90）
        output_window: 预测步长（例如 90 或 365）
        target_col: 预测目标列
    返回：
        X: shape = [样本数, input_window, 特征数]
        y: shape = [样本数, output_window]
    """
    data = df.copy()
    feature_cols = [col for col in data.columns if col != 'Date']

    X_list = []
    y_list = []

    for i in range(len(data) - input_window - output_window + 1):
        x_window = data[feature_cols].iloc[i : i + input_window].values
        y_window = data[target_col].iloc[i + input_window : i + input_window + output_window].values

        if not (np.isnan(x_window).any() or np.isnan(y_window).any()):
            X_list.append(x_window)
            y_list.append(y_window)

    X = np.array(X_list)
    y = np.array(y_list)
    return X, y

# %% [markdown]
# LSTM模型设计

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow.keras.backend as K
from tensorflow.keras.losses import Huber
def mae_with_derivative(y_true, y_pred):
    mae = K.mean(K.abs(y_pred - y_true))
    # 一阶差分
    diff_true = y_true[:, 1:] - y_true[:, :-1]
    diff_pred = y_pred[:, 1:] - y_pred[:, :-1]
    diff_loss = K.mean(K.abs(diff_true - diff_pred))
    return mae + 0.5 * diff_loss  # 你可以调节这个系数


def build_lstm_model(input_timesteps, num_features, output_timesteps):
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(input_timesteps, num_features)))
    model.add(Dropout(0.2))
    # model.add(LSTM(128, return_sequences=False))
    # model.add(Dropout(0.2))
    model.add(Dense(output_timesteps))  # 默认线性激活
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# **模型训练函数**

# %%
from tensorflow.keras.callbacks import EarlyStopping
def train_transformer_model(X_train, y_train, X_val, y_val,
                     input_timesteps, num_features, output_timesteps,
                     epochs=50, batch_size=64, n_runs=5):
    from tensorflow.keras import backend as K

    mse_list = []
    mae_list = []
    best_model = None
    best_mse = float('inf')

    for run in range(n_runs):
        print(f"\n===== Run {run+1}/{n_runs} =====")
        model = build_lstm_model(input_timesteps, num_features, output_timesteps)

        early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

        model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),  # 显式验证集
            callbacks=[early_stopping],
            verbose=2
        )

        # 验证集评估（用于模型选择）
        loss, mae = model.evaluate(X_val, y_val, verbose=0)
        mse = loss

        print(f"Run {run+1} - MSE: {mse:.6f}, MAE: {mae:.6f}")

        mse_list.append(mse)
        mae_list.append(mae)

        if mse < best_mse:
            best_mse = mse
            best_model = model

        K.clear_session()

    results = {
        'mse_mean': np.mean(mse_list),
        'mse_std': np.std(mse_list),
        'mae_mean': np.mean(mae_list),
        'mae_std': np.std(mae_list),
    }

    print("\n===== Summary =====")
    print(f"MSE mean: {results['mse_mean']:.6f}, std: {results['mse_std']:.6f}")
    print(f"MAE mean: {results['mae_mean']:.6f}, std: {results['mae_std']:.6f}")

    return best_model, results

# %% [markdown]
# 开始训练

# %%
input_window = 90
output_window = 90
target_col = 'Global_active_power'

X_full, y_full = create_supervised_data(df_daily_scaled, input_window, output_window, target_col)
print(f"X shape: {X_full.shape}, y shape: {y_full.shape}")
print(f"原始日级数据总天数: {df_daily.shape[0]}")
print(f"用于建模的样本数: {len(X_full)}")

# 划分训练集和验证集
train_ratio = 0.9
split_idx = int(len(X_full) * train_ratio)
X_train, X_val = X_full[:split_idx], X_full[split_idx:]
y_train, y_val = y_full[:split_idx], y_full[split_idx:]

print(f"训练集样本数: {len(X_train)}, 验证集样本数: {len(X_val)}")

num_features = X_train.shape[2]

model, results = train_transformer_model(
    X_train, y_train, X_val, y_val,
    input_window, num_features, output_window,
    epochs=50, batch_size=32, n_runs=5
)
# Out:
# X shape: (567, 90, 15), y shape: (567, 90)
# 原始日级数据总天数: 746
# 用于建模的样本数: 567
# 训练集样本数: 510, 验证集样本数: 57
#
# ===== Run 1/5 =====
# Epoch 1/50
# C:\code\MLFinal\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 - 1s - 73ms/step - loss: 0.0420 - mae: 0.1610 - val_loss: 0.0198 - val_mae: 0.1065
# Epoch 2/50
# 16/16 - 0s - 24ms/step - loss: 0.0187 - mae: 0.1074 - val_loss: 0.0184 - val_mae: 0.1034
# Epoch 3/50
# 16/16 - 0s - 22ms/step - loss: 0.0159 - mae: 0.0985 - val_loss: 0.0193 - val_mae: 0.1077
# Epoch 4/50
# 16/16 - 0s - 23ms/step - loss: 0.0143 - mae: 0.0934 - val_loss: 0.0183 - val_mae: 0.1042
# Epoch 5/50
# 16/16 - 0s - 21ms/step - loss: 0.0135 - mae: 0.0909 - val_loss: 0.0157 - val_mae: 0.0935
# Epoch 6/50
# 16/16 - 0s - 24ms/step - loss: 0.0129 - mae: 0.0887 - val_loss: 0.0170 - val_mae: 0.0999
# Epoch 7/50
# 16/16 - 0s - 23ms/step - loss: 0.0128 - mae: 0.0882 - val_loss: 0.0148 - val_mae: 0.0898
# Epoch 8/50
# 16/16 - 0s - 23ms/step - loss: 0.0120 - mae: 0.0855 - val_loss: 0.0151 - val_mae: 0.0921
# Epoch 9/50
# 16/16 - 0s - 22ms/step - loss: 0.0118 - mae: 0.0849 - val_loss: 0.0143 - val_mae: 0.0881
# Epoch 10/50
# 16/16 - 0s - 24ms/step - loss: 0.0115 - mae: 0.0834 - val_loss: 0.0131 - val_mae: 0.0849
# Epoch 11/50
# 16/16 - 0s - 23ms/step - loss: 0.0112 - mae: 0.0830 - val_loss: 0.0131 - val_mae: 0.0843
# Epoch 12/50
# 16/16 - 0s - 23ms/step - loss: 0.0110 - mae: 0.0818 - val_loss: 0.0127 - val_mae: 0.0839
# Epoch 13/50
# 16/16 - 0s - 24ms/step - loss: 0.0107 - mae: 0.0808 - val_loss: 0.0127 - val_mae: 0.0841
# Epoch 14/50
# 16/16 - 0s - 23ms/step - loss: 0.0104 - mae: 0.0797 - val_loss: 0.0128 - val_mae: 0.0848
# Epoch 15/50
# 16/16 - 0s - 21ms/step - loss: 0.0104 - mae: 0.0795 - val_loss: 0.0129 - val_mae: 0.0846
# Epoch 16/50
# 16/16 - 0s - 22ms/step - loss: 0.0102 - mae: 0.0791 - val_loss: 0.0131 - val_mae: 0.0859
# Epoch 17/50
# 16/16 - 0s - 22ms/step - loss: 0.0100 - mae: 0.0784 - val_loss: 0.0129 - val_mae: 0.0863
# Epoch 18/50
# 16/16 - 0s - 22ms/step - loss: 0.0098 - mae: 0.0774 - val_loss: 0.0127 - val_mae: 0.0838
# Epoch 19/50
# 16/16 - 0s - 22ms/step - loss: 0.0096 - mae: 0.0766 - val_loss: 0.0127 - val_mae: 0.0851
# Epoch 20/50
# 16/16 - 0s - 22ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0126 - val_mae: 0.0846
# Epoch 21/50
# 16/16 - 0s - 22ms/step - loss: 0.0094 - mae: 0.0758 - val_loss: 0.0128 - val_mae: 0.0855
# Epoch 22/50
# 16/16 - 0s - 22ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0124 - val_mae: 0.0840
# Epoch 23/50
# 16/16 - 0s - 22ms/step - loss: 0.0090 - mae: 0.0741 - val_loss: 0.0121 - val_mae: 0.0835
# Epoch 24/50
# 16/16 - 0s - 24ms/step - loss: 0.0089 - mae: 0.0739 - val_loss: 0.0121 - val_mae: 0.0842
# Epoch 25/50
# 16/16 - 0s - 23ms/step - loss: 0.0089 - mae: 0.0735 - val_loss: 0.0119 - val_mae: 0.0830
# Epoch 26/50
# 16/16 - 0s - 22ms/step - loss: 0.0088 - mae: 0.0733 - val_loss: 0.0119 - val_mae: 0.0830
# Epoch 27/50
# 16/16 - 0s - 23ms/step - loss: 0.0086 - mae: 0.0726 - val_loss: 0.0120 - val_mae: 0.0838
# Epoch 28/50
# 16/16 - 0s - 23ms/step - loss: 0.0085 - mae: 0.0718 - val_loss: 0.0120 - val_mae: 0.0836
# Epoch 29/50
# 16/16 - 0s - 24ms/step - loss: 0.0084 - mae: 0.0716 - val_loss: 0.0117 - val_mae: 0.0826
# Epoch 30/50
# 16/16 - 0s - 23ms/step - loss: 0.0084 - mae: 0.0715 - val_loss: 0.0114 - val_mae: 0.0813
# Epoch 31/50
# 16/16 - 0s - 23ms/step - loss: 0.0084 - mae: 0.0716 - val_loss: 0.0120 - val_mae: 0.0836
# Epoch 32/50
# 16/16 - 0s - 24ms/step - loss: 0.0083 - mae: 0.0711 - val_loss: 0.0115 - val_mae: 0.0814
# Epoch 33/50
# 16/16 - 0s - 24ms/step - loss: 0.0083 - mae: 0.0712 - val_loss: 0.0114 - val_mae: 0.0812
# Epoch 34/50
# 16/16 - 0s - 23ms/step - loss: 0.0082 - mae: 0.0710 - val_loss: 0.0119 - val_mae: 0.0833
# Epoch 35/50
# 16/16 - 0s - 24ms/step - loss: 0.0082 - mae: 0.0709 - val_loss: 0.0115 - val_mae: 0.0816
# Epoch 36/50
# 16/16 - 0s - 22ms/step - loss: 0.0082 - mae: 0.0706 - val_loss: 0.0116 - val_mae: 0.0823
# Epoch 37/50
# 16/16 - 0s - 23ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0115 - val_mae: 0.0815
# Epoch 38/50
# 16/16 - 0s - 23ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0114 - val_mae: 0.0813
# Epoch 39/50
# 16/16 - 0s - 23ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0116 - val_mae: 0.0815
# Epoch 40/50
# 16/16 - 0s - 24ms/step - loss: 0.0080 - mae: 0.0699 - val_loss: 0.0120 - val_mae: 0.0838
# Epoch 41/50
# 16/16 - 0s - 22ms/step - loss: 0.0080 - mae: 0.0699 - val_loss: 0.0112 - val_mae: 0.0801
# Epoch 42/50
# 16/16 - 0s - 22ms/step - loss: 0.0079 - mae: 0.0695 - val_loss: 0.0114 - val_mae: 0.0809
# Epoch 43/50
# 16/16 - 0s - 23ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0115 - val_mae: 0.0814
# Epoch 44/50
# 16/16 - 0s - 24ms/step - loss: 0.0078 - mae: 0.0691 - val_loss: 0.0117 - val_mae: 0.0824
# Epoch 45/50
# 16/16 - 0s - 24ms/step - loss: 0.0077 - mae: 0.0687 - val_loss: 0.0117 - val_mae: 0.0824
# Epoch 46/50
# 16/16 - 0s - 24ms/step - loss: 0.0077 - mae: 0.0687 - val_loss: 0.0117 - val_mae: 0.0820
# Epoch 47/50
# 16/16 - 0s - 22ms/step - loss: 0.0077 - mae: 0.0687 - val_loss: 0.0115 - val_mae: 0.0817
# Epoch 48/50
# 16/16 - 0s - 22ms/step - loss: 0.0077 - mae: 0.0688 - val_loss: 0.0115 - val_mae: 0.0813
# Epoch 49/50
# 16/16 - 0s - 23ms/step - loss: 0.0077 - mae: 0.0687 - val_loss: 0.0116 - val_mae: 0.0816
# Epoch 50/50
# 16/16 - 0s - 24ms/step - loss: 0.0076 - mae: 0.0683 - val_loss: 0.0115 - val_mae: 0.0815
# Run 1 - MSE: 0.011216, MAE: 0.080133
# WARNING:tensorflow:From C:\code\MLFinal\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# ===== Run 2/5 =====
# Epoch 1/50
# 16/16 - 1s - 76ms/step - loss: 0.0505 - mae: 0.1782 - val_loss: 0.0236 - val_mae: 0.1178
# Epoch 2/50
# 16/16 - 0s - 24ms/step - loss: 0.0207 - mae: 0.1130 - val_loss: 0.0183 - val_mae: 0.1013
# Epoch 3/50
# 16/16 - 0s - 25ms/step - loss: 0.0167 - mae: 0.1012 - val_loss: 0.0217 - val_mae: 0.1152
# Epoch 4/50
# 16/16 - 0s - 24ms/step - loss: 0.0154 - mae: 0.0971 - val_loss: 0.0183 - val_mae: 0.1030
# Epoch 5/50
# 16/16 - 0s - 22ms/step - loss: 0.0142 - mae: 0.0931 - val_loss: 0.0198 - val_mae: 0.1102
# Epoch 6/50
# 16/16 - 0s - 22ms/step - loss: 0.0133 - mae: 0.0902 - val_loss: 0.0174 - val_mae: 0.1003
# Epoch 7/50
# 16/16 - 0s - 23ms/step - loss: 0.0128 - mae: 0.0886 - val_loss: 0.0148 - val_mae: 0.0883
# Epoch 8/50
# 16/16 - 0s - 21ms/step - loss: 0.0125 - mae: 0.0876 - val_loss: 0.0149 - val_mae: 0.0891
# Epoch 9/50
# 16/16 - 0s - 22ms/step - loss: 0.0120 - mae: 0.0857 - val_loss: 0.0148 - val_mae: 0.0904
# Epoch 10/50
# 16/16 - 0s - 22ms/step - loss: 0.0118 - mae: 0.0849 - val_loss: 0.0139 - val_mae: 0.0861
# Epoch 11/50
# 16/16 - 0s - 22ms/step - loss: 0.0114 - mae: 0.0838 - val_loss: 0.0136 - val_mae: 0.0853
# Epoch 12/50
# 16/16 - 1s - 37ms/step - loss: 0.0113 - mae: 0.0833 - val_loss: 0.0137 - val_mae: 0.0866
# Epoch 13/50
# 16/16 - 1s - 32ms/step - loss: 0.0111 - mae: 0.0823 - val_loss: 0.0134 - val_mae: 0.0871
# Epoch 14/50
# 16/16 - 0s - 22ms/step - loss: 0.0108 - mae: 0.0815 - val_loss: 0.0141 - val_mae: 0.0895
# Epoch 15/50
# 16/16 - 0s - 21ms/step - loss: 0.0105 - mae: 0.0799 - val_loss: 0.0147 - val_mae: 0.0919
# Epoch 16/50
# 16/16 - 0s - 21ms/step - loss: 0.0105 - mae: 0.0801 - val_loss: 0.0132 - val_mae: 0.0864
# Epoch 17/50
# 16/16 - 0s - 26ms/step - loss: 0.0102 - mae: 0.0786 - val_loss: 0.0161 - val_mae: 0.0971
# Epoch 18/50
# 16/16 - 1s - 33ms/step - loss: 0.0102 - mae: 0.0793 - val_loss: 0.0135 - val_mae: 0.0872
# Epoch 19/50
# 16/16 - 0s - 21ms/step - loss: 0.0100 - mae: 0.0779 - val_loss: 0.0141 - val_mae: 0.0908
# Epoch 20/50
# 16/16 - 0s - 21ms/step - loss: 0.0098 - mae: 0.0773 - val_loss: 0.0135 - val_mae: 0.0886
# Epoch 21/50
# 16/16 - 0s - 23ms/step - loss: 0.0095 - mae: 0.0761 - val_loss: 0.0137 - val_mae: 0.0901
# Epoch 22/50
# 16/16 - 0s - 21ms/step - loss: 0.0094 - mae: 0.0757 - val_loss: 0.0140 - val_mae: 0.0917
# Epoch 23/50
# 16/16 - 0s - 21ms/step - loss: 0.0091 - mae: 0.0745 - val_loss: 0.0145 - val_mae: 0.0946
# Epoch 24/50
# 16/16 - 0s - 21ms/step - loss: 0.0090 - mae: 0.0743 - val_loss: 0.0140 - val_mae: 0.0920
# Epoch 25/50
# 16/16 - 0s - 22ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0144 - val_mae: 0.0928
# Epoch 26/50
# 16/16 - 0s - 21ms/step - loss: 0.0089 - mae: 0.0737 - val_loss: 0.0140 - val_mae: 0.0920
# Epoch 27/50
# 16/16 - 0s - 23ms/step - loss: 0.0089 - mae: 0.0737 - val_loss: 0.0128 - val_mae: 0.0870
# Epoch 28/50
# 16/16 - 0s - 21ms/step - loss: 0.0087 - mae: 0.0729 - val_loss: 0.0127 - val_mae: 0.0861
# Epoch 29/50
# 16/16 - 0s - 21ms/step - loss: 0.0088 - mae: 0.0738 - val_loss: 0.0133 - val_mae: 0.0880
# Epoch 30/50
# 16/16 - 0s - 21ms/step - loss: 0.0087 - mae: 0.0730 - val_loss: 0.0130 - val_mae: 0.0869
# Epoch 31/50
# 16/16 - 0s - 22ms/step - loss: 0.0085 - mae: 0.0722 - val_loss: 0.0147 - val_mae: 0.0928
# Epoch 32/50
# 16/16 - 0s - 21ms/step - loss: 0.0085 - mae: 0.0719 - val_loss: 0.0132 - val_mae: 0.0877
# Epoch 33/50
# 16/16 - 0s - 22ms/step - loss: 0.0084 - mae: 0.0717 - val_loss: 0.0125 - val_mae: 0.0850
# Epoch 34/50
# 16/16 - 0s - 22ms/step - loss: 0.0084 - mae: 0.0716 - val_loss: 0.0134 - val_mae: 0.0883
# Epoch 35/50
# 16/16 - 0s - 22ms/step - loss: 0.0083 - mae: 0.0716 - val_loss: 0.0143 - val_mae: 0.0912
# Epoch 36/50
# 16/16 - 0s - 21ms/step - loss: 0.0083 - mae: 0.0716 - val_loss: 0.0126 - val_mae: 0.0856
# Epoch 37/50
# 16/16 - 0s - 22ms/step - loss: 0.0083 - mae: 0.0711 - val_loss: 0.0131 - val_mae: 0.0884
# Epoch 38/50
# 16/16 - 0s - 22ms/step - loss: 0.0082 - mae: 0.0708 - val_loss: 0.0138 - val_mae: 0.0893
# Epoch 39/50
# 16/16 - 0s - 23ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0133 - val_mae: 0.0877
# Epoch 40/50
# 16/16 - 0s - 27ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0135 - val_mae: 0.0881
# Epoch 41/50
# 16/16 - 1s - 39ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0136 - val_mae: 0.0887
# Epoch 42/50
# 16/16 - 0s - 29ms/step - loss: 0.0080 - mae: 0.0703 - val_loss: 0.0126 - val_mae: 0.0852
# Epoch 43/50
# 16/16 - 0s - 27ms/step - loss: 0.0080 - mae: 0.0703 - val_loss: 0.0142 - val_mae: 0.0907
# Epoch 44/50
# 16/16 - 0s - 27ms/step - loss: 0.0080 - mae: 0.0699 - val_loss: 0.0127 - val_mae: 0.0861
# Epoch 45/50
# 16/16 - 0s - 31ms/step - loss: 0.0079 - mae: 0.0697 - val_loss: 0.0132 - val_mae: 0.0870
# Epoch 46/50
# 16/16 - 0s - 29ms/step - loss: 0.0079 - mae: 0.0697 - val_loss: 0.0123 - val_mae: 0.0843
# Epoch 47/50
# 16/16 - 0s - 31ms/step - loss: 0.0079 - mae: 0.0695 - val_loss: 0.0122 - val_mae: 0.0840
# Epoch 48/50
# 16/16 - 0s - 29ms/step - loss: 0.0078 - mae: 0.0694 - val_loss: 0.0130 - val_mae: 0.0871
# Epoch 49/50
# 16/16 - 0s - 27ms/step - loss: 0.0078 - mae: 0.0691 - val_loss: 0.0149 - val_mae: 0.0921
# Epoch 50/50
# 16/16 - 0s - 28ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0123 - val_mae: 0.0847
# Run 2 - MSE: 0.012173, MAE: 0.083997
#
# ===== Run 3/5 =====
# Epoch 1/50
# 16/16 - 3s - 191ms/step - loss: 0.0472 - mae: 0.1722 - val_loss: 0.0227 - val_mae: 0.1185
# Epoch 2/50
# 16/16 - 0s - 30ms/step - loss: 0.0197 - mae: 0.1102 - val_loss: 0.0203 - val_mae: 0.1106
# Epoch 3/50
# 16/16 - 1s - 43ms/step - loss: 0.0164 - mae: 0.1004 - val_loss: 0.0215 - val_mae: 0.1162
# Epoch 4/50
# 16/16 - 1s - 34ms/step - loss: 0.0151 - mae: 0.0958 - val_loss: 0.0214 - val_mae: 0.1172
# Epoch 5/50
# 16/16 - 0s - 27ms/step - loss: 0.0138 - mae: 0.0919 - val_loss: 0.0188 - val_mae: 0.1073
# Epoch 6/50
# 16/16 - 0s - 31ms/step - loss: 0.0132 - mae: 0.0897 - val_loss: 0.0158 - val_mae: 0.0935
# Epoch 7/50
# 16/16 - 0s - 27ms/step - loss: 0.0125 - mae: 0.0872 - val_loss: 0.0155 - val_mae: 0.0918
# Epoch 8/50
# 16/16 - 0s - 29ms/step - loss: 0.0121 - mae: 0.0861 - val_loss: 0.0142 - val_mae: 0.0868
# Epoch 9/50
# 16/16 - 0s - 27ms/step - loss: 0.0119 - mae: 0.0855 - val_loss: 0.0143 - val_mae: 0.0872
# Epoch 10/50
# 16/16 - 1s - 49ms/step - loss: 0.0118 - mae: 0.0852 - val_loss: 0.0142 - val_mae: 0.0872
# Epoch 11/50
# 16/16 - 1s - 42ms/step - loss: 0.0114 - mae: 0.0835 - val_loss: 0.0137 - val_mae: 0.0865
# Epoch 12/50
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0826 - val_loss: 0.0138 - val_mae: 0.0878
# Epoch 13/50
# 16/16 - 0s - 28ms/step - loss: 0.0110 - mae: 0.0821 - val_loss: 0.0141 - val_mae: 0.0887
# Epoch 14/50
# 16/16 - 0s - 25ms/step - loss: 0.0108 - mae: 0.0811 - val_loss: 0.0135 - val_mae: 0.0868
# Epoch 15/50
# 16/16 - 0s - 26ms/step - loss: 0.0105 - mae: 0.0801 - val_loss: 0.0150 - val_mae: 0.0929
# Epoch 16/50
# 16/16 - 1s - 45ms/step - loss: 0.0102 - mae: 0.0791 - val_loss: 0.0140 - val_mae: 0.0898
# Epoch 17/50
# 16/16 - 1s - 58ms/step - loss: 0.0100 - mae: 0.0782 - val_loss: 0.0140 - val_mae: 0.0898
# Epoch 18/50
# 16/16 - 1s - 45ms/step - loss: 0.0100 - mae: 0.0782 - val_loss: 0.0148 - val_mae: 0.0928
# Epoch 19/50
# 16/16 - 1s - 32ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0138 - val_mae: 0.0889
# Epoch 20/50
# 16/16 - 0s - 27ms/step - loss: 0.0096 - mae: 0.0769 - val_loss: 0.0131 - val_mae: 0.0862
# Epoch 21/50
# 16/16 - 1s - 50ms/step - loss: 0.0095 - mae: 0.0764 - val_loss: 0.0138 - val_mae: 0.0906
# Epoch 22/50
# 16/16 - 1s - 49ms/step - loss: 0.0094 - mae: 0.0757 - val_loss: 0.0133 - val_mae: 0.0873
# Epoch 23/50
# 16/16 - 0s - 29ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0136 - val_mae: 0.0888
# Epoch 24/50
# 16/16 - 0s - 28ms/step - loss: 0.0092 - mae: 0.0752 - val_loss: 0.0132 - val_mae: 0.0879
# Epoch 25/50
# 16/16 - 1s - 54ms/step - loss: 0.0090 - mae: 0.0745 - val_loss: 0.0133 - val_mae: 0.0883
# Epoch 26/50
# 16/16 - 1s - 48ms/step - loss: 0.0090 - mae: 0.0741 - val_loss: 0.0131 - val_mae: 0.0881
# Epoch 27/50
# 16/16 - 0s - 30ms/step - loss: 0.0090 - mae: 0.0742 - val_loss: 0.0128 - val_mae: 0.0867
# Epoch 28/50
# 16/16 - 0s - 30ms/step - loss: 0.0088 - mae: 0.0735 - val_loss: 0.0135 - val_mae: 0.0894
# Epoch 29/50
# 16/16 - 0s - 28ms/step - loss: 0.0087 - mae: 0.0727 - val_loss: 0.0138 - val_mae: 0.0900
# Epoch 30/50
# 16/16 - 1s - 33ms/step - loss: 0.0086 - mae: 0.0725 - val_loss: 0.0133 - val_mae: 0.0882
# Epoch 31/50
# 16/16 - 1s - 52ms/step - loss: 0.0085 - mae: 0.0722 - val_loss: 0.0137 - val_mae: 0.0899
# Epoch 32/50
# 16/16 - 1s - 46ms/step - loss: 0.0085 - mae: 0.0720 - val_loss: 0.0132 - val_mae: 0.0877
# Epoch 33/50
# 16/16 - 0s - 29ms/step - loss: 0.0084 - mae: 0.0717 - val_loss: 0.0130 - val_mae: 0.0869
# Epoch 34/50
# 16/16 - 0s - 30ms/step - loss: 0.0083 - mae: 0.0711 - val_loss: 0.0130 - val_mae: 0.0868
# Epoch 35/50
# 16/16 - 1s - 33ms/step - loss: 0.0082 - mae: 0.0709 - val_loss: 0.0135 - val_mae: 0.0883
# Epoch 36/50
# 16/16 - 1s - 53ms/step - loss: 0.0082 - mae: 0.0710 - val_loss: 0.0133 - val_mae: 0.0873
# Epoch 37/50
# 16/16 - 1s - 50ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0157 - val_mae: 0.0962
# Epoch 38/50
# 16/16 - 0s - 31ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0144 - val_mae: 0.0920
# Epoch 39/50
# 16/16 - 1s - 37ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0142 - val_mae: 0.0911
# Epoch 40/50
# 16/16 - 1s - 53ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0136 - val_mae: 0.0885
# Epoch 41/50
# 16/16 - 1s - 49ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0154 - val_mae: 0.0945
# Epoch 42/50
# 16/16 - 0s - 25ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0151 - val_mae: 0.0937
# Run 3 - MSE: 0.012843, MAE: 0.086683
#
# ===== Run 4/5 =====
# Epoch 1/50
# 16/16 - 2s - 134ms/step - loss: 0.0447 - mae: 0.1678 - val_loss: 0.0191 - val_mae: 0.1055
# Epoch 2/50
# 16/16 - 0s - 22ms/step - loss: 0.0195 - mae: 0.1098 - val_loss: 0.0191 - val_mae: 0.1069
# Epoch 3/50
# 16/16 - 0s - 22ms/step - loss: 0.0160 - mae: 0.0992 - val_loss: 0.0190 - val_mae: 0.1069
# Epoch 4/50
# 16/16 - 0s - 22ms/step - loss: 0.0145 - mae: 0.0942 - val_loss: 0.0180 - val_mae: 0.1032
# Epoch 5/50
# 16/16 - 0s - 21ms/step - loss: 0.0135 - mae: 0.0906 - val_loss: 0.0156 - val_mae: 0.0925
# Epoch 6/50
# 16/16 - 0s - 22ms/step - loss: 0.0132 - mae: 0.0897 - val_loss: 0.0154 - val_mae: 0.0918
# Epoch 7/50
# 16/16 - 0s - 23ms/step - loss: 0.0124 - mae: 0.0871 - val_loss: 0.0146 - val_mae: 0.0889
# Epoch 8/50
# 16/16 - 0s - 21ms/step - loss: 0.0121 - mae: 0.0860 - val_loss: 0.0146 - val_mae: 0.0883
# Epoch 9/50
# 16/16 - 0s - 21ms/step - loss: 0.0120 - mae: 0.0854 - val_loss: 0.0139 - val_mae: 0.0864
# Epoch 10/50
# 16/16 - 0s - 21ms/step - loss: 0.0118 - mae: 0.0848 - val_loss: 0.0149 - val_mae: 0.0918
# Epoch 11/50
# 16/16 - 0s - 20ms/step - loss: 0.0117 - mae: 0.0844 - val_loss: 0.0136 - val_mae: 0.0856
# Epoch 12/50
# 16/16 - 0s - 21ms/step - loss: 0.0113 - mae: 0.0834 - val_loss: 0.0134 - val_mae: 0.0858
# Epoch 13/50
# 16/16 - 0s - 21ms/step - loss: 0.0110 - mae: 0.0819 - val_loss: 0.0133 - val_mae: 0.0863
# Epoch 14/50
# 16/16 - 0s - 21ms/step - loss: 0.0107 - mae: 0.0806 - val_loss: 0.0139 - val_mae: 0.0890
# Epoch 15/50
# 16/16 - 0s - 21ms/step - loss: 0.0104 - mae: 0.0797 - val_loss: 0.0138 - val_mae: 0.0888
# Epoch 16/50
# 16/16 - 0s - 21ms/step - loss: 0.0102 - mae: 0.0790 - val_loss: 0.0180 - val_mae: 0.1020
# Epoch 17/50
# 16/16 - 0s - 21ms/step - loss: 0.0100 - mae: 0.0782 - val_loss: 0.0148 - val_mae: 0.0921
# Epoch 18/50
# 16/16 - 0s - 21ms/step - loss: 0.0099 - mae: 0.0781 - val_loss: 0.0138 - val_mae: 0.0897
# Epoch 19/50
# 16/16 - 0s - 21ms/step - loss: 0.0098 - mae: 0.0776 - val_loss: 0.0141 - val_mae: 0.0914
# Epoch 20/50
# 16/16 - 0s - 21ms/step - loss: 0.0094 - mae: 0.0761 - val_loss: 0.0132 - val_mae: 0.0873
# Epoch 21/50
# 16/16 - 0s - 21ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0133 - val_mae: 0.0886
# Epoch 22/50
# 16/16 - 0s - 21ms/step - loss: 0.0092 - mae: 0.0753 - val_loss: 0.0131 - val_mae: 0.0869
# Epoch 23/50
# 16/16 - 0s - 21ms/step - loss: 0.0091 - mae: 0.0747 - val_loss: 0.0132 - val_mae: 0.0870
# Epoch 24/50
# 16/16 - 0s - 21ms/step - loss: 0.0091 - mae: 0.0746 - val_loss: 0.0132 - val_mae: 0.0874
# Epoch 25/50
# 16/16 - 0s - 22ms/step - loss: 0.0089 - mae: 0.0740 - val_loss: 0.0129 - val_mae: 0.0859
# Epoch 26/50
# 16/16 - 0s - 21ms/step - loss: 0.0087 - mae: 0.0731 - val_loss: 0.0126 - val_mae: 0.0851
# Epoch 27/50
# 16/16 - 0s - 21ms/step - loss: 0.0087 - mae: 0.0730 - val_loss: 0.0126 - val_mae: 0.0851
# Epoch 28/50
# 16/16 - 0s - 21ms/step - loss: 0.0086 - mae: 0.0727 - val_loss: 0.0135 - val_mae: 0.0887
# Epoch 29/50
# 16/16 - 0s - 24ms/step - loss: 0.0086 - mae: 0.0726 - val_loss: 0.0148 - val_mae: 0.0937
# Epoch 30/50
# 16/16 - 0s - 28ms/step - loss: 0.0085 - mae: 0.0719 - val_loss: 0.0134 - val_mae: 0.0883
# Epoch 31/50
# 16/16 - 0s - 26ms/step - loss: 0.0084 - mae: 0.0720 - val_loss: 0.0136 - val_mae: 0.0891
# Epoch 32/50
# 16/16 - 0s - 25ms/step - loss: 0.0084 - mae: 0.0718 - val_loss: 0.0138 - val_mae: 0.0898
# Epoch 33/50
# 16/16 - 0s - 22ms/step - loss: 0.0082 - mae: 0.0711 - val_loss: 0.0141 - val_mae: 0.0910
# Epoch 34/50
# 16/16 - 0s - 21ms/step - loss: 0.0083 - mae: 0.0717 - val_loss: 0.0136 - val_mae: 0.0886
# Epoch 35/50
# 16/16 - 0s - 21ms/step - loss: 0.0083 - mae: 0.0712 - val_loss: 0.0133 - val_mae: 0.0870
# Epoch 36/50
# 16/16 - 0s - 22ms/step - loss: 0.0082 - mae: 0.0711 - val_loss: 0.0136 - val_mae: 0.0889
# Epoch 37/50
# 16/16 - 0s - 21ms/step - loss: 0.0082 - mae: 0.0710 - val_loss: 0.0130 - val_mae: 0.0862
# Epoch 38/50
# 16/16 - 0s - 21ms/step - loss: 0.0081 - mae: 0.0706 - val_loss: 0.0128 - val_mae: 0.0857
# Epoch 39/50
# 16/16 - 0s - 21ms/step - loss: 0.0081 - mae: 0.0703 - val_loss: 0.0131 - val_mae: 0.0865
# Epoch 40/50
# 16/16 - 0s - 21ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0139 - val_mae: 0.0899
# Epoch 41/50
# 16/16 - 0s - 21ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0140 - val_mae: 0.0899
# Epoch 42/50
# 16/16 - 0s - 21ms/step - loss: 0.0080 - mae: 0.0699 - val_loss: 0.0123 - val_mae: 0.0841
# Epoch 43/50
# 16/16 - 0s - 21ms/step - loss: 0.0080 - mae: 0.0699 - val_loss: 0.0138 - val_mae: 0.0897
# Epoch 44/50
# 16/16 - 0s - 21ms/step - loss: 0.0079 - mae: 0.0696 - val_loss: 0.0141 - val_mae: 0.0898
# Epoch 45/50
# 16/16 - 0s - 21ms/step - loss: 0.0078 - mae: 0.0694 - val_loss: 0.0147 - val_mae: 0.0911
# Epoch 46/50
# 16/16 - 0s - 21ms/step - loss: 0.0078 - mae: 0.0694 - val_loss: 0.0128 - val_mae: 0.0851
# Epoch 47/50
# 16/16 - 0s - 21ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0132 - val_mae: 0.0865
# Epoch 48/50
# 16/16 - 0s - 21ms/step - loss: 0.0078 - mae: 0.0689 - val_loss: 0.0126 - val_mae: 0.0851
# Epoch 49/50
# 16/16 - 0s - 21ms/step - loss: 0.0077 - mae: 0.0686 - val_loss: 0.0158 - val_mae: 0.0959
# Epoch 50/50
# 16/16 - 0s - 21ms/step - loss: 0.0077 - mae: 0.0685 - val_loss: 0.0133 - val_mae: 0.0876
# Run 4 - MSE: 0.012322, MAE: 0.084116
#
# ===== Run 5/5 =====
# Epoch 1/50
# 16/16 - 1s - 66ms/step - loss: 0.0466 - mae: 0.1697 - val_loss: 0.0206 - val_mae: 0.1107
# Epoch 2/50
# 16/16 - 0s - 22ms/step - loss: 0.0196 - mae: 0.1096 - val_loss: 0.0181 - val_mae: 0.1030
# Epoch 3/50
# 16/16 - 0s - 21ms/step - loss: 0.0159 - mae: 0.0982 - val_loss: 0.0193 - val_mae: 0.1093
# Epoch 4/50
# 16/16 - 0s - 22ms/step - loss: 0.0144 - mae: 0.0935 - val_loss: 0.0165 - val_mae: 0.0970
# Epoch 5/50
# 16/16 - 0s - 23ms/step - loss: 0.0136 - mae: 0.0908 - val_loss: 0.0148 - val_mae: 0.0897
# Epoch 6/50
# 16/16 - 0s - 21ms/step - loss: 0.0129 - mae: 0.0890 - val_loss: 0.0142 - val_mae: 0.0863
# Epoch 7/50
# 16/16 - 0s - 21ms/step - loss: 0.0124 - mae: 0.0870 - val_loss: 0.0143 - val_mae: 0.0885
# Epoch 8/50
# 16/16 - 0s - 23ms/step - loss: 0.0122 - mae: 0.0862 - val_loss: 0.0139 - val_mae: 0.0861
# Epoch 9/50
# 16/16 - 1s - 32ms/step - loss: 0.0118 - mae: 0.0852 - val_loss: 0.0139 - val_mae: 0.0867
# Epoch 10/50
# 16/16 - 0s - 26ms/step - loss: 0.0115 - mae: 0.0836 - val_loss: 0.0132 - val_mae: 0.0846
# Epoch 11/50
# 16/16 - 0s - 22ms/step - loss: 0.0113 - mae: 0.0831 - val_loss: 0.0136 - val_mae: 0.0872
# Epoch 12/50
# 16/16 - 0s - 24ms/step - loss: 0.0111 - mae: 0.0823 - val_loss: 0.0130 - val_mae: 0.0850
# Epoch 13/50
# 16/16 - 0s - 22ms/step - loss: 0.0110 - mae: 0.0822 - val_loss: 0.0127 - val_mae: 0.0849
# Epoch 14/50
# 16/16 - 0s - 25ms/step - loss: 0.0108 - mae: 0.0816 - val_loss: 0.0130 - val_mae: 0.0858
# Epoch 15/50
# 16/16 - 0s - 28ms/step - loss: 0.0108 - mae: 0.0813 - val_loss: 0.0128 - val_mae: 0.0861
# Epoch 16/50
# 16/16 - 0s - 23ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0132 - val_mae: 0.0874
# Epoch 17/50
# 16/16 - 0s - 22ms/step - loss: 0.0102 - mae: 0.0789 - val_loss: 0.0142 - val_mae: 0.0908
# Epoch 18/50
# 16/16 - 0s - 22ms/step - loss: 0.0101 - mae: 0.0785 - val_loss: 0.0136 - val_mae: 0.0887
# Epoch 19/50
# 16/16 - 0s - 22ms/step - loss: 0.0099 - mae: 0.0781 - val_loss: 0.0161 - val_mae: 0.0966
# Epoch 20/50
# 16/16 - 0s - 23ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0145 - val_mae: 0.0936
# Epoch 21/50
# 16/16 - 0s - 22ms/step - loss: 0.0096 - mae: 0.0768 - val_loss: 0.0158 - val_mae: 0.0969
# Epoch 22/50
# 16/16 - 0s - 22ms/step - loss: 0.0095 - mae: 0.0766 - val_loss: 0.0131 - val_mae: 0.0878
# Epoch 23/50
# 16/16 - 0s - 24ms/step - loss: 0.0093 - mae: 0.0759 - val_loss: 0.0137 - val_mae: 0.0904
# Epoch 24/50
# 16/16 - 0s - 23ms/step - loss: 0.0092 - mae: 0.0753 - val_loss: 0.0135 - val_mae: 0.0908
# Epoch 25/50
# 16/16 - 0s - 22ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0130 - val_mae: 0.0871
# Epoch 26/50
# 16/16 - 0s - 21ms/step - loss: 0.0091 - mae: 0.0748 - val_loss: 0.0130 - val_mae: 0.0872
# Epoch 27/50
# 16/16 - 0s - 24ms/step - loss: 0.0090 - mae: 0.0744 - val_loss: 0.0130 - val_mae: 0.0871
# Epoch 28/50
# 16/16 - 0s - 22ms/step - loss: 0.0089 - mae: 0.0741 - val_loss: 0.0128 - val_mae: 0.0865
# Run 5 - MSE: 0.012690, MAE: 0.084885
#
# ===== Summary =====
# MSE mean: 0.012249, std: 0.000570
# MAE mean: 0.083963, std: 0.002142

# %% [markdown]
# 测试集+作图

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
df_test = pd.read_csv('data/test.csv', header=None)

# Step 2：赋完整列名（按顺序）
df_test.columns = [
    'DateTime', 'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]




# 数值列转换（如有非数字或缺失，转为NaN）
df_test[numeric_cols] = df_test[numeric_cols].apply(pd.to_numeric, errors='coerce')
# 显式删除不需要字段
df_test = df_test.drop(columns=columns_to_drop)
df_test['DateTime'] = pd.to_datetime(df['DateTime'], errors='coerce')
df_test['Date'] = df_test['DateTime'].dt.date

# 计算 sub_metering_remainder
df_test['sub_metering_remainder'] = (df_test['Global_active_power'] * 1000 / 60) - (
    df_test['Sub_metering_1'] + df_test['Sub_metering_2'] + df_test['Sub_metering_3'])

# 按天聚合
df_test_daily = df_test.groupby('Date').agg(daily_agg).reset_index()
df_test_daily['Date'] = pd.to_datetime(df_test_daily['Date'])
df_test_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
df_test_daily['day_of_month'] = df_daily['Date'].dt.day
df_test_daily['month'] = df_daily['Date'].dt.month
df_test_daily['quarter'] = df_daily['Date'].dt.quarter
# ========== 关键修改点：丢弃含NaN的天 ==========
df_test_daily_clean = df_test_daily.dropna()
print(f"清洗后测试集天数: {len(df_test_daily_clean)}")

# 归一化（只对干净数据做）
df_test_daily_scaled = df_test_daily_clean.copy()
df_test_daily_scaled[feature_cols] = scaler.transform(df_test_daily_scaled[feature_cols])


def inverse_transform_target(scaler, feature_cols, data_1d, target_col='Global_active_power'):
    """
    把一维的目标列数据逆归一化。
    scaler: 训练时fit的Scaler
    feature_cols: 归一化时所有特征的列名列表
    data_1d: 目标列的一维归一化数据（如full_pred或full_true）
    返回：逆归一化后目标列一维数据
    """
    n = len(data_1d)
    temp = np.zeros((n, len(feature_cols)))
    # 找到目标列索引
    target_idx = feature_cols.index(target_col)
    temp[:, target_idx] = data_1d
    # 逆归一化
    inv_data = scaler.inverse_transform(temp)
    return inv_data[:, target_idx]


X_test_final, y_test_final = create_supervised_data(
    df_test_daily_scaled,
    input_window=input_window,
    output_window=output_window,
    target_col=target_col  # 一般是 'Global_active_power'
)
y_pred_final = model.predict(X_test_final)
# print("测试集天数(原始日数据):", len(df_test_daily_scaled))
# print("测试集每日特征缺失情况:\n", df_test_daily_scaled.isna().sum())
# print("预测窗口数(样本数):", len(y_pred_final))
# print("预测窗口中有缺失值样本丢弃数:", (len(df_test_daily_scaled) - input_window - output_window + 1) - len(y_pred_final))


# 初始化累计容器
total_days = input_window + (len(y_pred_final) - 1) + output_window
pred_sum = np.zeros(total_days)
pred_count = np.zeros(total_days)
true_sum = np.zeros(total_days)
true_count = np.zeros(total_days)

# 多窗口预测融合
for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
    start_idx = input_window + i
    end_idx = start_idx + output_window

    pred_sum[start_idx:end_idx] += pred
    pred_count[start_idx:end_idx] += 1

    true_sum[start_idx:end_idx] += true
    true_count[start_idx:end_idx] += 1

# 平均融合
pred_avg = np.zeros_like(pred_sum)
true_avg = np.zeros_like(true_sum)

pred_avg[pred_count > 0] = pred_sum[pred_count > 0] / pred_count[pred_count > 0]
true_avg[true_count > 0] = true_sum[true_count > 0] / true_count[true_count > 0]

# 用最后一个样本的历史输入作为上下文
# past_context = X_test_final[-1][:, 0]  # 通常预测目标在第0列

# 拼接成完整序列
# full_pred = np.concatenate([past_context, pred_avg[input_window:]])
# full_true = np.concatenate([past_context, true_avg[input_window:]])
full_pred = pred_avg[input_window:]  # 直接取模型预测融合部分
full_true = true_avg[input_window:]
# 对full_pred和full_true做逆归一化
full_pred_inv = inverse_transform_target(scaler, feature_cols, full_pred, target_col)
full_true_inv = inverse_transform_target(scaler, feature_cols, full_true, target_col)

# 横轴时间
# days = np.arange(len(full_pred) - input_window)
days = np.arange(len(full_pred))  # 对应 prediction-only 区段

plt.figure(figsize=(14, 5))
plt.plot(days, full_true_inv, label='Ground Truth', color='blue', linewidth=2)
plt.plot(days, full_pred_inv, label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('Merged 90-day Predictions vs Ground Truth (Actual Values)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
true_values_to_show = full_true_inv
pred_values_to_show = full_pred_inv

# 打印前30天（或根据需要改）
print("Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error")
print("-" * 50)
for i in range(min(30, len(true_values_to_show))):
    true_val = true_values_to_show[i]
    pred_val = pred_values_to_show[i]
    error = abs(true_val - pred_val)
    print(f"{i:3d} | {true_val:17.4f} | {pred_val:19.4f} | {error:14.4f}")



# MSE
mse = mean_squared_error(true_values_to_show, pred_values_to_show)

# RMSE
rmse = mse ** 0.5

# MAE
mae = mean_absolute_error(true_values_to_show, pred_values_to_show)
errors = pred_values_to_show- true_values_to_show
std_dev = np.std(errors)

print(f"测试集评估指标:")
print(f"MSE : {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE : {mae:.6f}")
print(f"预测误差标准差: {std_dev:.6f}")
# Out:
# C:\Users\16693\AppData\Local\Temp\ipykernel_29556\3274135352.py:3: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('data/test.csv', header=None)
# 清洗后测试集天数: 684
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error
# --------------------------------------------------
#   0 |            1.3645 |              1.3412 |         0.0232
#   1 |            1.0307 |              1.3385 |         0.3078
#   2 |            1.1437 |              1.3125 |         0.1688
#   3 |            0.9423 |              1.2967 |         0.3544
#   4 |            1.5466 |              1.2736 |         0.2729
#   5 |            0.9371 |              1.2407 |         0.3036
#   6 |            1.0013 |              1.2281 |         0.2268
#   7 |            1.0317 |              1.2501 |         0.2184
#   8 |            1.0568 |              1.2501 |         0.1933
#   9 |            1.2965 |              1.2342 |         0.0623
#  10 |            1.2550 |              1.2143 |         0.0407
#  11 |            1.8782 |              1.1969 |         0.6812
#  12 |            1.3555 |              1.1748 |         0.1807
#  13 |            1.0928 |              1.1714 |         0.0786
#  14 |            1.0722 |              1.1827 |         0.1105
#  15 |            0.8385 |              1.1938 |         0.3553
#  16 |            1.3665 |              1.1755 |         0.1909
#  17 |            1.1529 |              1.1579 |         0.0050
#  18 |            1.0313 |              1.1399 |         0.1086
#  19 |            0.8968 |              1.1226 |         0.2258
#  20 |            1.3002 |              1.1219 |         0.1783
#  21 |            1.0349 |              1.1416 |         0.1067
#  22 |            1.0774 |              1.1523 |         0.0748
#  23 |            0.7670 |              1.1437 |         0.3767
#  24 |            0.8149 |              1.1234 |         0.3084
#  25 |            1.4407 |              1.1018 |         0.3389
#  26 |            1.2046 |              1.0818 |         0.1229
#  27 |            0.9737 |              1.0830 |         0.1092
#  28 |            1.1415 |              1.1036 |         0.0380
#  29 |            1.1776 |              1.1192 |         0.0584
# 测试集评估指标:
# MSE : 0.125740
# RMSE: 0.354598
# MAE : 0.280583
# 预测误差标准差: 0.350198

# %%
def inverse_transform_target_2d(scaler, feature_cols, data_2d, target_col='Global_active_power'):
    n_samples, n_steps = data_2d.shape
    inv_data = np.zeros_like(data_2d)
    target_idx = feature_cols.index(target_col)

    for i in range(n_samples):
        temp = np.zeros((n_steps, len(feature_cols)))
        temp[:, target_idx] = data_2d[i]
        inv_temp = scaler.inverse_transform(temp)
        inv_data[i] = inv_temp[:, target_idx]
    return inv_data

# 调用示例
y_test_inv = inverse_transform_target_2d(scaler, feature_cols, y_test_final)
y_pred_inv = inverse_transform_target_2d(scaler, feature_cols, y_pred_final)

days2 = np.arange(90)
plt.figure(figsize=(14, 5))
plt.plot(days2, y_test_inv[90], label='Ground Truth', color='blue', linewidth=2)
plt.plot(days2, y_pred_inv[90], label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('90-day Predictions vs Ground Truth')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
