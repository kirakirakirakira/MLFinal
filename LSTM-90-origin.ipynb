# %% [markdown]
# **数据预处理**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

need_date_time_columns=1 #是否需要时间作为特征
columns_to_drop=[] #需要删除的列
df = pd.read_csv('data//train.csv', parse_dates=['DateTime'])
# 转换所有应为数值的列为 float（防止字符串类型报错）
numeric_cols = [
    'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]

# 强制转换为 float，如果有无法解析的值，设置为 NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
df.dropna(subset=numeric_cols, inplace=True)

df=df.drop(columns=columns_to_drop)
# 添加日期列
df['Date'] = df['DateTime'].dt.date  # 只保留年月日部分

# 计算 sub_metering_remainder（每分钟）
df['sub_metering_remainder'] = (df['Global_active_power'] * 1000 / 60) - (
    df['Sub_metering_1'] + df['Sub_metering_2'] + df['Sub_metering_3'])

# 定义日级聚合函数
daily_agg = {
    'Global_active_power': 'sum' ,
    'Global_reactive_power': 'sum',
    'Sub_metering_1': 'sum',  # 已是 Wh，每分钟累计可以直接 sum
    'Sub_metering_2': 'sum',
    'Sub_metering_3': 'sum',
    'sub_metering_remainder': 'sum',

    'Voltage': 'mean',  # 电压波动，均值即可
    'Global_intensity': 'mean',  # 电流均值也合理

    'RR': 'first',  # 天气指标，一天一个值即可
    'NBJRR1': 'first',
    'NBJRR5': 'first',
    'NBJRR10': 'first',
    'NBJBROU': 'first'
}
for col in columns_to_drop:
    daily_agg.pop(col, None)

# 按日期聚合
df_daily = df.groupby('Date').agg(daily_agg).reset_index()


# 可以选择将日期列转回 datetime 类型
if need_date_time_columns==1:
    df_daily['Date'] = pd.to_datetime(df_daily['Date'])
    df_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
    df_daily['day_of_month'] = df_daily['Date'].dt.day
    df_daily['month'] = df_daily['Date'].dt.month
    df_daily['quarter'] = df_daily['Date'].dt.quarter
# 查看结果
print("预处理后日级数据：")
print(df_daily.info())
print(df_daily.head())
feature_cols = [col for col in df_daily.columns if col != 'Date']
scaler = MinMaxScaler()
df_daily_scaled = df_daily.copy()
df_daily_scaled[feature_cols] = scaler.fit_transform(df_daily[feature_cols])
print(df_daily_scaled.head())
# Out:
# 预处理后日级数据：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    746 non-null    datetime64[ns]
#  1   Global_active_power     746 non-null    float64
#  2   Global_reactive_power   746 non-null    float64
#  3   Sub_metering_1          746 non-null    float64
#  4   Sub_metering_2          746 non-null    float64
#  5   Sub_metering_3          746 non-null    float64
#  6   sub_metering_remainder  746 non-null    float64
#  7   Voltage                 746 non-null    float64
#  8   Global_intensity        746 non-null    float64
#  9   RR                      746 non-null    float64
#  10  NBJRR1                  746 non-null    float64
#  11  NBJRR5                  746 non-null    float64
#  12  NBJRR10                 746 non-null    float64
#  13  NBJBROU                 746 non-null    float64
#  14  day_of_week             746 non-null    int32
#  15  day_of_month            746 non-null    int32
#  16  month                   746 non-null    int32
#  17  quarter                 746 non-null    int32
# dtypes: datetime64[ns](1), float64(13), int32(4)
# memory usage: 93.4 KB
# None
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             1209.176                 34.922             0.0
# 1 2006-12-17             3390.460                226.006          2033.0
# 2 2006-12-18             2203.826                161.792          1063.0
# 3 2006-12-19             1666.194                150.942           839.0
# 4 2006-12-20             2225.748                160.998             0.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0           546.0          4926.0            14680.933333  236.243763
# 1          4187.0         13341.0            36946.666667  240.087028
# 2          2621.0         14018.0            19028.433333  241.231694
# 3          7602.0          6197.0            13131.900000  241.999313
# 4          2648.0         14063.0            20384.800000  242.308062
#
#    Global_intensity     RR  NBJRR1  NBJRR5  NBJRR10  NBJBROU  day_of_week  \
# 0         13.082828  63.75   9.333   5.667    2.167    0.167            5
# 1          9.999028  63.75   9.333   5.667    2.167    0.167            6
# 2          6.421667  63.75   9.333   5.667    2.167    0.167            0
# 3          4.926389  63.75   9.333   5.667    2.167    0.167            1
# 4          6.467361  63.75   9.333   5.667    2.167    0.167            2
#
#    day_of_month  month  quarter
# 0            16     12        4
# 1            17     12        4
# 2            18     12        4
# 3            19     12        4
# 4            20     12        4
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             0.249742               0.082334        0.000000
# 1 2006-12-17             0.708897               0.573033        0.196501
# 2 2006-12-18             0.459114               0.408133        0.102745
# 3 2006-12-19             0.345944               0.380271        0.081094
# 4 2006-12-20             0.463728               0.406094        0.000000
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder   Voltage  \
# 0        0.045090        0.252499                0.233317  0.371797
# 1        0.345776        0.683838                0.596096  0.648958
# 2        0.216451        0.718540                0.304152  0.731507
# 3        0.627798        0.317648                0.208079  0.786865
# 4        0.218680        0.720847                0.326251  0.809131
#
#    Global_intensity        RR    NBJRR1    NBJRR5  NBJRR10  NBJBROU  \
# 0          0.928499  0.395727  0.480759  0.767727   0.4925   0.4175
# 1          0.695226  0.395727  0.480759  0.767727   0.4925   0.4175
# 2          0.424618  0.395727  0.480759  0.767727   0.4925   0.4175
# 3          0.311508  0.395727  0.480759  0.767727   0.4925   0.4175
# 4          0.428075  0.395727  0.480759  0.767727   0.4925   0.4175
#
#    day_of_week  day_of_month  month  quarter
# 0     0.833333      0.500000    1.0      1.0
# 1     1.000000      0.533333    1.0      1.0
# 2     0.000000      0.566667    1.0      1.0
# 3     0.166667      0.600000    1.0      1.0
# 4     0.333333      0.633333    1.0      1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target_col = 'Global_active_power'
# 计算皮尔逊相关系数矩阵
corr_matrix = df_daily[feature_cols + [target_col]].corr()

# 可视化热力图
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title("Pearson Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import mutual_info_regression

X = df_daily[feature_cols]
y = df_daily[target_col]

mi_scores = mutual_info_regression(X, y, random_state=0)
mi_series = pd.Series(mi_scores, index=feature_cols).sort_values(ascending=False)

# 可视化
plt.figure(figsize=(10, 5))
mi_series.plot(kind='bar', color='darkorange')
plt.title(f'Mutual Information with Target: {target_col}')
plt.ylabel('MI Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **构造监督学习数据集**

# %%
def create_supervised_data(df, input_window=90, output_window=90, target_col='Global_active_power'):
    """
    构造用于多变量时间序列预测的监督学习样本
    参数：
        df: 已按天聚合的 DataFrame，包含时间序列特征
        input_window: 输入时间步长（例如 90）
        output_window: 预测步长（例如 90 或 365）
        target_col: 预测目标列
    返回：
        X: shape = [样本数, input_window, 特征数]
        y: shape = [样本数, output_window]
    """
    data = df.copy()
    feature_cols = [col for col in data.columns if col != 'Date']

    X_list = []
    y_list = []

    for i in range(len(data) - input_window - output_window + 1):
        x_window = data[feature_cols].iloc[i : i + input_window].values
        y_window = data[target_col].iloc[i + input_window : i + input_window + output_window].values

        if not (np.isnan(x_window).any() or np.isnan(y_window).any()):
            X_list.append(x_window)
            y_list.append(y_window)

    X = np.array(X_list)
    y = np.array(y_list)
    return X, y

# %% [markdown]
# LSTM模型设计+训练

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow.keras.backend as K
from tensorflow.keras.losses import Huber
def mae_with_derivative(y_true, y_pred):
    mae = K.mean(K.abs(y_pred - y_true))
    # 一阶差分
    diff_true = y_true[:, 1:] - y_true[:, :-1]
    diff_pred = y_pred[:, 1:] - y_pred[:, :-1]
    diff_loss = K.mean(K.abs(diff_true - diff_pred))
    return mae + 0.5 * diff_loss  # 你可以调节这个系数


def build_lstm_model(input_timesteps, num_features, output_timesteps):
    model = Sequential()
    model.add(LSTM(256, return_sequences=True, input_shape=(input_timesteps, num_features)))
    model.add(Dropout(0.1))
    model.add(LSTM(256, return_sequences=False))
    model.add(Dropout(0.1))
    # model.add(LSTM(512, return_sequences=False))
    # model.add(Dropout(0.2))
    model.add(Dense(output_timesteps))  # 默认线性激活
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model
from tensorflow.keras.callbacks import EarlyStopping
def train_lstm_model(X_train, y_train, X_val, y_val,
                     input_timesteps, num_features, output_timesteps,
                     epochs=50, batch_size=64, n_runs=5):
    from tensorflow.keras import backend as K

    mse_list = []
    mae_list = []
    best_model = None
    best_mse = float('inf')
    # model=None
    for run in range(n_runs):
        print(f"\n===== Run {run+1}/{n_runs} =====")
        model = build_lstm_model(input_timesteps, num_features, output_timesteps)

        early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

        model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),  # 显式验证集
            callbacks=[early_stopping],
            verbose=2
        )

        # 验证集评估（用于模型选择）
        loss, mae = model.evaluate(X_val, y_val, verbose=0)
        mse = loss

        print(f"Run {run+1} - MSE: {mse:.6f}, MAE: {mae:.6f}")

        mse_list.append(mse)
        mae_list.append(mae)

        if mse < best_mse:
            best_mse = mse
            best_model = model

        K.clear_session()

    results = {
        'mse_mean': np.mean(mse_list),
        'mse_std': np.std(mse_list),
        'mae_mean': np.mean(mae_list),
        'mae_std': np.std(mae_list),
    }

    print("\n===== Summary =====")
    print(f"MSE mean: {results['mse_mean']:.6f}, std: {results['mse_std']:.6f}")
    print(f"MAE mean: {results['mae_mean']:.6f}, std: {results['mae_std']:.6f}")

    return best_model, results

# %% [markdown]
# 开始训练

# %%
#parameters
epochs=100
batch_size=16
n_nums=10
input_window = 90
output_window = 90
target_col = 'Global_active_power'

X_full, y_full = create_supervised_data(df_daily_scaled, input_window, output_window, target_col)
x_df = pd.DataFrame(X_full[0], columns=feature_cols)
y_series = pd.Series(y_full[0], name='Global_active_power')

# print("第", 0, "组 X（输入窗口）:")
# print(x_df)
#
# print("\n第", 0, "组 y（输出窗口）:")
# print(y_series)
print(f"X shape: {X_full.shape}, y shape: {y_full.shape}")
print(f"原始日级数据总天数: {df_daily.shape[0]}")
print(f"用于建模的样本数: {len(X_full)}")

# 划分训练集和验证集
train_ratio = 0.9
split_idx = int(len(X_full) * train_ratio)
X_train, X_val = X_full[:split_idx], X_full[split_idx:]
y_train, y_val = y_full[:split_idx], y_full[split_idx:]

print(f"训练集样本数: {len(X_train)}, 验证集样本数: {len(X_val)}")

num_features = X_train.shape[2]

model, results = train_lstm_model(
    X_train, y_train, X_val, y_val,
    input_window, num_features, output_window,
    epochs=epochs, batch_size=batch_size, n_runs=n_nums
)
model.summary()
# Out:
# X shape: (567, 90, 17), y shape: (567, 90)
# 原始日级数据总天数: 746
# 用于建模的样本数: 567
# 训练集样本数: 510, 验证集样本数: 57
#
# ===== Run 1/10 =====
# Epoch 1/100
# C:\code\MLFinal\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 - 4s - 112ms/step - loss: 0.0253 - mae: 0.1202 - val_loss: 0.0203 - val_mae: 0.1146
# Epoch 2/100
# 32/32 - 2s - 71ms/step - loss: 0.0122 - mae: 0.0860 - val_loss: 0.0143 - val_mae: 0.0908
# Epoch 3/100
# 32/32 - 2s - 71ms/step - loss: 0.0109 - mae: 0.0812 - val_loss: 0.0121 - val_mae: 0.0832
# Epoch 4/100
# 32/32 - 2s - 71ms/step - loss: 0.0099 - mae: 0.0780 - val_loss: 0.0119 - val_mae: 0.0795
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0097 - mae: 0.0771 - val_loss: 0.0153 - val_mae: 0.1006
# Epoch 6/100
# 32/32 - 2s - 72ms/step - loss: 0.0090 - mae: 0.0741 - val_loss: 0.0119 - val_mae: 0.0834
# Epoch 7/100
# 32/32 - 2s - 72ms/step - loss: 0.0085 - mae: 0.0723 - val_loss: 0.0124 - val_mae: 0.0895
# Epoch 8/100
# 32/32 - 2s - 72ms/step - loss: 0.0081 - mae: 0.0706 - val_loss: 0.0148 - val_mae: 0.0967
# Epoch 9/100
# 32/32 - 2s - 72ms/step - loss: 0.0082 - mae: 0.0711 - val_loss: 0.0139 - val_mae: 0.0957
# Epoch 10/100
# 32/32 - 2s - 73ms/step - loss: 0.0079 - mae: 0.0698 - val_loss: 0.0133 - val_mae: 0.0919
# Epoch 11/100
# 32/32 - 2s - 74ms/step - loss: 0.0077 - mae: 0.0690 - val_loss: 0.0135 - val_mae: 0.0918
# Epoch 12/100
# 32/32 - 2s - 72ms/step - loss: 0.0075 - mae: 0.0675 - val_loss: 0.0122 - val_mae: 0.0877
# Epoch 13/100
# 32/32 - 2s - 73ms/step - loss: 0.0073 - mae: 0.0671 - val_loss: 0.0123 - val_mae: 0.0866
# Epoch 14/100
# 32/32 - 2s - 72ms/step - loss: 0.0073 - mae: 0.0668 - val_loss: 0.0130 - val_mae: 0.0898
# Epoch 15/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0147 - val_mae: 0.0960
# Epoch 16/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0658 - val_loss: 0.0121 - val_mae: 0.0860
# Epoch 17/100
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0653 - val_loss: 0.0144 - val_mae: 0.0941
# Epoch 18/100
# 32/32 - 2s - 72ms/step - loss: 0.0069 - mae: 0.0650 - val_loss: 0.0127 - val_mae: 0.0867
# Epoch 19/100
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0126 - val_mae: 0.0872
# Epoch 20/100
# 32/32 - 2s - 72ms/step - loss: 0.0069 - mae: 0.0652 - val_loss: 0.0121 - val_mae: 0.0830
# Epoch 21/100
# 32/32 - 2s - 72ms/step - loss: 0.0067 - mae: 0.0637 - val_loss: 0.0141 - val_mae: 0.0920
# Epoch 22/100
# 32/32 - 2s - 72ms/step - loss: 0.0067 - mae: 0.0642 - val_loss: 0.0123 - val_mae: 0.0845
# Epoch 23/100
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0633 - val_loss: 0.0120 - val_mae: 0.0834
# Epoch 24/100
# 32/32 - 2s - 72ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0125 - val_mae: 0.0869
# Run 1 - MSE: 0.011872, MAE: 0.079540
#
# ===== Run 2/10 =====
# Epoch 1/100
# 32/32 - 4s - 114ms/step - loss: 0.0214 - mae: 0.1114 - val_loss: 0.0169 - val_mae: 0.1005
# Epoch 2/100
# 32/32 - 2s - 74ms/step - loss: 0.0120 - mae: 0.0853 - val_loss: 0.0188 - val_mae: 0.1110
# Epoch 3/100
# 32/32 - 2s - 74ms/step - loss: 0.0108 - mae: 0.0812 - val_loss: 0.0134 - val_mae: 0.0884
# Epoch 4/100
# 32/32 - 2s - 74ms/step - loss: 0.0100 - mae: 0.0780 - val_loss: 0.0128 - val_mae: 0.0864
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0095 - mae: 0.0762 - val_loss: 0.0125 - val_mae: 0.0901
# Epoch 6/100
# 32/32 - 2s - 74ms/step - loss: 0.0089 - mae: 0.0738 - val_loss: 0.0124 - val_mae: 0.0904
# Epoch 7/100
# 32/32 - 2s - 74ms/step - loss: 0.0084 - mae: 0.0717 - val_loss: 0.0132 - val_mae: 0.0916
# Epoch 8/100
# 32/32 - 2s - 73ms/step - loss: 0.0082 - mae: 0.0711 - val_loss: 0.0128 - val_mae: 0.0881
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0080 - mae: 0.0699 - val_loss: 0.0125 - val_mae: 0.0877
# Epoch 10/100
# 32/32 - 2s - 74ms/step - loss: 0.0077 - mae: 0.0686 - val_loss: 0.0134 - val_mae: 0.0916
# Epoch 11/100
# 32/32 - 2s - 74ms/step - loss: 0.0076 - mae: 0.0685 - val_loss: 0.0122 - val_mae: 0.0876
# Epoch 12/100
# 32/32 - 2s - 74ms/step - loss: 0.0075 - mae: 0.0680 - val_loss: 0.0117 - val_mae: 0.0854
# Epoch 13/100
# 32/32 - 2s - 74ms/step - loss: 0.0073 - mae: 0.0671 - val_loss: 0.0118 - val_mae: 0.0851
# Epoch 14/100
# 32/32 - 2s - 74ms/step - loss: 0.0072 - mae: 0.0663 - val_loss: 0.0129 - val_mae: 0.0892
# Epoch 15/100
# 32/32 - 2s - 75ms/step - loss: 0.0072 - mae: 0.0664 - val_loss: 0.0126 - val_mae: 0.0888
# Epoch 16/100
# 32/32 - 2s - 74ms/step - loss: 0.0071 - mae: 0.0662 - val_loss: 0.0115 - val_mae: 0.0810
# Epoch 17/100
# 32/32 - 2s - 74ms/step - loss: 0.0071 - mae: 0.0659 - val_loss: 0.0106 - val_mae: 0.0786
# Epoch 18/100
# 32/32 - 2s - 74ms/step - loss: 0.0069 - mae: 0.0648 - val_loss: 0.0106 - val_mae: 0.0800
# Epoch 19/100
# 32/32 - 2s - 74ms/step - loss: 0.0068 - mae: 0.0646 - val_loss: 0.0107 - val_mae: 0.0787
# Epoch 20/100
# 32/32 - 2s - 74ms/step - loss: 0.0068 - mae: 0.0649 - val_loss: 0.0107 - val_mae: 0.0796
# Epoch 21/100
# 32/32 - 2s - 74ms/step - loss: 0.0068 - mae: 0.0644 - val_loss: 0.0110 - val_mae: 0.0810
# Epoch 22/100
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0119 - val_mae: 0.0832
# Epoch 23/100
# 32/32 - 2s - 74ms/step - loss: 0.0066 - mae: 0.0633 - val_loss: 0.0109 - val_mae: 0.0809
# Epoch 24/100
# 32/32 - 2s - 74ms/step - loss: 0.0064 - mae: 0.0627 - val_loss: 0.0112 - val_mae: 0.0809
# Epoch 25/100
# 32/32 - 2s - 73ms/step - loss: 0.0063 - mae: 0.0622 - val_loss: 0.0111 - val_mae: 0.0789
# Epoch 26/100
# 32/32 - 2s - 74ms/step - loss: 0.0064 - mae: 0.0626 - val_loss: 0.0109 - val_mae: 0.0795
# Epoch 27/100
# 32/32 - 2s - 73ms/step - loss: 0.0061 - mae: 0.0615 - val_loss: 0.0114 - val_mae: 0.0806
# Epoch 28/100
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0607 - val_loss: 0.0113 - val_mae: 0.0791
# Epoch 29/100
# 32/32 - 2s - 74ms/step - loss: 0.0059 - mae: 0.0605 - val_loss: 0.0121 - val_mae: 0.0819
# Epoch 30/100
# 32/32 - 2s - 74ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0119 - val_mae: 0.0806
# Epoch 31/100
# 32/32 - 2s - 73ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0114 - val_mae: 0.0791
# Epoch 32/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0593 - val_loss: 0.0106 - val_mae: 0.0762
# Epoch 33/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0591 - val_loss: 0.0110 - val_mae: 0.0768
# Epoch 34/100
# 32/32 - 2s - 73ms/step - loss: 0.0056 - mae: 0.0590 - val_loss: 0.0114 - val_mae: 0.0798
# Epoch 35/100
# 32/32 - 2s - 73ms/step - loss: 0.0056 - mae: 0.0591 - val_loss: 0.0117 - val_mae: 0.0792
# Epoch 36/100
# 32/32 - 2s - 74ms/step - loss: 0.0057 - mae: 0.0596 - val_loss: 0.0114 - val_mae: 0.0786
# Epoch 37/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0586 - val_loss: 0.0119 - val_mae: 0.0817
# Epoch 38/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0587 - val_loss: 0.0114 - val_mae: 0.0796
# Run 2 - MSE: 0.010599, MAE: 0.079952
#
# ===== Run 3/10 =====
# Epoch 1/100
# 32/32 - 4s - 113ms/step - loss: 0.0242 - mae: 0.1177 - val_loss: 0.0196 - val_mae: 0.1111
# Epoch 2/100
# 32/32 - 2s - 74ms/step - loss: 0.0118 - mae: 0.0848 - val_loss: 0.0140 - val_mae: 0.0903
# Epoch 3/100
# 32/32 - 2s - 74ms/step - loss: 0.0108 - mae: 0.0812 - val_loss: 0.0130 - val_mae: 0.0881
# Epoch 4/100
# 32/32 - 2s - 74ms/step - loss: 0.0100 - mae: 0.0782 - val_loss: 0.0116 - val_mae: 0.0797
# Epoch 5/100
# 32/32 - 2s - 74ms/step - loss: 0.0095 - mae: 0.0760 - val_loss: 0.0121 - val_mae: 0.0848
# Epoch 6/100
# 32/32 - 2s - 73ms/step - loss: 0.0087 - mae: 0.0731 - val_loss: 0.0120 - val_mae: 0.0832
# Epoch 7/100
# 32/32 - 2s - 73ms/step - loss: 0.0090 - mae: 0.0738 - val_loss: 0.0122 - val_mae: 0.0835
# Epoch 8/100
# 32/32 - 2s - 73ms/step - loss: 0.0082 - mae: 0.0707 - val_loss: 0.0116 - val_mae: 0.0807
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0080 - mae: 0.0701 - val_loss: 0.0117 - val_mae: 0.0796
# Epoch 10/100
# 32/32 - 2s - 74ms/step - loss: 0.0077 - mae: 0.0688 - val_loss: 0.0109 - val_mae: 0.0788
# Epoch 11/100
# 32/32 - 2s - 74ms/step - loss: 0.0076 - mae: 0.0682 - val_loss: 0.0116 - val_mae: 0.0799
# Epoch 12/100
# 32/32 - 2s - 74ms/step - loss: 0.0075 - mae: 0.0676 - val_loss: 0.0105 - val_mae: 0.0771
# Epoch 13/100
# 32/32 - 2s - 74ms/step - loss: 0.0074 - mae: 0.0675 - val_loss: 0.0112 - val_mae: 0.0791
# Epoch 14/100
# 32/32 - 2s - 74ms/step - loss: 0.0073 - mae: 0.0667 - val_loss: 0.0111 - val_mae: 0.0757
# Epoch 15/100
# 32/32 - 2s - 74ms/step - loss: 0.0071 - mae: 0.0658 - val_loss: 0.0111 - val_mae: 0.0764
# Epoch 16/100
# 32/32 - 2s - 74ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0111 - val_mae: 0.0767
# Epoch 17/100
# 32/32 - 2s - 74ms/step - loss: 0.0070 - mae: 0.0652 - val_loss: 0.0124 - val_mae: 0.0810
# Epoch 18/100
# 32/32 - 2s - 75ms/step - loss: 0.0069 - mae: 0.0652 - val_loss: 0.0113 - val_mae: 0.0768
# Epoch 19/100
# 32/32 - 2s - 75ms/step - loss: 0.0067 - mae: 0.0639 - val_loss: 0.0111 - val_mae: 0.0759
# Epoch 20/100
# 32/32 - 2s - 74ms/step - loss: 0.0066 - mae: 0.0638 - val_loss: 0.0130 - val_mae: 0.0863
# Epoch 21/100
# 32/32 - 2s - 74ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0117 - val_mae: 0.0778
# Epoch 22/100
# 32/32 - 2s - 74ms/step - loss: 0.0065 - mae: 0.0633 - val_loss: 0.0111 - val_mae: 0.0755
# Epoch 23/100
# 32/32 - 2s - 74ms/step - loss: 0.0064 - mae: 0.0625 - val_loss: 0.0108 - val_mae: 0.0750
# Epoch 24/100
# 32/32 - 2s - 74ms/step - loss: 0.0063 - mae: 0.0625 - val_loss: 0.0112 - val_mae: 0.0774
# Epoch 25/100
# 32/32 - 2s - 75ms/step - loss: 0.0060 - mae: 0.0610 - val_loss: 0.0121 - val_mae: 0.0785
# Epoch 26/100
# 32/32 - 2s - 74ms/step - loss: 0.0059 - mae: 0.0604 - val_loss: 0.0114 - val_mae: 0.0762
# Epoch 27/100
# 32/32 - 2s - 74ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0112 - val_mae: 0.0759
# Epoch 28/100
# 32/32 - 2s - 74ms/step - loss: 0.0059 - mae: 0.0600 - val_loss: 0.0114 - val_mae: 0.0762
# Epoch 29/100
# 32/32 - 2s - 74ms/step - loss: 0.0057 - mae: 0.0595 - val_loss: 0.0121 - val_mae: 0.0782
# Epoch 30/100
# 32/32 - 2s - 74ms/step - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0124 - val_mae: 0.0793
# Epoch 31/100
# 32/32 - 2s - 74ms/step - loss: 0.0057 - mae: 0.0595 - val_loss: 0.0124 - val_mae: 0.0801
# Epoch 32/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0132 - val_mae: 0.0818
# Run 3 - MSE: 0.010549, MAE: 0.077127
#
# ===== Run 4/10 =====
# Epoch 1/100
# 32/32 - 4s - 113ms/step - loss: 0.0256 - mae: 0.1209 - val_loss: 0.0182 - val_mae: 0.1064
# Epoch 2/100
# 32/32 - 2s - 74ms/step - loss: 0.0120 - mae: 0.0853 - val_loss: 0.0141 - val_mae: 0.0910
# Epoch 3/100
# 32/32 - 2s - 74ms/step - loss: 0.0107 - mae: 0.0808 - val_loss: 0.0123 - val_mae: 0.0849
# Epoch 4/100
# 32/32 - 2s - 74ms/step - loss: 0.0100 - mae: 0.0783 - val_loss: 0.0151 - val_mae: 0.1010
# Epoch 5/100
# 32/32 - 2s - 75ms/step - loss: 0.0097 - mae: 0.0769 - val_loss: 0.0131 - val_mae: 0.0907
# Epoch 6/100
# 32/32 - 2s - 74ms/step - loss: 0.0088 - mae: 0.0737 - val_loss: 0.0155 - val_mae: 0.1022
# Epoch 7/100
# 32/32 - 2s - 74ms/step - loss: 0.0090 - mae: 0.0743 - val_loss: 0.0140 - val_mae: 0.0960
# Epoch 8/100
# 32/32 - 2s - 74ms/step - loss: 0.0084 - mae: 0.0720 - val_loss: 0.0134 - val_mae: 0.0948
# Epoch 9/100
# 32/32 - 2s - 74ms/step - loss: 0.0079 - mae: 0.0698 - val_loss: 0.0115 - val_mae: 0.0833
# Epoch 10/100
# 32/32 - 2s - 74ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0115 - val_mae: 0.0833
# Epoch 11/100
# 32/32 - 2s - 74ms/step - loss: 0.0076 - mae: 0.0685 - val_loss: 0.0111 - val_mae: 0.0824
# Epoch 12/100
# 32/32 - 2s - 74ms/step - loss: 0.0075 - mae: 0.0678 - val_loss: 0.0108 - val_mae: 0.0791
# Epoch 13/100
# 32/32 - 2s - 74ms/step - loss: 0.0074 - mae: 0.0673 - val_loss: 0.0108 - val_mae: 0.0782
# Epoch 14/100
# 32/32 - 2s - 74ms/step - loss: 0.0073 - mae: 0.0672 - val_loss: 0.0110 - val_mae: 0.0779
# Epoch 15/100
# 32/32 - 2s - 74ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0113 - val_mae: 0.0794
# Epoch 16/100
# 32/32 - 2s - 74ms/step - loss: 0.0073 - mae: 0.0667 - val_loss: 0.0111 - val_mae: 0.0791
# Epoch 17/100
# 32/32 - 2s - 74ms/step - loss: 0.0071 - mae: 0.0657 - val_loss: 0.0116 - val_mae: 0.0790
# Epoch 18/100
# 32/32 - 2s - 74ms/step - loss: 0.0070 - mae: 0.0657 - val_loss: 0.0107 - val_mae: 0.0760
# Epoch 19/100
# 32/32 - 2s - 73ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.0104 - val_mae: 0.0770
# Epoch 20/100
# 32/32 - 2s - 73ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0116 - val_mae: 0.0797
# Epoch 21/100
# 32/32 - 2s - 74ms/step - loss: 0.0067 - mae: 0.0639 - val_loss: 0.0105 - val_mae: 0.0760
# Epoch 22/100
# 32/32 - 2s - 74ms/step - loss: 0.0066 - mae: 0.0634 - val_loss: 0.0107 - val_mae: 0.0787
# Epoch 23/100
# 32/32 - 2s - 74ms/step - loss: 0.0067 - mae: 0.0642 - val_loss: 0.0103 - val_mae: 0.0746
# Epoch 24/100
# 32/32 - 2s - 74ms/step - loss: 0.0065 - mae: 0.0629 - val_loss: 0.0108 - val_mae: 0.0774
# Epoch 25/100
# 32/32 - 2s - 73ms/step - loss: 0.0064 - mae: 0.0628 - val_loss: 0.0106 - val_mae: 0.0774
# Epoch 26/100
# 32/32 - 2s - 73ms/step - loss: 0.0063 - mae: 0.0621 - val_loss: 0.0110 - val_mae: 0.0778
# Epoch 27/100
# 32/32 - 2s - 73ms/step - loss: 0.0062 - mae: 0.0620 - val_loss: 0.0110 - val_mae: 0.0789
# Epoch 28/100
# 32/32 - 2s - 74ms/step - loss: 0.0061 - mae: 0.0612 - val_loss: 0.0108 - val_mae: 0.0770
# Epoch 29/100
# 32/32 - 2s - 74ms/step - loss: 0.0060 - mae: 0.0607 - val_loss: 0.0109 - val_mae: 0.0777
# Epoch 30/100
# 32/32 - 2s - 74ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0111 - val_mae: 0.0785
# Epoch 31/100
# 32/32 - 2s - 73ms/step - loss: 0.0059 - mae: 0.0603 - val_loss: 0.0112 - val_mae: 0.0782
# Epoch 32/100
# 32/32 - 2s - 74ms/step - loss: 0.0057 - mae: 0.0595 - val_loss: 0.0118 - val_mae: 0.0805
# Epoch 33/100
# 32/32 - 2s - 74ms/step - loss: 0.0057 - mae: 0.0596 - val_loss: 0.0118 - val_mae: 0.0803
# Epoch 34/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0593 - val_loss: 0.0107 - val_mae: 0.0774
# Epoch 35/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0111 - val_mae: 0.0779
# Epoch 36/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0584 - val_loss: 0.0113 - val_mae: 0.0802
# Epoch 37/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0584 - val_loss: 0.0116 - val_mae: 0.0803
# Epoch 38/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0584 - val_loss: 0.0110 - val_mae: 0.0779
# Epoch 39/100
# 32/32 - 2s - 74ms/step - loss: 0.0054 - mae: 0.0580 - val_loss: 0.0126 - val_mae: 0.0841
# Epoch 40/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0587 - val_loss: 0.0109 - val_mae: 0.0776
# Epoch 41/100
# 32/32 - 2s - 73ms/step - loss: 0.0053 - mae: 0.0577 - val_loss: 0.0108 - val_mae: 0.0772
# Epoch 42/100
# 32/32 - 2s - 74ms/step - loss: 0.0052 - mae: 0.0571 - val_loss: 0.0111 - val_mae: 0.0775
# Epoch 43/100
# 32/32 - 2s - 73ms/step - loss: 0.0052 - mae: 0.0571 - val_loss: 0.0114 - val_mae: 0.0791
# Run 4 - MSE: 0.010273, MAE: 0.074622
#
# ===== Run 5/10 =====
# Epoch 1/100
# 32/32 - 4s - 112ms/step - loss: 0.0240 - mae: 0.1176 - val_loss: 0.0217 - val_mae: 0.1219
# Epoch 2/100
# 32/32 - 2s - 74ms/step - loss: 0.0121 - mae: 0.0856 - val_loss: 0.0144 - val_mae: 0.0926
# Epoch 3/100
# 32/32 - 2s - 75ms/step - loss: 0.0105 - mae: 0.0802 - val_loss: 0.0121 - val_mae: 0.0869
# Epoch 4/100
# 32/32 - 2s - 73ms/step - loss: 0.0097 - mae: 0.0772 - val_loss: 0.0148 - val_mae: 0.0985
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0090 - mae: 0.0744 - val_loss: 0.0114 - val_mae: 0.0828
# Epoch 6/100
# 32/32 - 2s - 75ms/step - loss: 0.0087 - mae: 0.0727 - val_loss: 0.0119 - val_mae: 0.0848
# Epoch 7/100
# 32/32 - 2s - 72ms/step - loss: 0.0082 - mae: 0.0709 - val_loss: 0.0115 - val_mae: 0.0836
# Epoch 8/100
# 32/32 - 2s - 73ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0121 - val_mae: 0.0874
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0109 - val_mae: 0.0816
# Epoch 10/100
# 32/32 - 2s - 73ms/step - loss: 0.0078 - mae: 0.0691 - val_loss: 0.0114 - val_mae: 0.0817
# Epoch 11/100
# 32/32 - 2s - 73ms/step - loss: 0.0076 - mae: 0.0684 - val_loss: 0.0110 - val_mae: 0.0811
# Epoch 12/100
# 32/32 - 2s - 72ms/step - loss: 0.0074 - mae: 0.0675 - val_loss: 0.0108 - val_mae: 0.0811
# Epoch 13/100
# 32/32 - 2s - 75ms/step - loss: 0.0072 - mae: 0.0666 - val_loss: 0.0105 - val_mae: 0.0780
# Epoch 14/100
# 32/32 - 2s - 74ms/step - loss: 0.0072 - mae: 0.0662 - val_loss: 0.0108 - val_mae: 0.0805
# Epoch 15/100
# 32/32 - 2s - 73ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0108 - val_mae: 0.0803
# Epoch 16/100
# 32/32 - 2s - 76ms/step - loss: 0.0071 - mae: 0.0659 - val_loss: 0.0105 - val_mae: 0.0795
# Epoch 17/100
# 32/32 - 4s - 110ms/step - loss: 0.0070 - mae: 0.0654 - val_loss: 0.0105 - val_mae: 0.0780
# Epoch 18/100
# 32/32 - 3s - 103ms/step - loss: 0.0070 - mae: 0.0654 - val_loss: 0.0106 - val_mae: 0.0785
# Epoch 19/100
# 32/32 - 3s - 96ms/step - loss: 0.0068 - mae: 0.0644 - val_loss: 0.0110 - val_mae: 0.0788
# Epoch 20/100
# 32/32 - 3s - 96ms/step - loss: 0.0067 - mae: 0.0638 - val_loss: 0.0108 - val_mae: 0.0768
# Epoch 21/100
# 32/32 - 3s - 100ms/step - loss: 0.0066 - mae: 0.0636 - val_loss: 0.0110 - val_mae: 0.0810
# Epoch 22/100
# 32/32 - 3s - 98ms/step - loss: 0.0066 - mae: 0.0635 - val_loss: 0.0110 - val_mae: 0.0819
# Epoch 23/100
# 32/32 - 3s - 98ms/step - loss: 0.0065 - mae: 0.0630 - val_loss: 0.0105 - val_mae: 0.0784
# Epoch 24/100
# 32/32 - 3s - 97ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0107 - val_mae: 0.0783
# Epoch 25/100
# 32/32 - 3s - 99ms/step - loss: 0.0064 - mae: 0.0630 - val_loss: 0.0105 - val_mae: 0.0771
# Epoch 26/100
# 32/32 - 3s - 100ms/step - loss: 0.0062 - mae: 0.0616 - val_loss: 0.0108 - val_mae: 0.0798
# Epoch 27/100
# 32/32 - 3s - 102ms/step - loss: 0.0062 - mae: 0.0619 - val_loss: 0.0117 - val_mae: 0.0825
# Epoch 28/100
# 32/32 - 3s - 104ms/step - loss: 0.0061 - mae: 0.0615 - val_loss: 0.0107 - val_mae: 0.0783
# Epoch 29/100
# 32/32 - 3s - 106ms/step - loss: 0.0059 - mae: 0.0603 - val_loss: 0.0111 - val_mae: 0.0792
# Epoch 30/100
# 32/32 - 3s - 107ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0109 - val_mae: 0.0794
# Epoch 31/100
# 32/32 - 3s - 86ms/step - loss: 0.0058 - mae: 0.0601 - val_loss: 0.0109 - val_mae: 0.0779
# Epoch 32/100
# 32/32 - 2s - 73ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0106 - val_mae: 0.0769
# Epoch 33/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0110 - val_mae: 0.0786
# Run 5 - MSE: 0.010460, MAE: 0.078023
#
# ===== Run 6/10 =====
# Epoch 1/100
# 32/32 - 4s - 112ms/step - loss: 0.0238 - mae: 0.1178 - val_loss: 0.0172 - val_mae: 0.1022
# Epoch 2/100
# 32/32 - 2s - 73ms/step - loss: 0.0126 - mae: 0.0875 - val_loss: 0.0131 - val_mae: 0.0839
# Epoch 3/100
# 32/32 - 2s - 74ms/step - loss: 0.0115 - mae: 0.0836 - val_loss: 0.0145 - val_mae: 0.0933
# Epoch 4/100
# 32/32 - 2s - 73ms/step - loss: 0.0103 - mae: 0.0793 - val_loss: 0.0120 - val_mae: 0.0857
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0095 - mae: 0.0763 - val_loss: 0.0141 - val_mae: 0.0960
# Epoch 6/100
# 32/32 - 2s - 73ms/step - loss: 0.0094 - mae: 0.0758 - val_loss: 0.0141 - val_mae: 0.0873
# Epoch 7/100
# 32/32 - 2s - 73ms/step - loss: 0.0096 - mae: 0.0768 - val_loss: 0.0133 - val_mae: 0.0909
# Epoch 8/100
# 32/32 - 2s - 73ms/step - loss: 0.0087 - mae: 0.0732 - val_loss: 0.0123 - val_mae: 0.0879
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0085 - mae: 0.0721 - val_loss: 0.0117 - val_mae: 0.0835
# Epoch 10/100
# 32/32 - 2s - 72ms/step - loss: 0.0080 - mae: 0.0704 - val_loss: 0.0113 - val_mae: 0.0839
# Epoch 11/100
# 32/32 - 2s - 72ms/step - loss: 0.0077 - mae: 0.0690 - val_loss: 0.0111 - val_mae: 0.0800
# Epoch 12/100
# 32/32 - 2s - 73ms/step - loss: 0.0077 - mae: 0.0688 - val_loss: 0.0106 - val_mae: 0.0798
# Epoch 13/100
# 32/32 - 2s - 72ms/step - loss: 0.0077 - mae: 0.0686 - val_loss: 0.0116 - val_mae: 0.0802
# Epoch 14/100
# 32/32 - 2s - 72ms/step - loss: 0.0074 - mae: 0.0678 - val_loss: 0.0109 - val_mae: 0.0790
# Epoch 15/100
# 32/32 - 2s - 73ms/step - loss: 0.0072 - mae: 0.0664 - val_loss: 0.0111 - val_mae: 0.0783
# Epoch 16/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0660 - val_loss: 0.0106 - val_mae: 0.0772
# Epoch 17/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0661 - val_loss: 0.0105 - val_mae: 0.0775
# Epoch 18/100
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0656 - val_loss: 0.0103 - val_mae: 0.0760
# Epoch 19/100
# 32/32 - 2s - 72ms/step - loss: 0.0069 - mae: 0.0650 - val_loss: 0.0112 - val_mae: 0.0799
# Epoch 20/100
# 32/32 - 2s - 72ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0106 - val_mae: 0.0779
# Epoch 21/100
# 32/32 - 2s - 72ms/step - loss: 0.0067 - mae: 0.0639 - val_loss: 0.0111 - val_mae: 0.0768
# Epoch 22/100
# 32/32 - 2s - 72ms/step - loss: 0.0066 - mae: 0.0636 - val_loss: 0.0103 - val_mae: 0.0763
# Epoch 23/100
# 32/32 - 2s - 73ms/step - loss: 0.0066 - mae: 0.0635 - val_loss: 0.0104 - val_mae: 0.0755
# Epoch 24/100
# 32/32 - 2s - 72ms/step - loss: 0.0066 - mae: 0.0634 - val_loss: 0.0106 - val_mae: 0.0768
# Epoch 25/100
# 32/32 - 2s - 72ms/step - loss: 0.0065 - mae: 0.0629 - val_loss: 0.0106 - val_mae: 0.0766
# Epoch 26/100
# 32/32 - 2s - 72ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0116 - val_mae: 0.0823
# Epoch 27/100
# 32/32 - 2s - 72ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0115 - val_mae: 0.0806
# Epoch 28/100
# 32/32 - 2s - 72ms/step - loss: 0.0063 - mae: 0.0622 - val_loss: 0.0103 - val_mae: 0.0761
# Epoch 29/100
# 32/32 - 2s - 73ms/step - loss: 0.0061 - mae: 0.0615 - val_loss: 0.0102 - val_mae: 0.0747
# Epoch 30/100
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0609 - val_loss: 0.0099 - val_mae: 0.0727
# Epoch 31/100
# 32/32 - 2s - 73ms/step - loss: 0.0059 - mae: 0.0604 - val_loss: 0.0111 - val_mae: 0.0773
# Epoch 32/100
# 32/32 - 2s - 73ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0105 - val_mae: 0.0759
# Epoch 33/100
# 32/32 - 2s - 73ms/step - loss: 0.0059 - mae: 0.0604 - val_loss: 0.0105 - val_mae: 0.0766
# Epoch 34/100
# 32/32 - 2s - 73ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0106 - val_mae: 0.0760
# Epoch 35/100
# 32/32 - 2s - 72ms/step - loss: 0.0057 - mae: 0.0592 - val_loss: 0.0102 - val_mae: 0.0753
# Epoch 36/100
# 32/32 - 2s - 72ms/step - loss: 0.0057 - mae: 0.0592 - val_loss: 0.0105 - val_mae: 0.0760
# Epoch 37/100
# 32/32 - 2s - 72ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0112 - val_mae: 0.0780
# Epoch 38/100
# 32/32 - 2s - 73ms/step - loss: 0.0056 - mae: 0.0589 - val_loss: 0.0104 - val_mae: 0.0735
# Epoch 39/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0593 - val_loss: 0.0109 - val_mae: 0.0762
# Epoch 40/100
# 32/32 - 2s - 72ms/step - loss: 0.0055 - mae: 0.0587 - val_loss: 0.0114 - val_mae: 0.0776
# Epoch 41/100
# 32/32 - 2s - 73ms/step - loss: 0.0054 - mae: 0.0577 - val_loss: 0.0112 - val_mae: 0.0769
# Epoch 42/100
# 32/32 - 2s - 73ms/step - loss: 0.0053 - mae: 0.0575 - val_loss: 0.0108 - val_mae: 0.0755
# Epoch 43/100
# 32/32 - 2s - 72ms/step - loss: 0.0053 - mae: 0.0574 - val_loss: 0.0108 - val_mae: 0.0768
# Epoch 44/100
# 32/32 - 2s - 73ms/step - loss: 0.0054 - mae: 0.0582 - val_loss: 0.0113 - val_mae: 0.0789
# Epoch 45/100
# 32/32 - 2s - 73ms/step - loss: 0.0053 - mae: 0.0573 - val_loss: 0.0104 - val_mae: 0.0745
# Epoch 46/100
# 32/32 - 2s - 72ms/step - loss: 0.0052 - mae: 0.0568 - val_loss: 0.0114 - val_mae: 0.0784
# Epoch 47/100
# 32/32 - 2s - 73ms/step - loss: 0.0051 - mae: 0.0561 - val_loss: 0.0109 - val_mae: 0.0753
# Epoch 48/100
# 32/32 - 2s - 73ms/step - loss: 0.0051 - mae: 0.0566 - val_loss: 0.0119 - val_mae: 0.0803
# Epoch 49/100
# 32/32 - 2s - 73ms/step - loss: 0.0051 - mae: 0.0560 - val_loss: 0.0106 - val_mae: 0.0749
# Epoch 50/100
# 32/32 - 2s - 73ms/step - loss: 0.0050 - mae: 0.0557 - val_loss: 0.0101 - val_mae: 0.0732
# Run 6 - MSE: 0.009863, MAE: 0.072715
#
# ===== Run 7/10 =====
# Epoch 1/100
# 32/32 - 4s - 113ms/step - loss: 0.0227 - mae: 0.1138 - val_loss: 0.0138 - val_mae: 0.0854
# Epoch 2/100
# 32/32 - 2s - 73ms/step - loss: 0.0121 - mae: 0.0857 - val_loss: 0.0138 - val_mae: 0.0888
# Epoch 3/100
# 32/32 - 2s - 73ms/step - loss: 0.0109 - mae: 0.0811 - val_loss: 0.0126 - val_mae: 0.0846
# Epoch 4/100
# 32/32 - 2s - 73ms/step - loss: 0.0098 - mae: 0.0774 - val_loss: 0.0159 - val_mae: 0.1043
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0091 - mae: 0.0748 - val_loss: 0.0112 - val_mae: 0.0800
# Epoch 6/100
# 32/32 - 2s - 73ms/step - loss: 0.0089 - mae: 0.0739 - val_loss: 0.0119 - val_mae: 0.0860
# Epoch 7/100
# 32/32 - 2s - 73ms/step - loss: 0.0083 - mae: 0.0714 - val_loss: 0.0115 - val_mae: 0.0831
# Epoch 8/100
# 32/32 - 2s - 73ms/step - loss: 0.0081 - mae: 0.0705 - val_loss: 0.0108 - val_mae: 0.0786
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0078 - mae: 0.0692 - val_loss: 0.0118 - val_mae: 0.0855
# Epoch 10/100
# 32/32 - 2s - 73ms/step - loss: 0.0079 - mae: 0.0698 - val_loss: 0.0104 - val_mae: 0.0768
# Epoch 11/100
# 32/32 - 2s - 73ms/step - loss: 0.0076 - mae: 0.0687 - val_loss: 0.0114 - val_mae: 0.0826
# Epoch 12/100
# 32/32 - 2s - 73ms/step - loss: 0.0077 - mae: 0.0688 - val_loss: 0.0112 - val_mae: 0.0795
# Epoch 13/100
# 32/32 - 2s - 73ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0104 - val_mae: 0.0762
# Epoch 14/100
# 32/32 - 2s - 74ms/step - loss: 0.0072 - mae: 0.0664 - val_loss: 0.0104 - val_mae: 0.0751
# Epoch 15/100
# 32/32 - 2s - 73ms/step - loss: 0.0072 - mae: 0.0663 - val_loss: 0.0107 - val_mae: 0.0776
# Epoch 16/100
# 32/32 - 2s - 73ms/step - loss: 0.0070 - mae: 0.0656 - val_loss: 0.0108 - val_mae: 0.0770
# Epoch 17/100
# 32/32 - 2s - 73ms/step - loss: 0.0069 - mae: 0.0648 - val_loss: 0.0105 - val_mae: 0.0759
# Epoch 18/100
# 32/32 - 2s - 73ms/step - loss: 0.0068 - mae: 0.0645 - val_loss: 0.0105 - val_mae: 0.0744
# Epoch 19/100
# 32/32 - 2s - 73ms/step - loss: 0.0067 - mae: 0.0640 - val_loss: 0.0104 - val_mae: 0.0749
# Epoch 20/100
# 32/32 - 2s - 73ms/step - loss: 0.0068 - mae: 0.0643 - val_loss: 0.0103 - val_mae: 0.0771
# Epoch 21/100
# 32/32 - 2s - 74ms/step - loss: 0.0067 - mae: 0.0640 - val_loss: 0.0103 - val_mae: 0.0749
# Epoch 22/100
# 32/32 - 2s - 73ms/step - loss: 0.0066 - mae: 0.0633 - val_loss: 0.0102 - val_mae: 0.0742
# Epoch 23/100
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0103 - val_mae: 0.0744
# Epoch 24/100
# 32/32 - 2s - 73ms/step - loss: 0.0064 - mae: 0.0628 - val_loss: 0.0109 - val_mae: 0.0769
# Epoch 25/100
# 32/32 - 2s - 73ms/step - loss: 0.0064 - mae: 0.0625 - val_loss: 0.0105 - val_mae: 0.0744
# Epoch 26/100
# 32/32 - 2s - 74ms/step - loss: 0.0064 - mae: 0.0630 - val_loss: 0.0116 - val_mae: 0.0805
# Epoch 27/100
# 32/32 - 2s - 73ms/step - loss: 0.0064 - mae: 0.0631 - val_loss: 0.0108 - val_mae: 0.0783
# Epoch 28/100
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0611 - val_loss: 0.0108 - val_mae: 0.0752
# Epoch 29/100
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0606 - val_loss: 0.0109 - val_mae: 0.0776
# Epoch 30/100
# 32/32 - 2s - 74ms/step - loss: 0.0060 - mae: 0.0608 - val_loss: 0.0111 - val_mae: 0.0773
# Epoch 31/100
# 32/32 - 2s - 73ms/step - loss: 0.0059 - mae: 0.0601 - val_loss: 0.0127 - val_mae: 0.0844
# Epoch 32/100
# 32/32 - 2s - 75ms/step - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0105 - val_mae: 0.0747
# Epoch 33/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0591 - val_loss: 0.0113 - val_mae: 0.0785
# Epoch 34/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0588 - val_loss: 0.0105 - val_mae: 0.0751
# Epoch 35/100
# 32/32 - 2s - 73ms/step - loss: 0.0056 - mae: 0.0588 - val_loss: 0.0118 - val_mae: 0.0791
# Epoch 36/100
# 32/32 - 2s - 74ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0112 - val_mae: 0.0767
# Epoch 37/100
# 32/32 - 2s - 74ms/step - loss: 0.0054 - mae: 0.0578 - val_loss: 0.0105 - val_mae: 0.0756
# Epoch 38/100
# 32/32 - 2s - 74ms/step - loss: 0.0054 - mae: 0.0578 - val_loss: 0.0102 - val_mae: 0.0726
# Epoch 39/100
# 32/32 - 2s - 74ms/step - loss: 0.0053 - mae: 0.0574 - val_loss: 0.0106 - val_mae: 0.0752
# Epoch 40/100
# 32/32 - 2s - 74ms/step - loss: 0.0053 - mae: 0.0573 - val_loss: 0.0107 - val_mae: 0.0741
# Epoch 41/100
# 32/32 - 2s - 74ms/step - loss: 0.0052 - mae: 0.0571 - val_loss: 0.0104 - val_mae: 0.0743
# Epoch 42/100
# 32/32 - 2s - 74ms/step - loss: 0.0052 - mae: 0.0569 - val_loss: 0.0116 - val_mae: 0.0789
# Run 7 - MSE: 0.010211, MAE: 0.074207
#
# ===== Run 8/10 =====
# Epoch 1/100
# 32/32 - 4s - 114ms/step - loss: 0.0246 - mae: 0.1186 - val_loss: 0.0160 - val_mae: 0.0964
# Epoch 2/100
# 32/32 - 2s - 75ms/step - loss: 0.0120 - mae: 0.0852 - val_loss: 0.0149 - val_mae: 0.0937
# Epoch 3/100
# 32/32 - 2s - 74ms/step - loss: 0.0108 - mae: 0.0810 - val_loss: 0.0130 - val_mae: 0.0883
# Epoch 4/100
# 32/32 - 2s - 74ms/step - loss: 0.0099 - mae: 0.0777 - val_loss: 0.0126 - val_mae: 0.0899
# Epoch 5/100
# 32/32 - 2s - 74ms/step - loss: 0.0093 - mae: 0.0753 - val_loss: 0.0120 - val_mae: 0.0871
# Epoch 6/100
# 32/32 - 2s - 74ms/step - loss: 0.0088 - mae: 0.0737 - val_loss: 0.0137 - val_mae: 0.0956
# Epoch 7/100
# 32/32 - 2s - 74ms/step - loss: 0.0085 - mae: 0.0722 - val_loss: 0.0126 - val_mae: 0.0871
# Epoch 8/100
# 32/32 - 2s - 74ms/step - loss: 0.0083 - mae: 0.0712 - val_loss: 0.0117 - val_mae: 0.0829
# Epoch 9/100
# 32/32 - 2s - 74ms/step - loss: 0.0079 - mae: 0.0694 - val_loss: 0.0116 - val_mae: 0.0841
# Epoch 10/100
# 32/32 - 2s - 74ms/step - loss: 0.0076 - mae: 0.0687 - val_loss: 0.0119 - val_mae: 0.0846
# Epoch 11/100
# 32/32 - 2s - 74ms/step - loss: 0.0078 - mae: 0.0690 - val_loss: 0.0112 - val_mae: 0.0797
# Epoch 12/100
# 32/32 - 2s - 74ms/step - loss: 0.0075 - mae: 0.0678 - val_loss: 0.0108 - val_mae: 0.0771
# Epoch 13/100
# 32/32 - 2s - 74ms/step - loss: 0.0074 - mae: 0.0673 - val_loss: 0.0103 - val_mae: 0.0767
# Epoch 14/100
# 32/32 - 2s - 74ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0103 - val_mae: 0.0756
# Epoch 15/100
# 32/32 - 2s - 74ms/step - loss: 0.0072 - mae: 0.0665 - val_loss: 0.0104 - val_mae: 0.0764
# Epoch 16/100
# 32/32 - 2s - 75ms/step - loss: 0.0070 - mae: 0.0654 - val_loss: 0.0101 - val_mae: 0.0738
# Epoch 17/100
# 32/32 - 2s - 75ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0100 - val_mae: 0.0743
# Epoch 18/100
# 32/32 - 2s - 75ms/step - loss: 0.0069 - mae: 0.0649 - val_loss: 0.0101 - val_mae: 0.0745
# Epoch 19/100
# 32/32 - 2s - 74ms/step - loss: 0.0067 - mae: 0.0641 - val_loss: 0.0108 - val_mae: 0.0758
# Epoch 20/100
# 32/32 - 2s - 74ms/step - loss: 0.0067 - mae: 0.0642 - val_loss: 0.0101 - val_mae: 0.0745
# Epoch 21/100
# 32/32 - 2s - 75ms/step - loss: 0.0066 - mae: 0.0637 - val_loss: 0.0107 - val_mae: 0.0757
# Epoch 22/100
# 32/32 - 2s - 75ms/step - loss: 0.0067 - mae: 0.0641 - val_loss: 0.0110 - val_mae: 0.0774
# Epoch 23/100
# 32/32 - 2s - 75ms/step - loss: 0.0065 - mae: 0.0633 - val_loss: 0.0105 - val_mae: 0.0760
# Epoch 24/100
# 32/32 - 2s - 75ms/step - loss: 0.0064 - mae: 0.0626 - val_loss: 0.0108 - val_mae: 0.0759
# Epoch 25/100
# 32/32 - 2s - 75ms/step - loss: 0.0064 - mae: 0.0624 - val_loss: 0.0102 - val_mae: 0.0745
# Epoch 26/100
# 32/32 - 2s - 75ms/step - loss: 0.0063 - mae: 0.0622 - val_loss: 0.0105 - val_mae: 0.0767
# Epoch 27/100
# 32/32 - 2s - 74ms/step - loss: 0.0064 - mae: 0.0625 - val_loss: 0.0115 - val_mae: 0.0796
# Epoch 28/100
# 32/32 - 2s - 74ms/step - loss: 0.0062 - mae: 0.0619 - val_loss: 0.0105 - val_mae: 0.0768
# Epoch 29/100
# 32/32 - 2s - 74ms/step - loss: 0.0061 - mae: 0.0616 - val_loss: 0.0110 - val_mae: 0.0780
# Epoch 30/100
# 32/32 - 2s - 74ms/step - loss: 0.0060 - mae: 0.0606 - val_loss: 0.0106 - val_mae: 0.0756
# Epoch 31/100
# 32/32 - 2s - 74ms/step - loss: 0.0060 - mae: 0.0607 - val_loss: 0.0114 - val_mae: 0.0796
# Epoch 32/100
# 32/32 - 2s - 74ms/step - loss: 0.0059 - mae: 0.0605 - val_loss: 0.0108 - val_mae: 0.0769
# Epoch 33/100
# 32/32 - 2s - 74ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0116 - val_mae: 0.0803
# Epoch 34/100
# 32/32 - 2s - 74ms/step - loss: 0.0057 - mae: 0.0593 - val_loss: 0.0126 - val_mae: 0.0838
# Epoch 35/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0590 - val_loss: 0.0116 - val_mae: 0.0790
# Epoch 36/100
# 32/32 - 2s - 74ms/step - loss: 0.0056 - mae: 0.0587 - val_loss: 0.0110 - val_mae: 0.0774
# Epoch 37/100
# 32/32 - 2s - 74ms/step - loss: 0.0054 - mae: 0.0580 - val_loss: 0.0113 - val_mae: 0.0788
# Run 8 - MSE: 0.010043, MAE: 0.074265
#
# ===== Run 9/10 =====
# Epoch 1/100
# 32/32 - 4s - 113ms/step - loss: 0.0226 - mae: 0.1142 - val_loss: 0.0168 - val_mae: 0.1008
# Epoch 2/100
# 32/32 - 2s - 73ms/step - loss: 0.0114 - mae: 0.0833 - val_loss: 0.0125 - val_mae: 0.0828
# Epoch 3/100
# 32/32 - 2s - 73ms/step - loss: 0.0107 - mae: 0.0806 - val_loss: 0.0131 - val_mae: 0.0870
# Epoch 4/100
# 32/32 - 2s - 72ms/step - loss: 0.0098 - mae: 0.0777 - val_loss: 0.0135 - val_mae: 0.0931
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0090 - mae: 0.0744 - val_loss: 0.0137 - val_mae: 0.0953
# Epoch 6/100
# 32/32 - 2s - 72ms/step - loss: 0.0087 - mae: 0.0728 - val_loss: 0.0128 - val_mae: 0.0879
# Epoch 7/100
# 32/32 - 2s - 72ms/step - loss: 0.0081 - mae: 0.0703 - val_loss: 0.0136 - val_mae: 0.0943
# Epoch 8/100
# 32/32 - 2s - 72ms/step - loss: 0.0079 - mae: 0.0697 - val_loss: 0.0117 - val_mae: 0.0839
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0079 - mae: 0.0695 - val_loss: 0.0115 - val_mae: 0.0849
# Epoch 10/100
# 32/32 - 2s - 73ms/step - loss: 0.0077 - mae: 0.0686 - val_loss: 0.0125 - val_mae: 0.0904
# Epoch 11/100
# 32/32 - 2s - 73ms/step - loss: 0.0075 - mae: 0.0678 - val_loss: 0.0118 - val_mae: 0.0848
# Epoch 12/100
# 32/32 - 2s - 72ms/step - loss: 0.0073 - mae: 0.0670 - val_loss: 0.0122 - val_mae: 0.0880
# Epoch 13/100
# 32/32 - 2s - 73ms/step - loss: 0.0072 - mae: 0.0662 - val_loss: 0.0119 - val_mae: 0.0860
# Epoch 14/100
# 32/32 - 2s - 73ms/step - loss: 0.0071 - mae: 0.0660 - val_loss: 0.0105 - val_mae: 0.0793
# Epoch 15/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0662 - val_loss: 0.0122 - val_mae: 0.0856
# Epoch 16/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0660 - val_loss: 0.0105 - val_mae: 0.0788
# Epoch 17/100
# 32/32 - 2s - 73ms/step - loss: 0.0070 - mae: 0.0652 - val_loss: 0.0109 - val_mae: 0.0782
# Epoch 18/100
# 32/32 - 2s - 73ms/step - loss: 0.0069 - mae: 0.0649 - val_loss: 0.0110 - val_mae: 0.0784
# Epoch 19/100
# 32/32 - 2s - 73ms/step - loss: 0.0068 - mae: 0.0648 - val_loss: 0.0103 - val_mae: 0.0771
# Epoch 20/100
# 32/32 - 2s - 73ms/step - loss: 0.0068 - mae: 0.0644 - val_loss: 0.0107 - val_mae: 0.0772
# Epoch 21/100
# 32/32 - 2s - 73ms/step - loss: 0.0066 - mae: 0.0637 - val_loss: 0.0108 - val_mae: 0.0771
# Epoch 22/100
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0118 - val_mae: 0.0817
# Epoch 23/100
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0629 - val_loss: 0.0117 - val_mae: 0.0815
# Epoch 24/100
# 32/32 - 2s - 73ms/step - loss: 0.0065 - mae: 0.0632 - val_loss: 0.0113 - val_mae: 0.0795
# Epoch 25/100
# 32/32 - 2s - 73ms/step - loss: 0.0066 - mae: 0.0635 - val_loss: 0.0107 - val_mae: 0.0765
# Epoch 26/100
# 32/32 - 2s - 75ms/step - loss: 0.0064 - mae: 0.0627 - val_loss: 0.0114 - val_mae: 0.0783
# Epoch 27/100
# 32/32 - 2s - 73ms/step - loss: 0.0062 - mae: 0.0617 - val_loss: 0.0124 - val_mae: 0.0851
# Epoch 28/100
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0610 - val_loss: 0.0124 - val_mae: 0.0856
# Epoch 29/100
# 32/32 - 2s - 73ms/step - loss: 0.0060 - mae: 0.0607 - val_loss: 0.0113 - val_mae: 0.0798
# Epoch 30/100
# 32/32 - 2s - 73ms/step - loss: 0.0058 - mae: 0.0600 - val_loss: 0.0110 - val_mae: 0.0770
# Epoch 31/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0595 - val_loss: 0.0113 - val_mae: 0.0812
# Epoch 32/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0594 - val_loss: 0.0117 - val_mae: 0.0801
# Epoch 33/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0592 - val_loss: 0.0111 - val_mae: 0.0790
# Epoch 34/100
# 32/32 - 2s - 73ms/step - loss: 0.0057 - mae: 0.0593 - val_loss: 0.0114 - val_mae: 0.0793
# Epoch 35/100
# 32/32 - 2s - 72ms/step - loss: 0.0056 - mae: 0.0590 - val_loss: 0.0117 - val_mae: 0.0804
# Epoch 36/100
# 32/32 - 2s - 73ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0116 - val_mae: 0.0796
# Epoch 37/100
# 32/32 - 2s - 72ms/step - loss: 0.0055 - mae: 0.0583 - val_loss: 0.0123 - val_mae: 0.0833
# Epoch 38/100
# 32/32 - 2s - 72ms/step - loss: 0.0055 - mae: 0.0581 - val_loss: 0.0119 - val_mae: 0.0793
# Epoch 39/100
# 32/32 - 2s - 72ms/step - loss: 0.0054 - mae: 0.0578 - val_loss: 0.0110 - val_mae: 0.0773
# Run 9 - MSE: 0.010317, MAE: 0.077065
#
# ===== Run 10/10 =====
# Epoch 1/100
# 32/32 - 4s - 112ms/step - loss: 0.0235 - mae: 0.1168 - val_loss: 0.0156 - val_mae: 0.0947
# Epoch 2/100
# 32/32 - 2s - 73ms/step - loss: 0.0120 - mae: 0.0856 - val_loss: 0.0135 - val_mae: 0.0892
# Epoch 3/100
# 32/32 - 2s - 73ms/step - loss: 0.0108 - mae: 0.0812 - val_loss: 0.0130 - val_mae: 0.0881
# Epoch 4/100
# 32/32 - 2s - 72ms/step - loss: 0.0097 - mae: 0.0769 - val_loss: 0.0123 - val_mae: 0.0884
# Epoch 5/100
# 32/32 - 2s - 73ms/step - loss: 0.0090 - mae: 0.0744 - val_loss: 0.0120 - val_mae: 0.0857
# Epoch 6/100
# 32/32 - 2s - 73ms/step - loss: 0.0087 - mae: 0.0731 - val_loss: 0.0121 - val_mae: 0.0870
# Epoch 7/100
# 32/32 - 2s - 73ms/step - loss: 0.0083 - mae: 0.0710 - val_loss: 0.0124 - val_mae: 0.0865
# Epoch 8/100
# 32/32 - 2s - 73ms/step - loss: 0.0080 - mae: 0.0702 - val_loss: 0.0130 - val_mae: 0.0889
# Epoch 9/100
# 32/32 - 2s - 73ms/step - loss: 0.0078 - mae: 0.0693 - val_loss: 0.0115 - val_mae: 0.0825
# Epoch 10/100
# 32/32 - 2s - 73ms/step - loss: 0.0076 - mae: 0.0685 - val_loss: 0.0131 - val_mae: 0.0889
# Epoch 11/100
# 32/32 - 2s - 73ms/step - loss: 0.0076 - mae: 0.0686 - val_loss: 0.0109 - val_mae: 0.0801
# Epoch 12/100
# 32/32 - 2s - 72ms/step - loss: 0.0074 - mae: 0.0677 - val_loss: 0.0114 - val_mae: 0.0827
# Epoch 13/100
# 32/32 - 2s - 72ms/step - loss: 0.0073 - mae: 0.0666 - val_loss: 0.0118 - val_mae: 0.0838
# Epoch 14/100
# 32/32 - 2s - 72ms/step - loss: 0.0072 - mae: 0.0663 - val_loss: 0.0115 - val_mae: 0.0839
# Epoch 15/100
# 32/32 - 2s - 72ms/step - loss: 0.0071 - mae: 0.0660 - val_loss: 0.0108 - val_mae: 0.0784
# Epoch 16/100
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0130 - val_mae: 0.0889
# Epoch 17/100
# 32/32 - 2s - 72ms/step - loss: 0.0070 - mae: 0.0653 - val_loss: 0.0122 - val_mae: 0.0830
# Epoch 18/100
# 32/32 - 2s - 74ms/step - loss: 0.0070 - mae: 0.0655 - val_loss: 0.0104 - val_mae: 0.0780
# Epoch 19/100
# 32/32 - 3s - 107ms/step - loss: 0.0068 - mae: 0.0644 - val_loss: 0.0125 - val_mae: 0.0852
# Epoch 20/100
# 32/32 - 3s - 100ms/step - loss: 0.0067 - mae: 0.0642 - val_loss: 0.0107 - val_mae: 0.0789
# Epoch 21/100
# 32/32 - 3s - 95ms/step - loss: 0.0066 - mae: 0.0638 - val_loss: 0.0105 - val_mae: 0.0774
# Epoch 22/100
# 32/32 - 3s - 99ms/step - loss: 0.0066 - mae: 0.0637 - val_loss: 0.0109 - val_mae: 0.0810
# Epoch 23/100
# 32/32 - 3s - 98ms/step - loss: 0.0065 - mae: 0.0631 - val_loss: 0.0116 - val_mae: 0.0817
# Epoch 24/100
# 32/32 - 3s - 105ms/step - loss: 0.0064 - mae: 0.0627 - val_loss: 0.0106 - val_mae: 0.0785
# Epoch 25/100
# 32/32 - 3s - 98ms/step - loss: 0.0063 - mae: 0.0626 - val_loss: 0.0105 - val_mae: 0.0769
# Epoch 26/100
# 32/32 - 3s - 98ms/step - loss: 0.0062 - mae: 0.0620 - val_loss: 0.0112 - val_mae: 0.0779
# Epoch 27/100
# 32/32 - 3s - 96ms/step - loss: 0.0060 - mae: 0.0611 - val_loss: 0.0111 - val_mae: 0.0779
# Epoch 28/100
# 32/32 - 3s - 98ms/step - loss: 0.0060 - mae: 0.0609 - val_loss: 0.0122 - val_mae: 0.0826
# Epoch 29/100
# 32/32 - 3s - 98ms/step - loss: 0.0059 - mae: 0.0602 - val_loss: 0.0118 - val_mae: 0.0804
# Epoch 30/100
# 32/32 - 3s - 96ms/step - loss: 0.0058 - mae: 0.0597 - val_loss: 0.0113 - val_mae: 0.0781
# Epoch 31/100
# 32/32 - 3s - 98ms/step - loss: 0.0057 - mae: 0.0595 - val_loss: 0.0110 - val_mae: 0.0793
# Epoch 32/100
# 32/32 - 3s - 100ms/step - loss: 0.0057 - mae: 0.0592 - val_loss: 0.0117 - val_mae: 0.0796
# Epoch 33/100
# 32/32 - 3s - 101ms/step - loss: 0.0057 - mae: 0.0592 - val_loss: 0.0117 - val_mae: 0.0823
# Epoch 34/100
# 32/32 - 3s - 97ms/step - loss: 0.0056 - mae: 0.0588 - val_loss: 0.0106 - val_mae: 0.0771
# Epoch 35/100
# 32/32 - 3s - 98ms/step - loss: 0.0055 - mae: 0.0585 - val_loss: 0.0116 - val_mae: 0.0801
# Epoch 36/100
# 32/32 - 4s - 114ms/step - loss: 0.0055 - mae: 0.0586 - val_loss: 0.0114 - val_mae: 0.0793
# Epoch 37/100
# 32/32 - 4s - 118ms/step - loss: 0.0055 - mae: 0.0582 - val_loss: 0.0114 - val_mae: 0.0829
# Epoch 38/100
# 32/32 - 3s - 80ms/step - loss: 0.0054 - mae: 0.0581 - val_loss: 0.0107 - val_mae: 0.0780
# Run 10 - MSE: 0.010395, MAE: 0.078008
#
# ===== Summary =====
# MSE mean: 0.010458, std: 0.000517
# MAE mean: 0.076552, std: 0.002335
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 90, 256)        │       280,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 90, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 90)             │        23,130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,487,056 (9.49 MB)
#  Trainable params: 829,018 (3.16 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,658,038 (6.32 MB)

# %% [markdown]
# 测试集+作图

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
df_test = pd.read_csv('data/test.csv', header=None)

# Step 2：赋完整列名（按顺序）
df_test.columns = ['DateTime']+numeric_cols
# 数值列转换（如有非数字或缺失，转为NaN）
df_test[numeric_cols] = df_test[numeric_cols].apply(pd.to_numeric, errors='coerce')
# 显式删除不需要字段
df_test = df_test.drop(columns=columns_to_drop)
df_test['DateTime'] = pd.to_datetime(df_test['DateTime'], errors='coerce')
df_test['Date'] = df_test['DateTime'].dt.date

# 计算 sub_metering_remainder
df_test['sub_metering_remainder'] = (df_test['Global_active_power'] * 1000 / 60) - (
    df_test['Sub_metering_1'] + df_test['Sub_metering_2'] + df_test['Sub_metering_3'])

# 按天聚合
df_test_daily = df_test.groupby('Date').agg(daily_agg).reset_index()
print(df_test_daily.head())
if need_date_time_columns==1:
    df_test_daily['Date'] = pd.to_datetime(df_test_daily['Date'])
    df_test_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
    df_test_daily['day_of_month'] = df_daily['Date'].dt.day
    df_test_daily['month'] = df_daily['Date'].dt.month
    df_test_daily['quarter'] = df_daily['Date'].dt.quarter
# ========== 关键修改点：丢弃含NaN的天 ==========
df_test_daily_clean = df_test_daily.dropna()
print(f"清洗后测试集天数: {len(df_test_daily_clean)}")


# 归一化（只对干净数据做）
df_test_daily_scaled = df_test_daily_clean.copy()
df_test_daily_scaled[feature_cols] = scaler.transform(df_test_daily_scaled[feature_cols])


def inverse_transform_target(scaler, feature_cols, data_1d, target_col='Global_active_power'):
    """
    把一维的目标列数据逆归一化。
    scaler: 训练时fit的Scaler
    feature_cols: 归一化时所有特征的列名列表
    data_1d: 目标列的一维归一化数据（如full_pred或full_true）
    返回：逆归一化后目标列一维数据
    """
    n = len(data_1d)
    temp = np.zeros((n, len(feature_cols)))
    # 找到目标列索引
    target_idx = feature_cols.index(target_col)
    temp[:, target_idx] = data_1d
    # 逆归一化
    inv_data = scaler.inverse_transform(temp)
    return inv_data[:, target_idx]


X_test_final, y_test_final = create_supervised_data(
    df_test_daily_scaled,
    input_window=input_window,
    output_window=output_window,
    target_col=target_col  # 一般是 'Global_active_power'
)
print(len(X_test_final))
y_pred_final = model.predict(X_test_final)

# 初始化容器
total_days = input_window + (len(y_pred_final) - 1) + output_window
pred_sum = np.zeros(total_days)
true_sum = np.zeros(total_days)
# pred_count = np.zeros(total_days)
# true_count = np.zeros(total_days)
#
# # 多窗口预测融合
# for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
#     start_idx = input_window + i
#     end_idx = start_idx + output_window
#
#     pred_sum[start_idx:end_idx] += pred
#     pred_count[start_idx:end_idx] += 1
#
#     true_sum[start_idx:end_idx] += true
#     true_count[start_idx:end_idx] += 1
#
# # 平均融合
# pred_avg = np.zeros_like(pred_sum)
# true_avg = np.zeros_like(true_sum)
#
# pred_avg[pred_count > 0] = pred_sum[pred_count > 0] / pred_count[pred_count > 0]
# true_avg[true_count > 0] = true_sum[true_count > 0] / true_count[true_count > 0]

# 替代平均融合：取最后一次预测
for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
    start_idx = input_window + i
    end_idx = start_idx + output_window

    pred_sum[start_idx:end_idx] = pred  # 直接覆盖
    true_sum[start_idx:end_idx] = true

# 取预测部分
full_pred = pred_sum[input_window:]
full_true = true_sum[input_window:]

# 反归一化
full_pred_inv = inverse_transform_target(scaler, feature_cols, full_pred, target_col)
full_true_inv = inverse_transform_target(scaler, feature_cols, full_true, target_col)

# 时间轴
days = np.arange(len(full_pred))



plt.figure(figsize=(14, 5))
plt.plot(days, full_true_inv, label='Ground Truth', color='blue', linewidth=2)
plt.plot(days, full_pred_inv, label='Merged Prediction', color='orange', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('Merged 90-day Predictions vs Ground Truth (Actual Values)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
true_values_to_show = full_true_inv
pred_values_to_show = full_pred_inv

# 打印前30天（或根据需要改）
print("Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error")
print("-" * 50)
for i in range(min(30, len(true_values_to_show))):
    true_val = true_values_to_show[i]
    pred_val = pred_values_to_show[i]
    error = abs(true_val - pred_val)
    print(f"{i:3d} | {true_val:17.4f} | {pred_val:19.4f} | {error:14.4f}")



# MSE
mse = mean_squared_error(true_values_to_show, pred_values_to_show)

# RMSE
rmse = mse ** 0.5

# MAE
mae = mean_absolute_error(true_values_to_show, pred_values_to_show)
errors = pred_values_to_show- true_values_to_show
std_dev = np.std(errors)

print(f"测试集评估指标:")
print(f"MSE : {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE : {mae:.6f}")
print(f"预测误差标准差: {std_dev:.6f}")
# Out:
# C:\Users\16693\AppData\Local\Temp\ipykernel_13252\1780962698.py:3: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('data/test.csv', header=None)
#          Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0  2009-01-01             1406.692                112.668           765.0
# 1  2009-01-02             2327.510                204.730          2417.0
# 2  2009-01-03             1913.496                174.912          6440.0
# 3  2009-01-04             1939.994                167.338          1457.0
# 4  2009-01-05             1604.000                128.938          1247.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0          3845.0          2803.0            16031.866667  242.836062
# 1          6018.0         11841.0            18515.833333  242.704889
# 2           328.0         10439.0            14684.600000  243.681458
# 3          5251.0          3245.0            22380.233333  244.822431
# 4           322.0          8650.0            16514.333333  244.830778
#
#    Global_intensity     RR  NBJRR1  NBJRR5  NBJRR10  NBJBROU
# 0          4.149861  51.24    10.0     4.2      1.4      0.6
# 1          6.737778  51.24    10.0     4.2      1.4      0.6
# 2          5.530833  51.24    10.0     4.2      1.4      0.6
# 3          5.633194  51.24    10.0     4.2      1.4      0.6
# 4          4.636250  51.24    10.0     4.2      1.4      0.6
# 清洗后测试集天数: 687
# 508
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
# Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error
# --------------------------------------------------
#   0 |         1641.1400 |           2085.6888 |       444.5488
#   1 |         1644.3340 |           2054.6706 |       410.3366
#   2 |         1363.2600 |           2024.9056 |       661.6456
#   3 |         2191.2320 |           1977.4901 |       213.7419
#   4 |         1375.7160 |           1968.2901 |       592.5741
#   5 |         1452.6340 |           1937.5725 |       484.9385
#   6 |         1440.0920 |           1903.8686 |       463.7766
#   7 |         1534.6000 |           1860.6249 |       326.0249
#   8 |         1890.4720 |           1806.6520 |        83.8200
#   9 |         1842.1140 |           1764.8881 |        77.2259
#  10 |         2462.4460 |           1725.7642 |       736.6818
#  11 |         2141.0120 |           1727.0952 |       413.9168
#  12 |         1598.6240 |           1715.6694 |       117.0454
#  13 |         1501.5380 |           1679.1282 |       177.5902
#  14 |         1216.0620 |           1640.1463 |       424.0843
#  15 |         1564.5240 |           1591.6379 |        27.1139
#  16 |         2042.8100 |           1556.0922 |       486.7178
#  17 |         1512.2660 |           1546.4582 |        34.1922
#  18 |         1286.4680 |           1576.5946 |       290.1266
#  19 |         1486.5100 |           1610.9968 |       124.4868
#  20 |         1894.5980 |           1643.9925 |       250.6055
#  21 |         1496.1980 |           1669.3863 |       173.1883
#  22 |         1141.4600 |           1688.0387 |       546.5787
#  23 |         1194.0480 |           1682.3541 |       488.3061
#  24 |         2022.2840 |           1673.4970 |       348.7870
#  25 |         1781.6260 |           1699.1601 |        82.4659
#  26 |         1351.6280 |           1723.1380 |       371.5100
#  27 |         1706.3860 |           1731.0638 |        24.6778
#  28 |         1664.6800 |           1740.6468 |        75.9668
#  29 |         1834.7620 |           1740.9435 |        93.8185
# 测试集评估指标:
# MSE : 181748.083262
# RMSE: 426.319227
# MAE : 336.860280
# 预测误差标准差: 420.235681

# %%
df_test_daily_clean.head()
# Out:
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2009-01-01             1406.692                112.668           765.0
# 1 2009-01-02             2327.510                204.730          2417.0
# 2 2009-01-03             1913.496                174.912          6440.0
# 3 2009-01-04             1939.994                167.338          1457.0
# 4 2009-01-05             1604.000                128.938          1247.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0          3845.0          2803.0            16031.866667  242.836062
# 1          6018.0         11841.0            18515.833333  242.704889
# 2           328.0         10439.0            14684.600000  243.681458
# 3          5251.0          3245.0            22380.233333  244.822431
# 4           322.0          8650.0            16514.333333  244.830778
#
#    Global_intensity     RR  NBJRR1  NBJRR5  NBJRR10  NBJBROU  day_of_week  \
# 0          4.149861  51.24    10.0     4.2      1.4      0.6            5
# 1          6.737778  51.24    10.0     4.2      1.4      0.6            6
# 2          5.530833  51.24    10.0     4.2      1.4      0.6            0
# 3          5.633194  51.24    10.0     4.2      1.4      0.6            1
# 4          4.636250  51.24    10.0     4.2      1.4      0.6            2
#
#    day_of_month  month  quarter
# 0            16     12        4
# 1            17     12        4
# 2            18     12        4
# 3            19     12        4
# 4            20     12        4

# %%
def inverse_transform_target_2d(scaler, feature_cols, data_2d, target_col='Global_active_power'):
    n_samples, n_steps = data_2d.shape
    inv_data = np.zeros_like(data_2d)
    target_idx = feature_cols.index(target_col)

    for i in range(n_samples):
        temp = np.zeros((n_steps, len(feature_cols)))
        temp[:, target_idx] = data_2d[i]
        inv_temp = scaler.inverse_transform(temp)
        inv_data[i] = inv_temp[:, target_idx]
    return inv_data

# 调用示例
y_test_inv = inverse_transform_target_2d(scaler, feature_cols, y_test_final)
y_pred_inv = inverse_transform_target_2d(scaler, feature_cols, y_pred_final)

days2 = np.arange(90)
plt.figure(figsize=(14, 5))
plt.plot(days2, y_test_inv[0], label='Ground Truth', color='blue', linewidth=2)
plt.plot(days2, y_pred_inv[0], label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('90-day Predictions vs Ground Truth')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
