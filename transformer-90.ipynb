# %% [markdown]
# **数据预处理**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# 读取数据
df = pd.read_csv('data//train.csv', parse_dates=['DateTime'])
# 转换所有应为数值的列为 float（防止字符串类型报错）
numeric_cols = [
    'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]
columns_to_drop=['RR','NBJRR5']
# 强制转换为 float，如果有无法解析的值，设置为 NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
df.dropna(subset=numeric_cols, inplace=True)

df=df.drop(columns=columns_to_drop)
# 添加日期列
df['Date'] = df['DateTime'].dt.date  # 只保留年月日部分

# 计算 sub_metering_remainder（每分钟）
df['sub_metering_remainder'] = (df['Global_active_power'] * 1000 / 60) - (
    df['Sub_metering_1'] + df['Sub_metering_2'] + df['Sub_metering_3'])

# 定义日级聚合函数
daily_agg = {
    'Global_active_power': 'mean' ,
    'Global_reactive_power': 'mean',
    'Sub_metering_1': 'sum',  # 已是 Wh，每分钟累计可以直接 sum
    'Sub_metering_2': 'sum',
    'Sub_metering_3': 'sum',
    'sub_metering_remainder': 'sum',

    'Voltage': 'mean',  # 电压波动，均值即可
    'Global_intensity': 'mean',  # 电流均值也合理

    'RR': 'first',  # 天气指标，一天一个值即可
    'NBJRR1': 'first',
    'NBJRR5': 'first',
    'NBJRR10': 'first',
    'NBJBROU': 'first'
}
for col in columns_to_drop:
    daily_agg.pop(col, None)

# 按日期聚合
df_daily = df.groupby('Date').agg(daily_agg).reset_index()

# 可以选择将日期列转回 datetime 类型
df_daily['Date'] = pd.to_datetime(df_daily['Date'])
df_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
df_daily['day_of_month'] = df_daily['Date'].dt.day
df_daily['month'] = df_daily['Date'].dt.month
df_daily['quarter'] = df_daily['Date'].dt.quarter
# 查看结果
print("预处理后日级数据：")
print(df_daily.info())
print(df_daily.head())
feature_cols = [col for col in df_daily.columns if col != 'Date']
scaler = MinMaxScaler()
df_daily_scaled = df_daily.copy()
df_daily_scaled[feature_cols] = scaler.fit_transform(df_daily[feature_cols])
print(df_daily_scaled.head())
# Out:
# 预处理后日级数据：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    746 non-null    datetime64[ns]
#  1   Global_active_power     746 non-null    float64
#  2   Global_reactive_power   746 non-null    float64
#  3   Sub_metering_1          746 non-null    float64
#  4   Sub_metering_2          746 non-null    float64
#  5   Sub_metering_3          746 non-null    float64
#  6   sub_metering_remainder  746 non-null    float64
#  7   Voltage                 746 non-null    float64
#  8   Global_intensity        746 non-null    float64
#  9   NBJRR1                  746 non-null    float64
#  10  NBJRR10                 746 non-null    float64
#  11  NBJBROU                 746 non-null    float64
#  12  day_of_week             746 non-null    int32
#  13  day_of_month            746 non-null    int32
#  14  month                   746 non-null    int32
#  15  quarter                 746 non-null    int32
# dtypes: datetime64[ns](1), float64(11), int32(4)
# memory usage: 81.7 KB
# None
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             3.053475               0.088187             0.0
# 1 2006-12-17             2.354486               0.156949          2033.0
# 2 2006-12-18             1.530435               0.112356          1063.0
# 3 2006-12-19             1.157079               0.104821           839.0
# 4 2006-12-20             1.545658               0.111804             0.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0           546.0          4926.0            14680.933333  236.243763
# 1          4187.0         13341.0            36946.666667  240.087028
# 2          2621.0         14018.0            19028.433333  241.231694
# 3          7602.0          6197.0            13131.900000  241.999313
# 4          2648.0         14063.0            20384.800000  242.308062
#
#    Global_intensity  NBJRR1  NBJRR10  NBJBROU  day_of_week  day_of_month  \
# 0         13.082828   9.333    2.167    0.167            5            16
# 1          9.999028   9.333    2.167    0.167            6            17
# 2          6.421667   9.333    2.167    0.167            0            18
# 3          4.926389   9.333    2.167    0.167            1            19
# 4          6.467361   9.333    2.167    0.167            2            20
#
#    month  quarter
# 0     12        4
# 1     12        4
# 2     12        4
# 3     12        4
# 4     12        4
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             0.916786               0.141546        0.000000
# 1 2006-12-17             0.694252               0.461964        0.196501
# 2 2006-12-18             0.431901               0.254168        0.102745
# 3 2006-12-19             0.313037               0.219057        0.081094
# 4 2006-12-20             0.436748               0.251599        0.000000
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder   Voltage  \
# 0        0.045090        0.252499                0.233317  0.371797
# 1        0.345776        0.683838                0.596096  0.648958
# 2        0.216451        0.718540                0.304152  0.731507
# 3        0.627798        0.317648                0.208079  0.786865
# 4        0.218680        0.720847                0.326251  0.809131
#
#    Global_intensity    NBJRR1  NBJRR10  NBJBROU  day_of_week  day_of_month  \
# 0          0.928499  0.480759   0.4925   0.4175     0.833333      0.500000
# 1          0.695226  0.480759   0.4925   0.4175     1.000000      0.533333
# 2          0.424618  0.480759   0.4925   0.4175     0.000000      0.566667
# 3          0.311508  0.480759   0.4925   0.4175     0.166667      0.600000
# 4          0.428075  0.480759   0.4925   0.4175     0.333333      0.633333
#
#    month  quarter
# 0    1.0      1.0
# 1    1.0      1.0
# 2    1.0      1.0
# 3    1.0      1.0
# 4    1.0      1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target_col = 'Global_active_power'
# 计算皮尔逊相关系数矩阵
corr_matrix = df_daily[feature_cols + [target_col]].corr()

# 可视化热力图
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title("Pearson Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
from sklearn.feature_selection import mutual_info_regression

X = df_daily[feature_cols]
y = df_daily[target_col]

mi_scores = mutual_info_regression(X, y, random_state=0)
mi_series = pd.Series(mi_scores, index=feature_cols).sort_values(ascending=False)

# 可视化
plt.figure(figsize=(10, 5))
mi_series.plot(kind='bar', color='darkorange')
plt.title(f'Mutual Information with Target: {target_col}')
plt.ylabel('MI Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **构造监督学习数据集**

# %%
def create_supervised_data(df, input_window=90, output_window=90, target_col='Global_active_power'):
    """
    构造用于多变量时间序列预测的监督学习样本
    参数：
        df: 已按天聚合的 DataFrame，包含时间序列特征
        input_window: 输入时间步长（例如 90）
        output_window: 预测步长（例如 90 或 365）
        target_col: 预测目标列
    返回：
        X: shape = [样本数, input_window, 特征数]
        y: shape = [样本数, output_window]
    """
    data = df.copy()
    feature_cols = [col for col in data.columns if col != 'Date']

    X_list = []
    y_list = []

    for i in range(len(data) - input_window - output_window + 1):
        x_window = data[feature_cols].iloc[i : i + input_window].values
        y_window = data[target_col].iloc[i + input_window : i + input_window + output_window].values

        if not (np.isnan(x_window).any() or np.isnan(y_window).any()):
            X_list.append(x_window)
            y_list.append(y_window)

    X = np.array(X_list)
    y = np.array(y_list)
    return X, y

# %% [markdown]
# Transformer模型设计

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.models import Model
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, d_model):
        super().__init__()
        pos = np.arange(sequence_length)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates

        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    # 多头注意力层

    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Dropout(dropout)(x)
    x = Add()([x, inputs])  # 残差连接
    x = LayerNormalization(epsilon=1e-6)(x)

    # 前馈网络
    x_ff = Dense(ff_dim, activation="relu")(x)
    x_ff = Dropout(dropout)(x_ff)
    x_ff = Dense(inputs.shape[-1])(x_ff)
    x = Add()([x_ff, x])
    x = LayerNormalization(epsilon=1e-6)(x)

    return x

def build_transformer_model(input_timesteps, num_features, output_timesteps,
                            head_size=64, num_heads=4, ff_dim=128, num_transformer_blocks=2, dropout=0.1):
    inputs = Input(shape=(input_timesteps, num_features))
    x = PositionalEncoding(input_timesteps, num_features)(inputs)
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # 可以取最后一个时间步，或者全局平均（更稳定）
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = Dropout(0.1)(x)
    outputs = Dense(output_timesteps)(x)

    model = Model(inputs, outputs)
    model.compile(optimizer="adam", loss="mse", metrics=["mae"])
    return model

# %% [markdown]
# **模型训练函数**

# %%
from tensorflow.keras.callbacks import EarlyStopping
def train_transformer_model(X_train, y_train, X_val, y_val,
                     input_timesteps, num_features, output_timesteps,
                     epochs=50, batch_size=64, n_runs=5):
    from tensorflow.keras import backend as K

    mse_list = []
    mae_list = []
    best_model = None
    best_mse = float('inf')

    for run in range(n_runs):
        print(f"\n===== Run {run+1}/{n_runs} =====")
        model = build_transformer_model(input_timesteps, num_features, output_timesteps)

        early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

        model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),  # 显式验证集
            callbacks=[early_stopping],
            verbose=2
        )

        # 验证集评估（用于模型选择）
        loss, mae = model.evaluate(X_val, y_val, verbose=0)
        mse = loss

        print(f"Run {run+1} - MSE: {mse:.6f}, MAE: {mae:.6f}")

        mse_list.append(mse)
        mae_list.append(mae)

        if mse < best_mse:
            best_mse = mse
            best_model = model

        K.clear_session()

    results = {
        'mse_mean': np.mean(mse_list),
        'mse_std': np.std(mse_list),
        'mae_mean': np.mean(mae_list),
        'mae_std': np.std(mae_list),
    }

    print("\n===== Summary =====")
    print(f"MSE mean: {results['mse_mean']:.6f}, std: {results['mse_std']:.6f}")
    print(f"MAE mean: {results['mae_mean']:.6f}, std: {results['mae_std']:.6f}")

    return best_model, results

# %% [markdown]
# 开始训练

# %%
input_window = 90
output_window = 90
target_col = 'Global_active_power'

X_full, y_full = create_supervised_data(df_daily_scaled, input_window, output_window, target_col)
print(f"X shape: {X_full.shape}, y shape: {y_full.shape}")
print(f"原始日级数据总天数: {df_daily.shape[0]}")
print(f"用于建模的样本数: {len(X_full)}")

# 划分训练集和验证集
train_ratio = 0.9
split_idx = int(len(X_full) * train_ratio)
X_train, X_val = X_full[:split_idx], X_full[split_idx:]
y_train, y_val = y_full[:split_idx], y_full[split_idx:]

print(f"训练集样本数: {len(X_train)}, 验证集样本数: {len(X_val)}")

num_features = X_train.shape[2]

model, results = train_transformer_model(
    X_train, y_train, X_val, y_val,
    input_window, num_features, output_window,
    epochs=50, batch_size=32, n_runs=5
)
# Out:
# X shape: (567, 90, 15), y shape: (567, 90)
# 原始日级数据总天数: 746
# 用于建模的样本数: 567
# 训练集样本数: 510, 验证集样本数: 57
#
# ===== Run 1/5 =====
# Epoch 1/50
# 16/16 - 3s - 183ms/step - loss: 0.1009 - mae: 0.2549 - val_loss: 0.0814 - val_mae: 0.2452
# Epoch 2/50
# 16/16 - 0s - 26ms/step - loss: 0.0527 - mae: 0.1808 - val_loss: 0.0500 - val_mae: 0.1818
# Epoch 3/50
# 16/16 - 0s - 26ms/step - loss: 0.0327 - mae: 0.1401 - val_loss: 0.0324 - val_mae: 0.1432
# Epoch 4/50
# 16/16 - 0s - 26ms/step - loss: 0.0228 - mae: 0.1166 - val_loss: 0.0271 - val_mae: 0.1319
# Epoch 5/50
# 16/16 - 0s - 26ms/step - loss: 0.0185 - mae: 0.1057 - val_loss: 0.0297 - val_mae: 0.1420
# Epoch 6/50
# 16/16 - 0s - 26ms/step - loss: 0.0168 - mae: 0.1009 - val_loss: 0.0377 - val_mae: 0.1656
# Epoch 7/50
# 16/16 - 0s - 26ms/step - loss: 0.0160 - mae: 0.0986 - val_loss: 0.0329 - val_mae: 0.1533
# Epoch 8/50
# 16/16 - 0s - 26ms/step - loss: 0.0151 - mae: 0.0957 - val_loss: 0.0319 - val_mae: 0.1507
# Epoch 9/50
# 16/16 - 0s - 25ms/step - loss: 0.0145 - mae: 0.0939 - val_loss: 0.0326 - val_mae: 0.1533
# Epoch 10/50
# 16/16 - 0s - 26ms/step - loss: 0.0140 - mae: 0.0926 - val_loss: 0.0303 - val_mae: 0.1462
# Epoch 11/50
# 16/16 - 0s - 25ms/step - loss: 0.0138 - mae: 0.0916 - val_loss: 0.0305 - val_mae: 0.1475
# Epoch 12/50
# 16/16 - 0s - 25ms/step - loss: 0.0137 - mae: 0.0911 - val_loss: 0.0318 - val_mae: 0.1512
# Epoch 13/50
# 16/16 - 0s - 25ms/step - loss: 0.0131 - mae: 0.0896 - val_loss: 0.0277 - val_mae: 0.1385
# Epoch 14/50
# 16/16 - 0s - 25ms/step - loss: 0.0131 - mae: 0.0894 - val_loss: 0.0279 - val_mae: 0.1397
# Epoch 15/50
# 16/16 - 0s - 25ms/step - loss: 0.0128 - mae: 0.0885 - val_loss: 0.0321 - val_mae: 0.1525
# Epoch 16/50
# 16/16 - 0s - 25ms/step - loss: 0.0131 - mae: 0.0891 - val_loss: 0.0340 - val_mae: 0.1580
# Epoch 17/50
# 16/16 - 0s - 25ms/step - loss: 0.0126 - mae: 0.0877 - val_loss: 0.0276 - val_mae: 0.1395
# Epoch 18/50
# 16/16 - 0s - 26ms/step - loss: 0.0123 - mae: 0.0865 - val_loss: 0.0292 - val_mae: 0.1445
# Epoch 19/50
# 16/16 - 0s - 25ms/step - loss: 0.0122 - mae: 0.0862 - val_loss: 0.0292 - val_mae: 0.1444
# Run 1 - MSE: 0.027059, MAE: 0.131925
#
# ===== Run 2/5 =====
# Epoch 1/50
# 16/16 - 3s - 182ms/step - loss: 0.1170 - mae: 0.2719 - val_loss: 0.0894 - val_mae: 0.2452
# Epoch 2/50
# 16/16 - 0s - 27ms/step - loss: 0.0644 - mae: 0.2050 - val_loss: 0.0631 - val_mae: 0.2027
# Epoch 3/50
# 16/16 - 0s - 27ms/step - loss: 0.0475 - mae: 0.1721 - val_loss: 0.0452 - val_mae: 0.1683
# Epoch 4/50
# 16/16 - 0s - 27ms/step - loss: 0.0346 - mae: 0.1439 - val_loss: 0.0329 - val_mae: 0.1414
# Epoch 5/50
# 16/16 - 0s - 26ms/step - loss: 0.0257 - mae: 0.1240 - val_loss: 0.0265 - val_mae: 0.1260
# Epoch 6/50
# 16/16 - 0s - 26ms/step - loss: 0.0209 - mae: 0.1119 - val_loss: 0.0245 - val_mae: 0.1235
# Epoch 7/50
# 16/16 - 0s - 26ms/step - loss: 0.0179 - mae: 0.1038 - val_loss: 0.0226 - val_mae: 0.1182
# Epoch 8/50
# 16/16 - 0s - 26ms/step - loss: 0.0160 - mae: 0.0979 - val_loss: 0.0222 - val_mae: 0.1175
# Epoch 9/50
# 16/16 - 0s - 26ms/step - loss: 0.0156 - mae: 0.0967 - val_loss: 0.0234 - val_mae: 0.1221
# Epoch 10/50
# 16/16 - 0s - 26ms/step - loss: 0.0151 - mae: 0.0953 - val_loss: 0.0251 - val_mae: 0.1282
# Epoch 11/50
# 16/16 - 0s - 26ms/step - loss: 0.0139 - mae: 0.0918 - val_loss: 0.0276 - val_mae: 0.1368
# Epoch 12/50
# 16/16 - 0s - 26ms/step - loss: 0.0142 - mae: 0.0929 - val_loss: 0.0253 - val_mae: 0.1291
# Epoch 13/50
# 16/16 - 0s - 26ms/step - loss: 0.0135 - mae: 0.0908 - val_loss: 0.0270 - val_mae: 0.1350
# Epoch 14/50
# 16/16 - 0s - 27ms/step - loss: 0.0132 - mae: 0.0899 - val_loss: 0.0283 - val_mae: 0.1392
# Epoch 15/50
# 16/16 - 0s - 27ms/step - loss: 0.0134 - mae: 0.0906 - val_loss: 0.0270 - val_mae: 0.1353
# Epoch 16/50
# 16/16 - 0s - 26ms/step - loss: 0.0129 - mae: 0.0885 - val_loss: 0.0285 - val_mae: 0.1404
# Epoch 17/50
# 16/16 - 0s - 26ms/step - loss: 0.0130 - mae: 0.0887 - val_loss: 0.0270 - val_mae: 0.1352
# Epoch 18/50
# 16/16 - 0s - 26ms/step - loss: 0.0127 - mae: 0.0879 - val_loss: 0.0248 - val_mae: 0.1285
# Epoch 19/50
# 16/16 - 0s - 26ms/step - loss: 0.0125 - mae: 0.0873 - val_loss: 0.0239 - val_mae: 0.1264
# Epoch 20/50
# 16/16 - 0s - 26ms/step - loss: 0.0124 - mae: 0.0870 - val_loss: 0.0258 - val_mae: 0.1326
# Epoch 21/50
# 16/16 - 0s - 26ms/step - loss: 0.0121 - mae: 0.0861 - val_loss: 0.0277 - val_mae: 0.1385
# Epoch 22/50
# 16/16 - 0s - 25ms/step - loss: 0.0119 - mae: 0.0852 - val_loss: 0.0270 - val_mae: 0.1367
# Epoch 23/50
# 16/16 - 0s - 26ms/step - loss: 0.0119 - mae: 0.0851 - val_loss: 0.0286 - val_mae: 0.1421
# Run 2 - MSE: 0.022238, MAE: 0.117532
#
# ===== Run 3/5 =====
# Epoch 1/50
# 16/16 - 3s - 176ms/step - loss: 0.1087 - mae: 0.2611 - val_loss: 0.0804 - val_mae: 0.2312
# Epoch 2/50
# 16/16 - 0s - 25ms/step - loss: 0.0589 - mae: 0.1929 - val_loss: 0.0572 - val_mae: 0.1901
# Epoch 3/50
# 16/16 - 0s - 25ms/step - loss: 0.0418 - mae: 0.1594 - val_loss: 0.0396 - val_mae: 0.1549
# Epoch 4/50
# 16/16 - 0s - 25ms/step - loss: 0.0308 - mae: 0.1353 - val_loss: 0.0296 - val_mae: 0.1327
# Epoch 5/50
# 16/16 - 0s - 25ms/step - loss: 0.0236 - mae: 0.1181 - val_loss: 0.0248 - val_mae: 0.1216
# Epoch 6/50
# 16/16 - 0s - 25ms/step - loss: 0.0193 - mae: 0.1072 - val_loss: 0.0235 - val_mae: 0.1197
# Epoch 7/50
# 16/16 - 0s - 25ms/step - loss: 0.0174 - mae: 0.1021 - val_loss: 0.0218 - val_mae: 0.1149
# Epoch 8/50
# 16/16 - 0s - 25ms/step - loss: 0.0163 - mae: 0.0991 - val_loss: 0.0241 - val_mae: 0.1244
# Epoch 9/50
# 16/16 - 0s - 25ms/step - loss: 0.0152 - mae: 0.0959 - val_loss: 0.0246 - val_mae: 0.1271
# Epoch 10/50
# 16/16 - 0s - 25ms/step - loss: 0.0148 - mae: 0.0946 - val_loss: 0.0245 - val_mae: 0.1269
# Epoch 11/50
# 16/16 - 0s - 25ms/step - loss: 0.0142 - mae: 0.0933 - val_loss: 0.0230 - val_mae: 0.1215
# Epoch 12/50
# 16/16 - 0s - 25ms/step - loss: 0.0140 - mae: 0.0922 - val_loss: 0.0229 - val_mae: 0.1212
# Epoch 13/50
# 16/16 - 0s - 25ms/step - loss: 0.0136 - mae: 0.0912 - val_loss: 0.0245 - val_mae: 0.1270
# Epoch 14/50
# 16/16 - 0s - 25ms/step - loss: 0.0138 - mae: 0.0915 - val_loss: 0.0274 - val_mae: 0.1371
# Epoch 15/50
# 16/16 - 0s - 25ms/step - loss: 0.0135 - mae: 0.0908 - val_loss: 0.0278 - val_mae: 0.1385
# Epoch 16/50
# 16/16 - 0s - 25ms/step - loss: 0.0135 - mae: 0.0907 - val_loss: 0.0188 - val_mae: 0.1047
# Epoch 17/50
# 16/16 - 0s - 25ms/step - loss: 0.0131 - mae: 0.0896 - val_loss: 0.0258 - val_mae: 0.1322
# Epoch 18/50
# 16/16 - 0s - 26ms/step - loss: 0.0131 - mae: 0.0894 - val_loss: 0.0206 - val_mae: 0.1129
# Epoch 19/50
# 16/16 - 0s - 25ms/step - loss: 0.0127 - mae: 0.0879 - val_loss: 0.0227 - val_mae: 0.1209
# Epoch 20/50
# 16/16 - 0s - 25ms/step - loss: 0.0125 - mae: 0.0875 - val_loss: 0.0227 - val_mae: 0.1212
# Epoch 21/50
# 16/16 - 0s - 25ms/step - loss: 0.0125 - mae: 0.0870 - val_loss: 0.0232 - val_mae: 0.1236
# Epoch 22/50
# 16/16 - 0s - 25ms/step - loss: 0.0123 - mae: 0.0865 - val_loss: 0.0240 - val_mae: 0.1266
# Epoch 23/50
# 16/16 - 0s - 26ms/step - loss: 0.0122 - mae: 0.0860 - val_loss: 0.0206 - val_mae: 0.1131
# Epoch 24/50
# 16/16 - 0s - 25ms/step - loss: 0.0120 - mae: 0.0856 - val_loss: 0.0225 - val_mae: 0.1215
# Epoch 25/50
# 16/16 - 0s - 25ms/step - loss: 0.0119 - mae: 0.0851 - val_loss: 0.0217 - val_mae: 0.1181
# Epoch 26/50
# 16/16 - 0s - 25ms/step - loss: 0.0117 - mae: 0.0847 - val_loss: 0.0217 - val_mae: 0.1185
# Epoch 27/50
# 16/16 - 0s - 25ms/step - loss: 0.0115 - mae: 0.0839 - val_loss: 0.0191 - val_mae: 0.1077
# Epoch 28/50
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0840 - val_loss: 0.0199 - val_mae: 0.1109
# Epoch 29/50
# 16/16 - 0s - 25ms/step - loss: 0.0115 - mae: 0.0838 - val_loss: 0.0209 - val_mae: 0.1159
# Epoch 30/50
# 16/16 - 0s - 25ms/step - loss: 0.0111 - mae: 0.0824 - val_loss: 0.0205 - val_mae: 0.1149
# Epoch 31/50
# 16/16 - 0s - 25ms/step - loss: 0.0111 - mae: 0.0824 - val_loss: 0.0209 - val_mae: 0.1167
# Run 3 - MSE: 0.018804, MAE: 0.104716
#
# ===== Run 4/5 =====
# Epoch 1/50
# 16/16 - 3s - 177ms/step - loss: 0.1179 - mae: 0.2797 - val_loss: 0.0994 - val_mae: 0.2720
# Epoch 2/50
# 16/16 - 0s - 26ms/step - loss: 0.0720 - mae: 0.2211 - val_loss: 0.0748 - val_mae: 0.2275
# Epoch 3/50
# 16/16 - 0s - 26ms/step - loss: 0.0538 - mae: 0.1847 - val_loss: 0.0536 - val_mae: 0.1866
# Epoch 4/50
# 16/16 - 0s - 26ms/step - loss: 0.0387 - mae: 0.1528 - val_loss: 0.0376 - val_mae: 0.1516
# Epoch 5/50
# 16/16 - 0s - 26ms/step - loss: 0.0278 - mae: 0.1285 - val_loss: 0.0293 - val_mae: 0.1331
# Epoch 6/50
# 16/16 - 0s - 26ms/step - loss: 0.0223 - mae: 0.1150 - val_loss: 0.0233 - val_mae: 0.1174
# Epoch 7/50
# 16/16 - 0s - 26ms/step - loss: 0.0184 - mae: 0.1052 - val_loss: 0.0225 - val_mae: 0.1171
# Epoch 8/50
# 16/16 - 0s - 25ms/step - loss: 0.0162 - mae: 0.0990 - val_loss: 0.0237 - val_mae: 0.1226
# Epoch 9/50
# 16/16 - 0s - 25ms/step - loss: 0.0150 - mae: 0.0956 - val_loss: 0.0227 - val_mae: 0.1193
# Epoch 10/50
# 16/16 - 0s - 26ms/step - loss: 0.0149 - mae: 0.0952 - val_loss: 0.0260 - val_mae: 0.1317
# Epoch 11/50
# 16/16 - 0s - 25ms/step - loss: 0.0147 - mae: 0.0944 - val_loss: 0.0228 - val_mae: 0.1210
# Epoch 12/50
# 16/16 - 0s - 25ms/step - loss: 0.0139 - mae: 0.0922 - val_loss: 0.0241 - val_mae: 0.1260
# Epoch 13/50
# 16/16 - 0s - 25ms/step - loss: 0.0140 - mae: 0.0924 - val_loss: 0.0241 - val_mae: 0.1259
# Epoch 14/50
# 16/16 - 0s - 26ms/step - loss: 0.0135 - mae: 0.0908 - val_loss: 0.0231 - val_mae: 0.1229
# Epoch 15/50
# 16/16 - 0s - 25ms/step - loss: 0.0132 - mae: 0.0898 - val_loss: 0.0241 - val_mae: 0.1264
# Epoch 16/50
# 16/16 - 0s - 25ms/step - loss: 0.0131 - mae: 0.0892 - val_loss: 0.0234 - val_mae: 0.1241
# Epoch 17/50
# 16/16 - 0s - 25ms/step - loss: 0.0129 - mae: 0.0887 - val_loss: 0.0241 - val_mae: 0.1267
# Epoch 18/50
# 16/16 - 0s - 26ms/step - loss: 0.0129 - mae: 0.0888 - val_loss: 0.0209 - val_mae: 0.1150
# Epoch 19/50
# 16/16 - 0s - 25ms/step - loss: 0.0128 - mae: 0.0883 - val_loss: 0.0255 - val_mae: 0.1318
# Epoch 20/50
# 16/16 - 0s - 26ms/step - loss: 0.0127 - mae: 0.0880 - val_loss: 0.0222 - val_mae: 0.1204
# Epoch 21/50
# 16/16 - 0s - 25ms/step - loss: 0.0123 - mae: 0.0866 - val_loss: 0.0220 - val_mae: 0.1197
# Epoch 22/50
# 16/16 - 0s - 26ms/step - loss: 0.0122 - mae: 0.0862 - val_loss: 0.0207 - val_mae: 0.1152
# Epoch 23/50
# 16/16 - 0s - 25ms/step - loss: 0.0124 - mae: 0.0872 - val_loss: 0.0204 - val_mae: 0.1142
# Epoch 24/50
# 16/16 - 0s - 26ms/step - loss: 0.0120 - mae: 0.0855 - val_loss: 0.0224 - val_mae: 0.1224
# Epoch 25/50
# 16/16 - 0s - 25ms/step - loss: 0.0118 - mae: 0.0850 - val_loss: 0.0192 - val_mae: 0.1100
# Epoch 26/50
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0840 - val_loss: 0.0198 - val_mae: 0.1129
# Epoch 27/50
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0843 - val_loss: 0.0178 - val_mae: 0.1050
# Epoch 28/50
# 16/16 - 0s - 26ms/step - loss: 0.0114 - mae: 0.0838 - val_loss: 0.0185 - val_mae: 0.1086
# Epoch 29/50
# 16/16 - 0s - 25ms/step - loss: 0.0113 - mae: 0.0829 - val_loss: 0.0201 - val_mae: 0.1146
# Epoch 30/50
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0828 - val_loss: 0.0197 - val_mae: 0.1143
# Epoch 31/50
# 16/16 - 0s - 25ms/step - loss: 0.0112 - mae: 0.0828 - val_loss: 0.0189 - val_mae: 0.1113
# Epoch 32/50
# 16/16 - 0s - 26ms/step - loss: 0.0110 - mae: 0.0819 - val_loss: 0.0227 - val_mae: 0.1253
# Epoch 33/50
# 16/16 - 0s - 25ms/step - loss: 0.0109 - mae: 0.0816 - val_loss: 0.0204 - val_mae: 0.1173
# Epoch 34/50
# 16/16 - 0s - 26ms/step - loss: 0.0107 - mae: 0.0808 - val_loss: 0.0184 - val_mae: 0.1102
# Epoch 35/50
# 16/16 - 0s - 26ms/step - loss: 0.0107 - mae: 0.0807 - val_loss: 0.0198 - val_mae: 0.1159
# Epoch 36/50
# 16/16 - 0s - 26ms/step - loss: 0.0104 - mae: 0.0802 - val_loss: 0.0183 - val_mae: 0.1106
# Epoch 37/50
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0798 - val_loss: 0.0178 - val_mae: 0.1086
# Epoch 38/50
# 16/16 - 0s - 26ms/step - loss: 0.0103 - mae: 0.0797 - val_loss: 0.0214 - val_mae: 0.1220
# Epoch 39/50
# 16/16 - 0s - 26ms/step - loss: 0.0103 - mae: 0.0795 - val_loss: 0.0208 - val_mae: 0.1204
# Epoch 40/50
# 16/16 - 0s - 26ms/step - loss: 0.0103 - mae: 0.0796 - val_loss: 0.0210 - val_mae: 0.1212
# Epoch 41/50
# 16/16 - 0s - 25ms/step - loss: 0.0100 - mae: 0.0784 - val_loss: 0.0185 - val_mae: 0.1123
# Epoch 42/50
# 16/16 - 0s - 26ms/step - loss: 0.0099 - mae: 0.0781 - val_loss: 0.0184 - val_mae: 0.1120
# Run 4 - MSE: 0.017774, MAE: 0.105016
#
# ===== Run 5/5 =====
# Epoch 1/50
# 16/16 - 3s - 177ms/step - loss: 0.0934 - mae: 0.2460 - val_loss: 0.0799 - val_mae: 0.2366
# Epoch 2/50
# 16/16 - 0s - 26ms/step - loss: 0.0568 - mae: 0.1895 - val_loss: 0.0590 - val_mae: 0.1966
# Epoch 3/50
# 16/16 - 0s - 26ms/step - loss: 0.0391 - mae: 0.1534 - val_loss: 0.0415 - val_mae: 0.1612
# Epoch 4/50
# 16/16 - 0s - 26ms/step - loss: 0.0275 - mae: 0.1270 - val_loss: 0.0340 - val_mae: 0.1470
# Epoch 5/50
# 16/16 - 0s - 26ms/step - loss: 0.0215 - mae: 0.1126 - val_loss: 0.0288 - val_mae: 0.1358
# Epoch 6/50
# 16/16 - 0s - 26ms/step - loss: 0.0184 - mae: 0.1045 - val_loss: 0.0297 - val_mae: 0.1406
# Epoch 7/50
# 16/16 - 0s - 25ms/step - loss: 0.0163 - mae: 0.0991 - val_loss: 0.0293 - val_mae: 0.1399
# Epoch 8/50
# 16/16 - 0s - 26ms/step - loss: 0.0155 - mae: 0.0967 - val_loss: 0.0281 - val_mae: 0.1370
# Epoch 9/50
# 16/16 - 0s - 26ms/step - loss: 0.0143 - mae: 0.0931 - val_loss: 0.0266 - val_mae: 0.1327
# Epoch 10/50
# 16/16 - 0s - 26ms/step - loss: 0.0144 - mae: 0.0936 - val_loss: 0.0287 - val_mae: 0.1395
# Epoch 11/50
# 16/16 - 0s - 25ms/step - loss: 0.0142 - mae: 0.0931 - val_loss: 0.0241 - val_mae: 0.1248
# Epoch 12/50
# 16/16 - 0s - 26ms/step - loss: 0.0139 - mae: 0.0923 - val_loss: 0.0286 - val_mae: 0.1405
# Epoch 13/50
# 16/16 - 0s - 26ms/step - loss: 0.0132 - mae: 0.0898 - val_loss: 0.0262 - val_mae: 0.1328
# Epoch 14/50
# 16/16 - 0s - 26ms/step - loss: 0.0130 - mae: 0.0892 - val_loss: 0.0260 - val_mae: 0.1326
# Epoch 15/50
# 16/16 - 0s - 26ms/step - loss: 0.0128 - mae: 0.0886 - val_loss: 0.0256 - val_mae: 0.1311
# Epoch 16/50
# 16/16 - 0s - 26ms/step - loss: 0.0127 - mae: 0.0880 - val_loss: 0.0254 - val_mae: 0.1315
# Epoch 17/50
# 16/16 - 0s - 26ms/step - loss: 0.0124 - mae: 0.0873 - val_loss: 0.0253 - val_mae: 0.1310
# Epoch 18/50
# 16/16 - 0s - 26ms/step - loss: 0.0122 - mae: 0.0865 - val_loss: 0.0270 - val_mae: 0.1370
# Epoch 19/50
# 16/16 - 0s - 26ms/step - loss: 0.0120 - mae: 0.0857 - val_loss: 0.0223 - val_mae: 0.1210
# Epoch 20/50
# 16/16 - 0s - 26ms/step - loss: 0.0116 - mae: 0.0844 - val_loss: 0.0242 - val_mae: 0.1279
# Epoch 21/50
# 16/16 - 0s - 26ms/step - loss: 0.0117 - mae: 0.0845 - val_loss: 0.0251 - val_mae: 0.1320
# Epoch 22/50
# 16/16 - 0s - 26ms/step - loss: 0.0113 - mae: 0.0830 - val_loss: 0.0232 - val_mae: 0.1253
# Epoch 23/50
# 16/16 - 0s - 25ms/step - loss: 0.0112 - mae: 0.0828 - val_loss: 0.0217 - val_mae: 0.1202
# Epoch 24/50
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0825 - val_loss: 0.0201 - val_mae: 0.1144
# Epoch 25/50
# 16/16 - 0s - 26ms/step - loss: 0.0110 - mae: 0.0821 - val_loss: 0.0191 - val_mae: 0.1104
# Epoch 26/50
# 16/16 - 0s - 26ms/step - loss: 0.0108 - mae: 0.0813 - val_loss: 0.0191 - val_mae: 0.1111
# Epoch 27/50
# 16/16 - 0s - 25ms/step - loss: 0.0106 - mae: 0.0807 - val_loss: 0.0220 - val_mae: 0.1223
# Epoch 28/50
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0800 - val_loss: 0.0219 - val_mae: 0.1223
# Epoch 29/50
# 16/16 - 0s - 25ms/step - loss: 0.0104 - mae: 0.0800 - val_loss: 0.0211 - val_mae: 0.1201
# Epoch 30/50
# 16/16 - 0s - 26ms/step - loss: 0.0105 - mae: 0.0801 - val_loss: 0.0198 - val_mae: 0.1149
# Epoch 31/50
# 16/16 - 0s - 26ms/step - loss: 0.0102 - mae: 0.0789 - val_loss: 0.0202 - val_mae: 0.1170
# Epoch 32/50
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0792 - val_loss: 0.0252 - val_mae: 0.1336
# Epoch 33/50
# 16/16 - 0s - 25ms/step - loss: 0.0102 - mae: 0.0790 - val_loss: 0.0199 - val_mae: 0.1165
# Epoch 34/50
# 16/16 - 0s - 26ms/step - loss: 0.0102 - mae: 0.0789 - val_loss: 0.0191 - val_mae: 0.1125
# Epoch 35/50
# 16/16 - 0s - 25ms/step - loss: 0.0099 - mae: 0.0780 - val_loss: 0.0184 - val_mae: 0.1102
# Epoch 36/50
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0777 - val_loss: 0.0199 - val_mae: 0.1168
# Epoch 37/50
# 16/16 - 0s - 26ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0173 - val_mae: 0.1077
# Epoch 38/50
# 16/16 - 0s - 25ms/step - loss: 0.0097 - mae: 0.0772 - val_loss: 0.0183 - val_mae: 0.1123
# Epoch 39/50
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0186 - val_mae: 0.1136
# Epoch 40/50
# 16/16 - 0s - 25ms/step - loss: 0.0097 - mae: 0.0772 - val_loss: 0.0184 - val_mae: 0.1119
# Epoch 41/50
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0199 - val_mae: 0.1183
# Epoch 42/50
# 16/16 - 0s - 26ms/step - loss: 0.0097 - mae: 0.0768 - val_loss: 0.0193 - val_mae: 0.1140
# Epoch 43/50
# 16/16 - 0s - 25ms/step - loss: 0.0097 - mae: 0.0767 - val_loss: 0.0188 - val_mae: 0.1135
# Epoch 44/50
# 16/16 - 0s - 25ms/step - loss: 0.0094 - mae: 0.0759 - val_loss: 0.0205 - val_mae: 0.1190
# Epoch 45/50
# 16/16 - 0s - 25ms/step - loss: 0.0094 - mae: 0.0759 - val_loss: 0.0203 - val_mae: 0.1190
# Epoch 46/50
# 16/16 - 0s - 26ms/step - loss: 0.0093 - mae: 0.0755 - val_loss: 0.0182 - val_mae: 0.1112
# Epoch 47/50
# 16/16 - 0s - 26ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0204 - val_mae: 0.1190
# Epoch 48/50
# 16/16 - 0s - 26ms/step - loss: 0.0094 - mae: 0.0760 - val_loss: 0.0203 - val_mae: 0.1191
# Epoch 49/50
# 16/16 - 0s - 26ms/step - loss: 0.0093 - mae: 0.0756 - val_loss: 0.0176 - val_mae: 0.1093
# Epoch 50/50
# 16/16 - 0s - 26ms/step - loss: 0.0092 - mae: 0.0749 - val_loss: 0.0197 - val_mae: 0.1167
# Run 5 - MSE: 0.017329, MAE: 0.107653
#
# ===== Summary =====
# MSE mean: 0.020641, std: 0.003641
# MAE mean: 0.113368, std: 0.010383

# %% [markdown]
# 测试集+作图

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
df_test = pd.read_csv('data/test.csv', header=None)

# Step 2：赋完整列名（按顺序）
df_test.columns = [
    'DateTime', 'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]




# 数值列转换（如有非数字或缺失，转为NaN）
df_test[numeric_cols] = df_test[numeric_cols].apply(pd.to_numeric, errors='coerce')
# 显式删除不需要字段
df_test = df_test.drop(columns=columns_to_drop)
df_test['DateTime'] = pd.to_datetime(df['DateTime'], errors='coerce')
df_test['Date'] = df_test['DateTime'].dt.date

# 计算 sub_metering_remainder
df_test['sub_metering_remainder'] = (df_test['Global_active_power'] * 1000 / 60) - (
    df_test['Sub_metering_1'] + df_test['Sub_metering_2'] + df_test['Sub_metering_3'])

# 按天聚合
df_test_daily = df_test.groupby('Date').agg(daily_agg).reset_index()
df_test_daily['Date'] = pd.to_datetime(df_test_daily['Date'])
df_test_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
df_test_daily['day_of_month'] = df_daily['Date'].dt.day
df_test_daily['month'] = df_daily['Date'].dt.month
df_test_daily['quarter'] = df_daily['Date'].dt.quarter
# ========== 关键修改点：丢弃含NaN的天 ==========
df_test_daily_clean = df_test_daily.dropna()
print(f"清洗后测试集天数: {len(df_test_daily_clean)}")

# 归一化（只对干净数据做）
df_test_daily_scaled = df_test_daily_clean.copy()
df_test_daily_scaled[feature_cols] = scaler.transform(df_test_daily_scaled[feature_cols])


def inverse_transform_target(scaler, feature_cols, data_1d, target_col='Global_active_power'):
    """
    把一维的目标列数据逆归一化。
    scaler: 训练时fit的Scaler
    feature_cols: 归一化时所有特征的列名列表
    data_1d: 目标列的一维归一化数据（如full_pred或full_true）
    返回：逆归一化后目标列一维数据
    """
    n = len(data_1d)
    temp = np.zeros((n, len(feature_cols)))
    # 找到目标列索引
    target_idx = feature_cols.index(target_col)
    temp[:, target_idx] = data_1d
    # 逆归一化
    inv_data = scaler.inverse_transform(temp)
    return inv_data[:, target_idx]


X_test_final, y_test_final = create_supervised_data(
    df_test_daily_scaled,
    input_window=input_window,
    output_window=output_window,
    target_col=target_col  # 一般是 'Global_active_power'
)
y_pred_final = model.predict(X_test_final)
# print("测试集天数(原始日数据):", len(df_test_daily_scaled))
# print("测试集每日特征缺失情况:\n", df_test_daily_scaled.isna().sum())
# print("预测窗口数(样本数):", len(y_pred_final))
# print("预测窗口中有缺失值样本丢弃数:", (len(df_test_daily_scaled) - input_window - output_window + 1) - len(y_pred_final))


# 初始化累计容器
total_days = input_window + (len(y_pred_final) - 1) + output_window
pred_sum = np.zeros(total_days)
pred_count = np.zeros(total_days)
true_sum = np.zeros(total_days)
true_count = np.zeros(total_days)

# 多窗口预测融合
for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
    start_idx = input_window + i
    end_idx = start_idx + output_window

    pred_sum[start_idx:end_idx] += pred
    pred_count[start_idx:end_idx] += 1

    true_sum[start_idx:end_idx] += true
    true_count[start_idx:end_idx] += 1

# 平均融合
pred_avg = np.zeros_like(pred_sum)
true_avg = np.zeros_like(true_sum)

pred_avg[pred_count > 0] = pred_sum[pred_count > 0] / pred_count[pred_count > 0]
true_avg[true_count > 0] = true_sum[true_count > 0] / true_count[true_count > 0]

# 用最后一个样本的历史输入作为上下文
# past_context = X_test_final[-1][:, 0]  # 通常预测目标在第0列

# 拼接成完整序列
# full_pred = np.concatenate([past_context, pred_avg[input_window:]])
# full_true = np.concatenate([past_context, true_avg[input_window:]])
full_pred = pred_avg[input_window:]  # 直接取模型预测融合部分
full_true = true_avg[input_window:]
# 对full_pred和full_true做逆归一化
full_pred_inv = inverse_transform_target(scaler, feature_cols, full_pred, target_col)
full_true_inv = inverse_transform_target(scaler, feature_cols, full_true, target_col)

# 横轴时间
# days = np.arange(len(full_pred) - input_window)
days = np.arange(len(full_pred))  # 对应 prediction-only 区段

plt.figure(figsize=(14, 5))
plt.plot(days, full_true_inv, label='Ground Truth', color='blue', linewidth=2)
plt.plot(days, full_pred_inv, label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('Merged 90-day Predictions vs Ground Truth (Actual Values)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
true_values_to_show = full_true_inv
pred_values_to_show = full_pred_inv

# 打印前30天（或根据需要改）
print("Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error")
print("-" * 50)
for i in range(min(30, len(true_values_to_show))):
    true_val = true_values_to_show[i]
    pred_val = pred_values_to_show[i]
    error = abs(true_val - pred_val)
    print(f"{i:3d} | {true_val:17.4f} | {pred_val:19.4f} | {error:14.4f}")



# MSE
mse = mean_squared_error(true_values_to_show, pred_values_to_show)

# RMSE
rmse = mse ** 0.5

# MAE
mae = mean_absolute_error(true_values_to_show, pred_values_to_show)
errors = pred_values_to_show- true_values_to_show
std_dev = np.std(errors)

print(f"测试集评估指标:")
print(f"MSE : {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE : {mae:.6f}")
print(f"预测误差标准差: {std_dev:.6f}")
# Out:
# C:\Users\16693\AppData\Local\Temp\ipykernel_41684\3274135352.py:3: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('data/test.csv', header=None)
# 清洗后测试集天数: 684
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error
# --------------------------------------------------
#   0 |            1.3645 |              1.4575 |         0.0930
#   1 |            1.0307 |              1.4544 |         0.4236
#   2 |            1.1437 |              1.4229 |         0.2792
#   3 |            0.9423 |              1.4297 |         0.4874
#   4 |            1.5466 |              1.4480 |         0.0986
#   5 |            0.9371 |              1.4545 |         0.5174
#   6 |            1.0013 |              1.4361 |         0.4348
#   7 |            1.0317 |              1.4460 |         0.4143
#   8 |            1.0568 |              1.4567 |         0.3999
#   9 |            1.2965 |              1.4385 |         0.1421
#  10 |            1.2550 |              1.4349 |         0.1800
#  11 |            1.8782 |              1.4357 |         0.4425
#  12 |            1.3555 |              1.4504 |         0.0950
#  13 |            1.0928 |              1.4383 |         0.3454
#  14 |            1.0722 |              1.4407 |         0.3685
#  15 |            0.8385 |              1.4330 |         0.5946
#  16 |            1.3665 |              1.4271 |         0.0606
#  17 |            1.1529 |              1.4094 |         0.2565
#  18 |            1.0313 |              1.4117 |         0.3804
#  19 |            0.8968 |              1.4121 |         0.5153
#  20 |            1.3002 |              1.4020 |         0.1018
#  21 |            1.0349 |              1.3994 |         0.3645
#  22 |            1.0774 |              1.3877 |         0.3103
#  23 |            0.7670 |              1.3850 |         0.6180
#  24 |            0.8149 |              1.3838 |         0.5689
#  25 |            1.4407 |              1.3656 |         0.0751
#  26 |            1.2046 |              1.3624 |         0.1577
#  27 |            0.9737 |              1.3581 |         0.3843
#  28 |            1.1415 |              1.3524 |         0.2109
#  29 |            1.1776 |              1.3422 |         0.1646
# 测试集评估指标:
# MSE : 0.104135
# RMSE: 0.322700
# MAE : 0.256348
# 预测误差标准差: 0.307068

# %%
days2 = np.arange(90)
plt.figure(figsize=(14, 5))
plt.plot(days2, y_test_final[1], label='Ground Truth', color='blue', linewidth=2)
plt.plot(days2, y_pred_final[1], label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('90-day Predictions vs Ground Truth')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
