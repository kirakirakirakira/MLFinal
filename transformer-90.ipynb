# %% [markdown]
# **数据预处理**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# 读取数据
need_date_time_columns=1 #是否需要时间作为特征
columns_to_drop=[] #需要删除的列
df = pd.read_csv('data//train.csv', parse_dates=['DateTime'])
# 转换所有应为数值的列为 float（防止字符串类型报错）
numeric_cols = [
    'Global_active_power', 'Global_reactive_power', 'Voltage',
    'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3',
    'RR', 'NBJRR1', 'NBJRR5', 'NBJRR10', 'NBJBROU'
]
# 强制转换为 float，如果有无法解析的值，设置为 NaN
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')
df.dropna(subset=numeric_cols, inplace=True)

df=df.drop(columns=columns_to_drop)
# 添加日期列
df['Date'] = df['DateTime'].dt.date  # 只保留年月日部分

# 计算 sub_metering_remainder（每分钟）
df['sub_metering_remainder'] = (df['Global_active_power'] * 1000 / 60) - (
    df['Sub_metering_1'] + df['Sub_metering_2'] + df['Sub_metering_3'])

# 定义日级聚合函数
daily_agg = {
    'Global_active_power': 'sum' ,
    'Global_reactive_power': 'sum',
    'Sub_metering_1': 'sum',  # 已是 Wh，每分钟累计可以直接 sum
    'Sub_metering_2': 'sum',
    'Sub_metering_3': 'sum',
    'sub_metering_remainder': 'sum',

    'Voltage': 'mean',  # 电压波动，均值即可
    'Global_intensity': 'mean',  # 电流均值也合理

    'RR': 'first',  # 天气指标，一天一个值即可
    'NBJRR1': 'first',
    'NBJRR5': 'first',
    'NBJRR10': 'first',
    'NBJBROU': 'first'
}
for col in columns_to_drop:
    daily_agg.pop(col, None)

# 按日期聚合
df_daily = df.groupby('Date').agg(daily_agg).reset_index()
df_daily['Date'] = pd.to_datetime(df_daily['Date'])
if need_date_time_columns:
    # 可以选择将日期列转回 datetime 类型
    df_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
    df_daily['day_of_month'] = df_daily['Date'].dt.day
    df_daily['month'] = df_daily['Date'].dt.month
    df_daily['quarter'] = df_daily['Date'].dt.quarter
# 查看结果
print("预处理后日级数据：")
print(df_daily.info())
print(df_daily.head())
feature_cols = [col for col in df_daily.columns if col != 'Date']
scaler = MinMaxScaler()
df_daily_scaled = df_daily.copy()
df_daily_scaled[feature_cols] = scaler.fit_transform(df_daily[feature_cols])
print(df_daily_scaled.head())
# Out:
# 预处理后日级数据：
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    746 non-null    datetime64[ns]
#  1   Global_active_power     746 non-null    float64
#  2   Global_reactive_power   746 non-null    float64
#  3   Sub_metering_1          746 non-null    float64
#  4   Sub_metering_2          746 non-null    float64
#  5   Sub_metering_3          746 non-null    float64
#  6   sub_metering_remainder  746 non-null    float64
#  7   Voltage                 746 non-null    float64
#  8   Global_intensity        746 non-null    float64
#  9   RR                      746 non-null    float64
#  10  NBJRR1                  746 non-null    float64
#  11  NBJRR5                  746 non-null    float64
#  12  NBJRR10                 746 non-null    float64
#  13  NBJBROU                 746 non-null    float64
#  14  day_of_week             746 non-null    int32
#  15  day_of_month            746 non-null    int32
#  16  month                   746 non-null    int32
#  17  quarter                 746 non-null    int32
# dtypes: datetime64[ns](1), float64(13), int32(4)
# memory usage: 93.4 KB
# None
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             3.053475               0.088187             0.0
# 1 2006-12-17             2.354486               0.156949          2033.0
# 2 2006-12-18             1.530435               0.112356          1063.0
# 3 2006-12-19             1.157079               0.104821           839.0
# 4 2006-12-20             1.545658               0.111804             0.0
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder     Voltage  \
# 0           546.0          4926.0            14680.933333  236.243763
# 1          4187.0         13341.0            36946.666667  240.087028
# 2          2621.0         14018.0            19028.433333  241.231694
# 3          7602.0          6197.0            13131.900000  241.999313
# 4          2648.0         14063.0            20384.800000  242.308062
#
#    Global_intensity     RR  NBJRR1  NBJRR5  NBJRR10  NBJBROU  day_of_week  \
# 0         13.082828  63.75   9.333   5.667    2.167    0.167            5
# 1          9.999028  63.75   9.333   5.667    2.167    0.167            6
# 2          6.421667  63.75   9.333   5.667    2.167    0.167            0
# 3          4.926389  63.75   9.333   5.667    2.167    0.167            1
# 4          6.467361  63.75   9.333   5.667    2.167    0.167            2
#
#    day_of_month  month  quarter
# 0            16     12        4
# 1            17     12        4
# 2            18     12        4
# 3            19     12        4
# 4            20     12        4
#         Date  Global_active_power  Global_reactive_power  Sub_metering_1  \
# 0 2006-12-16             0.916786               0.141546        0.000000
# 1 2006-12-17             0.694252               0.461964        0.196501
# 2 2006-12-18             0.431901               0.254168        0.102745
# 3 2006-12-19             0.313037               0.219057        0.081094
# 4 2006-12-20             0.436748               0.251599        0.000000
#
#    Sub_metering_2  Sub_metering_3  sub_metering_remainder   Voltage  \
# 0        0.045090        0.252499                0.233317  0.371797
# 1        0.345776        0.683838                0.596096  0.648958
# 2        0.216451        0.718540                0.304152  0.731507
# 3        0.627798        0.317648                0.208079  0.786865
# 4        0.218680        0.720847                0.326251  0.809131
#
#    Global_intensity        RR    NBJRR1    NBJRR5  NBJRR10  NBJBROU  \
# 0          0.928499  0.395727  0.480759  0.767727   0.4925   0.4175
# 1          0.695226  0.395727  0.480759  0.767727   0.4925   0.4175
# 2          0.424618  0.395727  0.480759  0.767727   0.4925   0.4175
# 3          0.311508  0.395727  0.480759  0.767727   0.4925   0.4175
# 4          0.428075  0.395727  0.480759  0.767727   0.4925   0.4175
#
#    day_of_week  day_of_month  month  quarter
# 0     0.833333      0.500000    1.0      1.0
# 1     1.000000      0.533333    1.0      1.0
# 2     0.000000      0.566667    1.0      1.0
# 3     0.166667      0.600000    1.0      1.0
# 4     0.333333      0.633333    1.0      1.0

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# target_col = 'Global_active_power'
# # 计算皮尔逊相关系数矩阵
# corr_matrix = df_daily[feature_cols + [target_col]].corr()
#
# # 可视化热力图
# plt.figure(figsize=(12, 10))
# sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
# plt.title("Pearson Correlation Matrix")
# plt.tight_layout()
# plt.show()

# %%
# from sklearn.feature_selection import mutual_info_regression
#
# X = df_daily[feature_cols]
# y = df_daily[target_col]
#
# mi_scores = mutual_info_regression(X, y, random_state=0)
# mi_series = pd.Series(mi_scores, index=feature_cols).sort_values(ascending=False)
#
# # 可视化
# plt.figure(figsize=(10, 5))
# mi_series.plot(kind='bar', color='darkorange')
# plt.title(f'Mutual Information with Target: {target_col}')
# plt.ylabel('MI Score')
# plt.grid(True)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# 构造监督学习数据集+Transformer模型设计+训练函数

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
def create_supervised_data(df, input_window=90, output_window=90, target_col='Global_active_power'):
    """
    构造用于多变量时间序列预测的监督学习样本
    参数：
        df: 已按天聚合的 DataFrame，包含时间序列特征
        input_window: 输入时间步长（例如 90）
        output_window: 预测步长（例如 90 或 365）
        target_col: 预测目标列
    返回：
        X: shape = [样本数, input_window, 特征数]
        y: shape = [样本数, output_window]
    """
    data = df.copy()
    feature_cols = [col for col in data.columns if col != 'Date']

    X_list = []
    y_list = []

    for i in range(len(data) - input_window - output_window + 1):
        x_window = data[feature_cols].iloc[i : i + input_window].values
        y_window = data[target_col].iloc[i + input_window : i + input_window + output_window].values

        if not (np.isnan(x_window).any() or np.isnan(y_window).any()):
            X_list.append(x_window)
            y_list.append(y_window)

    X = np.array(X_list)
    y = np.array(y_list)
    return X, y

class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, d_model):
        super().__init__()
        pos = np.arange(sequence_length)[:, np.newaxis]
        i = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model))
        angle_rads = pos * angle_rates

        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    # 多头注意力层

    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Dropout(dropout)(x)
    x = Add()([x, inputs])  # 残差连接
    x = LayerNormalization(epsilon=1e-6)(x)

    # 前馈网络
    x_ff = Dense(ff_dim, activation="relu")(x)
    x_ff = Dropout(dropout)(x_ff)
    x_ff = Dense(inputs.shape[-1])(x_ff)
    x = Add()([x_ff, x])
    x = LayerNormalization(epsilon=1e-6)(x)

    return x

def build_transformer_model(input_timesteps, num_features, output_timesteps,
                            head_size=64, num_heads=4, ff_dim=128, num_transformer_blocks=2, dropout=0.1):
    inputs = Input(shape=(input_timesteps, num_features))
    x = PositionalEncoding(input_timesteps, num_features)(inputs)
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # 可以取最后一个时间步，或者全局平均（更稳定）
    x = tf.keras.layers.GlobalAveragePooling1D()(x)
    x = Dropout(0.1)(x)
    outputs = Dense(output_timesteps)(x)

    model = Model(inputs, outputs)
    model.compile(optimizer="adam", loss="mse", metrics=["mae"])
    return model

def train_transformer_model(X_train, y_train, X_val, y_val,
                     input_timesteps, num_features, output_timesteps,
                     epochs=50, batch_size=64, n_runs=5):
    from tensorflow.keras import backend as K

    mse_list = []
    mae_list = []
    best_model = None
    best_mse = float('inf')

    for run in range(n_runs):
        print(f"\n===== Run {run+1}/{n_runs} =====")
        model = build_transformer_model(input_timesteps, num_features, output_timesteps)

        early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

        model.fit(
            X_train, y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val, y_val),  # 显式验证集
            callbacks=[early_stopping],
            verbose=2
        )

        # 验证集评估（用于模型选择）
        loss, mae = model.evaluate(X_val, y_val, verbose=0)
        mse = loss

        print(f"Run {run+1} - MSE: {mse:.6f}, MAE: {mae:.6f}")

        mse_list.append(mse)
        mae_list.append(mae)

        if mse < best_mse:
            best_mse = mse
            best_model = model

        K.clear_session()

    results = {
        'mse_mean': np.mean(mse_list),
        'mse_std': np.std(mse_list),
        'mae_mean': np.mean(mae_list),
        'mae_std': np.std(mae_list),
    }

    print("\n===== Summary =====")
    print(f"MSE mean: {results['mse_mean']:.6f}, std: {results['mse_std']:.6f}")
    print(f"MAE mean: {results['mae_mean']:.6f}, std: {results['mae_std']:.6f}")

    return best_model, results

# %% [markdown]
# 开始训练

# %%
epochs=100
n_runs=10
batch_size=32
input_window = 90
output_window = 90
target_col = 'Global_active_power'

X_full, y_full = create_supervised_data(df_daily_scaled, input_window, output_window, target_col)
print(f"X shape: {X_full.shape}, y shape: {y_full.shape}")
print(f"原始日级数据总天数: {df_daily.shape[0]}")
print(f"用于建模的样本数: {len(X_full)}")

# 划分训练集和验证集
train_ratio = 0.9
split_idx = int(len(X_full) * train_ratio)
X_train, X_val = X_full[:split_idx], X_full[split_idx:]
y_train, y_val = y_full[:split_idx], y_full[split_idx:]

print(f"训练集样本数: {len(X_train)}, 验证集样本数: {len(X_val)}")

num_features = X_train.shape[2]

model, results = train_transformer_model(
    X_train, y_train, X_val, y_val,
    input_window, num_features, output_window,
    epochs=epochs, batch_size=batch_size, n_runs=n_runs
)
model.summary()
# Out:
# X shape: (567, 90, 17), y shape: (567, 90)
# 原始日级数据总天数: 746
# 用于建模的样本数: 567
# 训练集样本数: 510, 验证集样本数: 57
#
# ===== Run 1/10 =====
# Epoch 1/100
# 16/16 - 3s - 183ms/step - loss: 0.1221 - mae: 0.2771 - val_loss: 0.0913 - val_mae: 0.2454
# Epoch 2/100
# 16/16 - 0s - 27ms/step - loss: 0.0617 - mae: 0.2005 - val_loss: 0.0622 - val_mae: 0.2012
# Epoch 3/100
# 16/16 - 0s - 27ms/step - loss: 0.0405 - mae: 0.1574 - val_loss: 0.0391 - val_mae: 0.1522
# Epoch 4/100
# 16/16 - 0s - 27ms/step - loss: 0.0270 - mae: 0.1272 - val_loss: 0.0289 - val_mae: 0.1311
# Epoch 5/100
# 16/16 - 0s - 26ms/step - loss: 0.0210 - mae: 0.1117 - val_loss: 0.0282 - val_mae: 0.1325
# Epoch 6/100
# 16/16 - 0s - 26ms/step - loss: 0.0184 - mae: 0.1053 - val_loss: 0.0331 - val_mae: 0.1477
# Epoch 7/100
# 16/16 - 0s - 26ms/step - loss: 0.0166 - mae: 0.1002 - val_loss: 0.0313 - val_mae: 0.1443
# Epoch 8/100
# 16/16 - 0s - 25ms/step - loss: 0.0159 - mae: 0.0980 - val_loss: 0.0329 - val_mae: 0.1491
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0151 - mae: 0.0958 - val_loss: 0.0336 - val_mae: 0.1521
# Epoch 10/100
# 16/16 - 0s - 25ms/step - loss: 0.0149 - mae: 0.0950 - val_loss: 0.0309 - val_mae: 0.1451
# Epoch 11/100
# 16/16 - 0s - 25ms/step - loss: 0.0142 - mae: 0.0926 - val_loss: 0.0312 - val_mae: 0.1461
# Epoch 12/100
# 16/16 - 0s - 25ms/step - loss: 0.0140 - mae: 0.0922 - val_loss: 0.0304 - val_mae: 0.1446
# Epoch 13/100
# 16/16 - 0s - 26ms/step - loss: 0.0141 - mae: 0.0927 - val_loss: 0.0294 - val_mae: 0.1425
# Epoch 14/100
# 16/16 - 0s - 25ms/step - loss: 0.0137 - mae: 0.0914 - val_loss: 0.0271 - val_mae: 0.1354
# Epoch 15/100
# 16/16 - 0s - 25ms/step - loss: 0.0130 - mae: 0.0891 - val_loss: 0.0307 - val_mae: 0.1470
# Epoch 16/100
# 16/16 - 0s - 25ms/step - loss: 0.0130 - mae: 0.0890 - val_loss: 0.0300 - val_mae: 0.1451
# Epoch 17/100
# 16/16 - 0s - 25ms/step - loss: 0.0132 - mae: 0.0895 - val_loss: 0.0290 - val_mae: 0.1420
# Epoch 18/100
# 16/16 - 0s - 25ms/step - loss: 0.0133 - mae: 0.0900 - val_loss: 0.0284 - val_mae: 0.1403
# Epoch 19/100
# 16/16 - 0s - 25ms/step - loss: 0.0126 - mae: 0.0878 - val_loss: 0.0232 - val_mae: 0.1235
# Epoch 20/100
# 16/16 - 0s - 25ms/step - loss: 0.0122 - mae: 0.0865 - val_loss: 0.0254 - val_mae: 0.1307
# Epoch 21/100
# 16/16 - 0s - 25ms/step - loss: 0.0122 - mae: 0.0860 - val_loss: 0.0235 - val_mae: 0.1246
# Epoch 22/100
# 16/16 - 0s - 25ms/step - loss: 0.0122 - mae: 0.0862 - val_loss: 0.0243 - val_mae: 0.1280
# Epoch 23/100
# 16/16 - 0s - 25ms/step - loss: 0.0117 - mae: 0.0845 - val_loss: 0.0220 - val_mae: 0.1201
# Epoch 24/100
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0841 - val_loss: 0.0222 - val_mae: 0.1211
# Epoch 25/100
# 16/16 - 0s - 25ms/step - loss: 0.0118 - mae: 0.0849 - val_loss: 0.0215 - val_mae: 0.1188
# Epoch 26/100
# 16/16 - 0s - 25ms/step - loss: 0.0117 - mae: 0.0843 - val_loss: 0.0191 - val_mae: 0.1105
# Epoch 27/100
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0840 - val_loss: 0.0222 - val_mae: 0.1221
# Epoch 28/100
# 16/16 - 0s - 25ms/step - loss: 0.0113 - mae: 0.0830 - val_loss: 0.0210 - val_mae: 0.1184
# Epoch 29/100
# 16/16 - 0s - 25ms/step - loss: 0.0110 - mae: 0.0821 - val_loss: 0.0235 - val_mae: 0.1271
# Epoch 30/100
# 16/16 - 0s - 25ms/step - loss: 0.0109 - mae: 0.0815 - val_loss: 0.0231 - val_mae: 0.1260
# Epoch 31/100
# 16/16 - 0s - 25ms/step - loss: 0.0108 - mae: 0.0810 - val_loss: 0.0232 - val_mae: 0.1270
# Epoch 32/100
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0803 - val_loss: 0.0229 - val_mae: 0.1262
# Epoch 33/100
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0802 - val_loss: 0.0233 - val_mae: 0.1278
# Epoch 34/100
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0793 - val_loss: 0.0234 - val_mae: 0.1284
# Epoch 35/100
# 16/16 - 0s - 25ms/step - loss: 0.0102 - mae: 0.0787 - val_loss: 0.0223 - val_mae: 0.1256
# Epoch 36/100
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0792 - val_loss: 0.0255 - val_mae: 0.1347
# Epoch 37/100
# 16/16 - 0s - 25ms/step - loss: 0.0101 - mae: 0.0786 - val_loss: 0.0243 - val_mae: 0.1319
# Epoch 38/100
# 16/16 - 0s - 25ms/step - loss: 0.0100 - mae: 0.0780 - val_loss: 0.0232 - val_mae: 0.1287
# Epoch 39/100
# 16/16 - 0s - 25ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0229 - val_mae: 0.1282
# Epoch 40/100
# 16/16 - 0s - 25ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0256 - val_mae: 0.1361
# Epoch 41/100
# 16/16 - 0s - 25ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0242 - val_mae: 0.1324
# Run 1 - MSE: 0.019108, MAE: 0.110454
#
# ===== Run 2/10 =====
# Epoch 1/100
# 16/16 - 3s - 172ms/step - loss: 0.1213 - mae: 0.2826 - val_loss: 0.0936 - val_mae: 0.2648
# Epoch 2/100
# 16/16 - 0s - 26ms/step - loss: 0.0653 - mae: 0.2085 - val_loss: 0.0640 - val_mae: 0.2087
# Epoch 3/100
# 16/16 - 0s - 25ms/step - loss: 0.0416 - mae: 0.1584 - val_loss: 0.0394 - val_mae: 0.1561
# Epoch 4/100
# 16/16 - 0s - 25ms/step - loss: 0.0271 - mae: 0.1264 - val_loss: 0.0288 - val_mae: 0.1326
# Epoch 5/100
# 16/16 - 0s - 25ms/step - loss: 0.0200 - mae: 0.1094 - val_loss: 0.0245 - val_mae: 0.1229
# Epoch 6/100
# 16/16 - 0s - 25ms/step - loss: 0.0175 - mae: 0.1028 - val_loss: 0.0272 - val_mae: 0.1332
# Epoch 7/100
# 16/16 - 0s - 25ms/step - loss: 0.0156 - mae: 0.0972 - val_loss: 0.0272 - val_mae: 0.1340
# Epoch 8/100
# 16/16 - 0s - 25ms/step - loss: 0.0152 - mae: 0.0960 - val_loss: 0.0260 - val_mae: 0.1307
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0145 - mae: 0.0940 - val_loss: 0.0255 - val_mae: 0.1299
# Epoch 10/100
# 16/16 - 0s - 26ms/step - loss: 0.0143 - mae: 0.0934 - val_loss: 0.0245 - val_mae: 0.1265
# Epoch 11/100
# 16/16 - 0s - 25ms/step - loss: 0.0140 - mae: 0.0924 - val_loss: 0.0262 - val_mae: 0.1323
# Epoch 12/100
# 16/16 - 0s - 25ms/step - loss: 0.0136 - mae: 0.0914 - val_loss: 0.0274 - val_mae: 0.1363
# Epoch 13/100
# 16/16 - 0s - 25ms/step - loss: 0.0133 - mae: 0.0901 - val_loss: 0.0234 - val_mae: 0.1234
# Epoch 14/100
# 16/16 - 0s - 25ms/step - loss: 0.0133 - mae: 0.0903 - val_loss: 0.0230 - val_mae: 0.1219
# Epoch 15/100
# 16/16 - 0s - 25ms/step - loss: 0.0134 - mae: 0.0904 - val_loss: 0.0230 - val_mae: 0.1226
# Epoch 16/100
# 16/16 - 0s - 25ms/step - loss: 0.0128 - mae: 0.0886 - val_loss: 0.0225 - val_mae: 0.1211
# Epoch 17/100
# 16/16 - 0s - 25ms/step - loss: 0.0125 - mae: 0.0877 - val_loss: 0.0220 - val_mae: 0.1189
# Epoch 18/100
# 16/16 - 0s - 26ms/step - loss: 0.0126 - mae: 0.0879 - val_loss: 0.0201 - val_mae: 0.1124
# Epoch 19/100
# 16/16 - 0s - 25ms/step - loss: 0.0124 - mae: 0.0868 - val_loss: 0.0203 - val_mae: 0.1132
# Epoch 20/100
# 16/16 - 0s - 25ms/step - loss: 0.0123 - mae: 0.0870 - val_loss: 0.0212 - val_mae: 0.1170
# Epoch 21/100
# 16/16 - 0s - 25ms/step - loss: 0.0119 - mae: 0.0857 - val_loss: 0.0202 - val_mae: 0.1134
# Epoch 22/100
# 16/16 - 0s - 25ms/step - loss: 0.0119 - mae: 0.0857 - val_loss: 0.0207 - val_mae: 0.1157
# Epoch 23/100
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0844 - val_loss: 0.0210 - val_mae: 0.1169
# Epoch 24/100
# 16/16 - 0s - 25ms/step - loss: 0.0115 - mae: 0.0838 - val_loss: 0.0197 - val_mae: 0.1126
# Epoch 25/100
# 16/16 - 0s - 25ms/step - loss: 0.0114 - mae: 0.0835 - val_loss: 0.0194 - val_mae: 0.1118
# Epoch 26/100
# 16/16 - 0s - 25ms/step - loss: 0.0114 - mae: 0.0834 - val_loss: 0.0218 - val_mae: 0.1207
# Epoch 27/100
# 16/16 - 0s - 26ms/step - loss: 0.0113 - mae: 0.0830 - val_loss: 0.0200 - val_mae: 0.1144
# Epoch 28/100
# 16/16 - 0s - 25ms/step - loss: 0.0111 - mae: 0.0824 - val_loss: 0.0195 - val_mae: 0.1134
# Epoch 29/100
# 16/16 - 0s - 25ms/step - loss: 0.0110 - mae: 0.0819 - val_loss: 0.0223 - val_mae: 0.1238
# Epoch 30/100
# 16/16 - 0s - 25ms/step - loss: 0.0107 - mae: 0.0809 - val_loss: 0.0201 - val_mae: 0.1165
# Epoch 31/100
# 16/16 - 0s - 25ms/step - loss: 0.0107 - mae: 0.0810 - val_loss: 0.0188 - val_mae: 0.1123
# Epoch 32/100
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0803 - val_loss: 0.0221 - val_mae: 0.1244
# Epoch 33/100
# 16/16 - 0s - 25ms/step - loss: 0.0107 - mae: 0.0807 - val_loss: 0.0201 - val_mae: 0.1181
# Epoch 34/100
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0794 - val_loss: 0.0215 - val_mae: 0.1235
# Epoch 35/100
# 16/16 - 0s - 25ms/step - loss: 0.0102 - mae: 0.0791 - val_loss: 0.0205 - val_mae: 0.1203
# Epoch 36/100
# 16/16 - 0s - 25ms/step - loss: 0.0102 - mae: 0.0793 - val_loss: 0.0209 - val_mae: 0.1221
# Epoch 37/100
# 16/16 - 0s - 25ms/step - loss: 0.0101 - mae: 0.0786 - val_loss: 0.0219 - val_mae: 0.1260
# Epoch 38/100
# 16/16 - 0s - 25ms/step - loss: 0.0099 - mae: 0.0781 - val_loss: 0.0223 - val_mae: 0.1269
# Epoch 39/100
# 16/16 - 0s - 25ms/step - loss: 0.0098 - mae: 0.0776 - val_loss: 0.0218 - val_mae: 0.1258
# Epoch 40/100
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0232 - val_mae: 0.1299
# Epoch 41/100
# 16/16 - 0s - 26ms/step - loss: 0.0101 - mae: 0.0787 - val_loss: 0.0207 - val_mae: 0.1224
# Epoch 42/100
# 16/16 - 0s - 25ms/step - loss: 0.0096 - mae: 0.0769 - val_loss: 0.0207 - val_mae: 0.1228
# Epoch 43/100
# 16/16 - 0s - 25ms/step - loss: 0.0094 - mae: 0.0761 - val_loss: 0.0218 - val_mae: 0.1263
# Epoch 44/100
# 16/16 - 0s - 25ms/step - loss: 0.0095 - mae: 0.0761 - val_loss: 0.0225 - val_mae: 0.1285
# Epoch 45/100
# 16/16 - 0s - 25ms/step - loss: 0.0095 - mae: 0.0763 - val_loss: 0.0204 - val_mae: 0.1222
# Epoch 46/100
# 16/16 - 0s - 25ms/step - loss: 0.0096 - mae: 0.0764 - val_loss: 0.0232 - val_mae: 0.1308
# Run 2 - MSE: 0.018796, MAE: 0.112252
#
# ===== Run 3/10 =====
# Epoch 1/100
# 16/16 - 3s - 172ms/step - loss: 0.1120 - mae: 0.2674 - val_loss: 0.0863 - val_mae: 0.2378
# Epoch 2/100
# 16/16 - 0s - 25ms/step - loss: 0.0614 - mae: 0.1989 - val_loss: 0.0597 - val_mae: 0.1924
# Epoch 3/100
# 16/16 - 0s - 25ms/step - loss: 0.0423 - mae: 0.1611 - val_loss: 0.0381 - val_mae: 0.1496
# Epoch 4/100
# 16/16 - 0s - 25ms/step - loss: 0.0291 - mae: 0.1319 - val_loss: 0.0266 - val_mae: 0.1219
# Epoch 5/100
# 16/16 - 0s - 25ms/step - loss: 0.0218 - mae: 0.1140 - val_loss: 0.0213 - val_mae: 0.1082
# Epoch 6/100
# 16/16 - 0s - 25ms/step - loss: 0.0182 - mae: 0.1043 - val_loss: 0.0200 - val_mae: 0.1075
# Epoch 7/100
# 16/16 - 0s - 25ms/step - loss: 0.0162 - mae: 0.0988 - val_loss: 0.0202 - val_mae: 0.1101
# Epoch 8/100
# 16/16 - 0s - 25ms/step - loss: 0.0151 - mae: 0.0955 - val_loss: 0.0212 - val_mae: 0.1146
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0145 - mae: 0.0939 - val_loss: 0.0203 - val_mae: 0.1112
# Epoch 10/100
# 16/16 - 0s - 25ms/step - loss: 0.0142 - mae: 0.0931 - val_loss: 0.0181 - val_mae: 0.1017
# Epoch 11/100
# 16/16 - 0s - 25ms/step - loss: 0.0140 - mae: 0.0923 - val_loss: 0.0188 - val_mae: 0.1052
# Epoch 12/100
# 16/16 - 0s - 25ms/step - loss: 0.0135 - mae: 0.0906 - val_loss: 0.0200 - val_mae: 0.1105
# Epoch 13/100
# 16/16 - 0s - 25ms/step - loss: 0.0134 - mae: 0.0904 - val_loss: 0.0208 - val_mae: 0.1134
# Epoch 14/100
# 16/16 - 0s - 25ms/step - loss: 0.0133 - mae: 0.0902 - val_loss: 0.0189 - val_mae: 0.1058
# Epoch 15/100
# 16/16 - 0s - 25ms/step - loss: 0.0126 - mae: 0.0875 - val_loss: 0.0194 - val_mae: 0.1087
# Epoch 16/100
# 16/16 - 0s - 25ms/step - loss: 0.0125 - mae: 0.0874 - val_loss: 0.0197 - val_mae: 0.1105
# Epoch 17/100
# 16/16 - 0s - 25ms/step - loss: 0.0123 - mae: 0.0866 - val_loss: 0.0191 - val_mae: 0.1081
# Epoch 18/100
# 16/16 - 0s - 26ms/step - loss: 0.0122 - mae: 0.0863 - val_loss: 0.0172 - val_mae: 0.0998
# Epoch 19/100
# 16/16 - 0s - 25ms/step - loss: 0.0121 - mae: 0.0860 - val_loss: 0.0190 - val_mae: 0.1074
# Epoch 20/100
# 16/16 - 0s - 26ms/step - loss: 0.0118 - mae: 0.0852 - val_loss: 0.0195 - val_mae: 0.1101
# Epoch 21/100
# 16/16 - 0s - 26ms/step - loss: 0.0117 - mae: 0.0844 - val_loss: 0.0174 - val_mae: 0.1022
# Epoch 22/100
# 16/16 - 0s - 25ms/step - loss: 0.0114 - mae: 0.0835 - val_loss: 0.0182 - val_mae: 0.1057
# Epoch 23/100
# 16/16 - 0s - 25ms/step - loss: 0.0115 - mae: 0.0840 - val_loss: 0.0169 - val_mae: 0.1019
# Epoch 24/100
# 16/16 - 0s - 25ms/step - loss: 0.0113 - mae: 0.0833 - val_loss: 0.0166 - val_mae: 0.1000
# Epoch 25/100
# 16/16 - 0s - 25ms/step - loss: 0.0111 - mae: 0.0823 - val_loss: 0.0172 - val_mae: 0.1031
# Epoch 26/100
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0830 - val_loss: 0.0180 - val_mae: 0.1071
# Epoch 27/100
# 16/16 - 0s - 25ms/step - loss: 0.0111 - mae: 0.0822 - val_loss: 0.0162 - val_mae: 0.0996
# Epoch 28/100
# 16/16 - 0s - 26ms/step - loss: 0.0107 - mae: 0.0811 - val_loss: 0.0177 - val_mae: 0.1067
# Epoch 29/100
# 16/16 - 0s - 25ms/step - loss: 0.0107 - mae: 0.0807 - val_loss: 0.0177 - val_mae: 0.1071
# Epoch 30/100
# 16/16 - 0s - 25ms/step - loss: 0.0107 - mae: 0.0807 - val_loss: 0.0177 - val_mae: 0.1067
# Epoch 31/100
# 16/16 - 0s - 25ms/step - loss: 0.0106 - mae: 0.0805 - val_loss: 0.0168 - val_mae: 0.1034
# Epoch 32/100
# 16/16 - 0s - 26ms/step - loss: 0.0104 - mae: 0.0800 - val_loss: 0.0171 - val_mae: 0.1072
# Epoch 33/100
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0793 - val_loss: 0.0163 - val_mae: 0.1034
# Epoch 34/100
# 16/16 - 0s - 26ms/step - loss: 0.0100 - mae: 0.0784 - val_loss: 0.0186 - val_mae: 0.1134
# Epoch 35/100
# 16/16 - 0s - 25ms/step - loss: 0.0101 - mae: 0.0783 - val_loss: 0.0189 - val_mae: 0.1149
# Epoch 36/100
# 16/16 - 0s - 27ms/step - loss: 0.0099 - mae: 0.0780 - val_loss: 0.0173 - val_mae: 0.1093
# Epoch 37/100
# 16/16 - 0s - 25ms/step - loss: 0.0101 - mae: 0.0784 - val_loss: 0.0173 - val_mae: 0.1093
# Epoch 38/100
# 16/16 - 0s - 25ms/step - loss: 0.0100 - mae: 0.0781 - val_loss: 0.0197 - val_mae: 0.1184
# Epoch 39/100
# 16/16 - 0s - 25ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0203 - val_mae: 0.1205
# Epoch 40/100
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0772 - val_loss: 0.0186 - val_mae: 0.1151
# Epoch 41/100
# 16/16 - 0s - 25ms/step - loss: 0.0098 - mae: 0.0773 - val_loss: 0.0193 - val_mae: 0.1177
# Epoch 42/100
# 16/16 - 0s - 27ms/step - loss: 0.0096 - mae: 0.0769 - val_loss: 0.0196 - val_mae: 0.1188
# Run 3 - MSE: 0.016198, MAE: 0.099614
#
# ===== Run 4/10 =====
# Epoch 1/100
# 16/16 - 3s - 184ms/step - loss: 0.1138 - mae: 0.2726 - val_loss: 0.0953 - val_mae: 0.2697
# Epoch 2/100
# 16/16 - 0s - 26ms/step - loss: 0.0668 - mae: 0.2084 - val_loss: 0.0641 - val_mae: 0.2052
# Epoch 3/100
# 16/16 - 0s - 26ms/step - loss: 0.0458 - mae: 0.1675 - val_loss: 0.0413 - val_mae: 0.1601
# Epoch 4/100
# 16/16 - 0s - 27ms/step - loss: 0.0313 - mae: 0.1357 - val_loss: 0.0285 - val_mae: 0.1312
# Epoch 5/100
# 16/16 - 0s - 26ms/step - loss: 0.0230 - mae: 0.1168 - val_loss: 0.0236 - val_mae: 0.1203
# Epoch 6/100
# 16/16 - 0s - 27ms/step - loss: 0.0189 - mae: 0.1063 - val_loss: 0.0221 - val_mae: 0.1159
# Epoch 7/100
# 16/16 - 0s - 25ms/step - loss: 0.0172 - mae: 0.1016 - val_loss: 0.0222 - val_mae: 0.1170
# Epoch 8/100
# 16/16 - 0s - 26ms/step - loss: 0.0161 - mae: 0.0984 - val_loss: 0.0261 - val_mae: 0.1302
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0150 - mae: 0.0954 - val_loss: 0.0254 - val_mae: 0.1280
# Epoch 10/100
# 16/16 - 0s - 26ms/step - loss: 0.0146 - mae: 0.0946 - val_loss: 0.0301 - val_mae: 0.1437
# Epoch 11/100
# 16/16 - 0s - 25ms/step - loss: 0.0144 - mae: 0.0936 - val_loss: 0.0269 - val_mae: 0.1338
# Epoch 12/100
# 16/16 - 0s - 26ms/step - loss: 0.0141 - mae: 0.0926 - val_loss: 0.0239 - val_mae: 0.1239
# Epoch 13/100
# 16/16 - 0s - 25ms/step - loss: 0.0138 - mae: 0.0919 - val_loss: 0.0290 - val_mae: 0.1413
# Epoch 14/100
# 16/16 - 0s - 26ms/step - loss: 0.0135 - mae: 0.0908 - val_loss: 0.0254 - val_mae: 0.1301
# Epoch 15/100
# 16/16 - 0s - 25ms/step - loss: 0.0134 - mae: 0.0905 - val_loss: 0.0244 - val_mae: 0.1268
# Epoch 16/100
# 16/16 - 0s - 26ms/step - loss: 0.0132 - mae: 0.0897 - val_loss: 0.0226 - val_mae: 0.1198
# Epoch 17/100
# 16/16 - 0s - 25ms/step - loss: 0.0130 - mae: 0.0893 - val_loss: 0.0273 - val_mae: 0.1365
# Epoch 18/100
# 16/16 - 0s - 26ms/step - loss: 0.0127 - mae: 0.0879 - val_loss: 0.0241 - val_mae: 0.1256
# Epoch 19/100
# 16/16 - 0s - 26ms/step - loss: 0.0126 - mae: 0.0877 - val_loss: 0.0222 - val_mae: 0.1183
# Epoch 20/100
# 16/16 - 0s - 26ms/step - loss: 0.0128 - mae: 0.0888 - val_loss: 0.0187 - val_mae: 0.1041
# Epoch 21/100
# 16/16 - 0s - 26ms/step - loss: 0.0124 - mae: 0.0872 - val_loss: 0.0229 - val_mae: 0.1218
# Epoch 22/100
# 16/16 - 0s - 26ms/step - loss: 0.0121 - mae: 0.0859 - val_loss: 0.0242 - val_mae: 0.1267
# Epoch 23/100
# 16/16 - 0s - 25ms/step - loss: 0.0121 - mae: 0.0860 - val_loss: 0.0226 - val_mae: 0.1210
# Epoch 24/100
# 16/16 - 0s - 26ms/step - loss: 0.0119 - mae: 0.0855 - val_loss: 0.0246 - val_mae: 0.1282
# Epoch 25/100
# 16/16 - 0s - 26ms/step - loss: 0.0119 - mae: 0.0850 - val_loss: 0.0221 - val_mae: 0.1195
# Epoch 26/100
# 16/16 - 0s - 26ms/step - loss: 0.0117 - mae: 0.0844 - val_loss: 0.0215 - val_mae: 0.1177
# Epoch 27/100
# 16/16 - 0s - 25ms/step - loss: 0.0116 - mae: 0.0839 - val_loss: 0.0219 - val_mae: 0.1196
# Epoch 28/100
# 16/16 - 0s - 26ms/step - loss: 0.0113 - mae: 0.0833 - val_loss: 0.0227 - val_mae: 0.1229
# Epoch 29/100
# 16/16 - 0s - 25ms/step - loss: 0.0114 - mae: 0.0835 - val_loss: 0.0228 - val_mae: 0.1237
# Epoch 30/100
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0826 - val_loss: 0.0218 - val_mae: 0.1200
# Epoch 31/100
# 16/16 - 0s - 25ms/step - loss: 0.0110 - mae: 0.0822 - val_loss: 0.0208 - val_mae: 0.1163
# Epoch 32/100
# 16/16 - 0s - 26ms/step - loss: 0.0108 - mae: 0.0816 - val_loss: 0.0202 - val_mae: 0.1148
# Epoch 33/100
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0829 - val_loss: 0.0182 - val_mae: 0.1068
# Epoch 34/100
# 16/16 - 0s - 26ms/step - loss: 0.0107 - mae: 0.0810 - val_loss: 0.0190 - val_mae: 0.1105
# Epoch 35/100
# 16/16 - 0s - 26ms/step - loss: 0.0108 - mae: 0.0811 - val_loss: 0.0224 - val_mae: 0.1236
# Epoch 36/100
# 16/16 - 0s - 27ms/step - loss: 0.0105 - mae: 0.0802 - val_loss: 0.0199 - val_mae: 0.1150
# Epoch 37/100
# 16/16 - 0s - 26ms/step - loss: 0.0104 - mae: 0.0796 - val_loss: 0.0188 - val_mae: 0.1109
# Epoch 38/100
# 16/16 - 0s - 27ms/step - loss: 0.0104 - mae: 0.0801 - val_loss: 0.0182 - val_mae: 0.1089
# Epoch 39/100
# 16/16 - 0s - 25ms/step - loss: 0.0104 - mae: 0.0797 - val_loss: 0.0183 - val_mae: 0.1107
# Epoch 40/100
# 16/16 - 0s - 26ms/step - loss: 0.0101 - mae: 0.0785 - val_loss: 0.0204 - val_mae: 0.1176
# Epoch 41/100
# 16/16 - 0s - 26ms/step - loss: 0.0099 - mae: 0.0779 - val_loss: 0.0209 - val_mae: 0.1198
# Epoch 42/100
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0221 - val_mae: 0.1239
# Epoch 43/100
# 16/16 - 0s - 26ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0216 - val_mae: 0.1225
# Epoch 44/100
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0775 - val_loss: 0.0220 - val_mae: 0.1237
# Epoch 45/100
# 16/16 - 0s - 28ms/step - loss: 0.0097 - mae: 0.0772 - val_loss: 0.0203 - val_mae: 0.1188
# Epoch 46/100
# 16/16 - 0s - 29ms/step - loss: 0.0099 - mae: 0.0778 - val_loss: 0.0192 - val_mae: 0.1167
# Epoch 47/100
# 16/16 - 1s - 36ms/step - loss: 0.0097 - mae: 0.0772 - val_loss: 0.0206 - val_mae: 0.1199
# Epoch 48/100
# 16/16 - 0s - 31ms/step - loss: 0.0095 - mae: 0.0762 - val_loss: 0.0199 - val_mae: 0.1183
# Run 4 - MSE: 0.018207, MAE: 0.106775
#
# ===== Run 5/10 =====
# Epoch 1/100
# 16/16 - 4s - 236ms/step - loss: 0.1324 - mae: 0.2867 - val_loss: 0.0916 - val_mae: 0.2507
# Epoch 2/100
# 16/16 - 1s - 32ms/step - loss: 0.0643 - mae: 0.2040 - val_loss: 0.0604 - val_mae: 0.1999
# Epoch 3/100
# 16/16 - 1s - 32ms/step - loss: 0.0440 - mae: 0.1648 - val_loss: 0.0447 - val_mae: 0.1684
# Epoch 4/100
# 16/16 - 1s - 43ms/step - loss: 0.0311 - mae: 0.1363 - val_loss: 0.0316 - val_mae: 0.1379
# Epoch 5/100
# 16/16 - 1s - 32ms/step - loss: 0.0233 - mae: 0.1177 - val_loss: 0.0256 - val_mae: 0.1232
# Epoch 6/100
# 16/16 - 1s - 32ms/step - loss: 0.0194 - mae: 0.1075 - val_loss: 0.0238 - val_mae: 0.1201
# Epoch 7/100
# 16/16 - 1s - 32ms/step - loss: 0.0174 - mae: 0.1018 - val_loss: 0.0249 - val_mae: 0.1254
# Epoch 8/100
# 16/16 - 1s - 32ms/step - loss: 0.0162 - mae: 0.0988 - val_loss: 0.0237 - val_mae: 0.1221
# Epoch 9/100
# 16/16 - 1s - 32ms/step - loss: 0.0153 - mae: 0.0960 - val_loss: 0.0243 - val_mae: 0.1248
# Epoch 10/100
# 16/16 - 1s - 32ms/step - loss: 0.0153 - mae: 0.0961 - val_loss: 0.0238 - val_mae: 0.1236
# Epoch 11/100
# 16/16 - 1s - 32ms/step - loss: 0.0150 - mae: 0.0955 - val_loss: 0.0240 - val_mae: 0.1241
# Epoch 12/100
# 16/16 - 1s - 32ms/step - loss: 0.0147 - mae: 0.0946 - val_loss: 0.0220 - val_mae: 0.1171
# Epoch 13/100
# 16/16 - 1s - 44ms/step - loss: 0.0140 - mae: 0.0926 - val_loss: 0.0230 - val_mae: 0.1207
# Epoch 14/100
# 16/16 - 1s - 32ms/step - loss: 0.0141 - mae: 0.0927 - val_loss: 0.0223 - val_mae: 0.1191
# Epoch 15/100
# 16/16 - 1s - 33ms/step - loss: 0.0136 - mae: 0.0907 - val_loss: 0.0224 - val_mae: 0.1197
# Epoch 16/100
# 16/16 - 1s - 42ms/step - loss: 0.0137 - mae: 0.0910 - val_loss: 0.0226 - val_mae: 0.1204
# Epoch 17/100
# 16/16 - 1s - 33ms/step - loss: 0.0132 - mae: 0.0895 - val_loss: 0.0222 - val_mae: 0.1187
# Epoch 18/100
# 16/16 - 1s - 36ms/step - loss: 0.0130 - mae: 0.0892 - val_loss: 0.0199 - val_mae: 0.1107
# Epoch 19/100
# 16/16 - 1s - 34ms/step - loss: 0.0127 - mae: 0.0880 - val_loss: 0.0200 - val_mae: 0.1111
# Epoch 20/100
# 16/16 - 1s - 33ms/step - loss: 0.0125 - mae: 0.0879 - val_loss: 0.0221 - val_mae: 0.1197
# Epoch 21/100
# 16/16 - 1s - 33ms/step - loss: 0.0125 - mae: 0.0873 - val_loss: 0.0206 - val_mae: 0.1139
# Epoch 22/100
# 16/16 - 1s - 32ms/step - loss: 0.0123 - mae: 0.0868 - val_loss: 0.0207 - val_mae: 0.1150
# Epoch 23/100
# 16/16 - 1s - 32ms/step - loss: 0.0123 - mae: 0.0866 - val_loss: 0.0194 - val_mae: 0.1099
# Epoch 24/100
# 16/16 - 1s - 47ms/step - loss: 0.0120 - mae: 0.0857 - val_loss: 0.0170 - val_mae: 0.1005
# Epoch 25/100
# 16/16 - 1s - 33ms/step - loss: 0.0120 - mae: 0.0856 - val_loss: 0.0192 - val_mae: 0.1102
# Epoch 26/100
# 16/16 - 1s - 32ms/step - loss: 0.0117 - mae: 0.0843 - val_loss: 0.0184 - val_mae: 0.1067
# Epoch 27/100
# 16/16 - 1s - 32ms/step - loss: 0.0117 - mae: 0.0846 - val_loss: 0.0186 - val_mae: 0.1081
# Epoch 28/100
# 16/16 - 1s - 32ms/step - loss: 0.0116 - mae: 0.0844 - val_loss: 0.0191 - val_mae: 0.1105
# Epoch 29/100
# 16/16 - 1s - 32ms/step - loss: 0.0115 - mae: 0.0838 - val_loss: 0.0179 - val_mae: 0.1056
# Epoch 30/100
# 16/16 - 1s - 33ms/step - loss: 0.0115 - mae: 0.0835 - val_loss: 0.0192 - val_mae: 0.1114
# Epoch 31/100
# 16/16 - 1s - 32ms/step - loss: 0.0112 - mae: 0.0830 - val_loss: 0.0189 - val_mae: 0.1109
# Epoch 32/100
# 16/16 - 1s - 32ms/step - loss: 0.0110 - mae: 0.0821 - val_loss: 0.0191 - val_mae: 0.1118
# Epoch 33/100
# 16/16 - 1s - 33ms/step - loss: 0.0110 - mae: 0.0818 - val_loss: 0.0180 - val_mae: 0.1079
# Epoch 34/100
# 16/16 - 1s - 33ms/step - loss: 0.0108 - mae: 0.0811 - val_loss: 0.0192 - val_mae: 0.1136
# Epoch 35/100
# 16/16 - 1s - 32ms/step - loss: 0.0107 - mae: 0.0809 - val_loss: 0.0204 - val_mae: 0.1176
# Epoch 36/100
# 16/16 - 1s - 35ms/step - loss: 0.0103 - mae: 0.0795 - val_loss: 0.0175 - val_mae: 0.1081
# Epoch 37/100
# 16/16 - 1s - 34ms/step - loss: 0.0104 - mae: 0.0797 - val_loss: 0.0189 - val_mae: 0.1137
# Epoch 38/100
# 16/16 - 1s - 32ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0179 - val_mae: 0.1103
# Epoch 39/100
# 16/16 - 1s - 32ms/step - loss: 0.0103 - mae: 0.0792 - val_loss: 0.0178 - val_mae: 0.1105
# Run 5 - MSE: 0.017004, MAE: 0.100451
#
# ===== Run 6/10 =====
# Epoch 1/100
# 16/16 - 4s - 241ms/step - loss: 0.1151 - mae: 0.2671 - val_loss: 0.0847 - val_mae: 0.2396
# Epoch 2/100
# 16/16 - 0s - 26ms/step - loss: 0.0567 - mae: 0.1901 - val_loss: 0.0588 - val_mae: 0.1956
# Epoch 3/100
# 16/16 - 0s - 25ms/step - loss: 0.0385 - mae: 0.1535 - val_loss: 0.0377 - val_mae: 0.1529
# Epoch 4/100
# 16/16 - 0s - 26ms/step - loss: 0.0270 - mae: 0.1274 - val_loss: 0.0282 - val_mae: 0.1311
# Epoch 5/100
# 16/16 - 0s - 25ms/step - loss: 0.0210 - mae: 0.1125 - val_loss: 0.0255 - val_mae: 0.1262
# Epoch 6/100
# 16/16 - 0s - 26ms/step - loss: 0.0187 - mae: 0.1062 - val_loss: 0.0222 - val_mae: 0.1164
# Epoch 7/100
# 16/16 - 0s - 25ms/step - loss: 0.0170 - mae: 0.1009 - val_loss: 0.0227 - val_mae: 0.1192
# Epoch 8/100
# 16/16 - 0s - 25ms/step - loss: 0.0159 - mae: 0.0979 - val_loss: 0.0253 - val_mae: 0.1288
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0151 - mae: 0.0956 - val_loss: 0.0223 - val_mae: 0.1188
# Epoch 10/100
# 16/16 - 0s - 25ms/step - loss: 0.0146 - mae: 0.0941 - val_loss: 0.0239 - val_mae: 0.1250
# Epoch 11/100
# 16/16 - 0s - 25ms/step - loss: 0.0140 - mae: 0.0925 - val_loss: 0.0231 - val_mae: 0.1226
# Epoch 12/100
# 16/16 - 0s - 26ms/step - loss: 0.0137 - mae: 0.0915 - val_loss: 0.0214 - val_mae: 0.1170
# Epoch 13/100
# 16/16 - 0s - 25ms/step - loss: 0.0138 - mae: 0.0918 - val_loss: 0.0216 - val_mae: 0.1176
# Epoch 14/100
# 16/16 - 0s - 26ms/step - loss: 0.0134 - mae: 0.0901 - val_loss: 0.0212 - val_mae: 0.1165
# Epoch 15/100
# 16/16 - 0s - 25ms/step - loss: 0.0135 - mae: 0.0904 - val_loss: 0.0206 - val_mae: 0.1147
# Epoch 16/100
# 16/16 - 0s - 26ms/step - loss: 0.0131 - mae: 0.0895 - val_loss: 0.0195 - val_mae: 0.1105
# Epoch 17/100
# 16/16 - 0s - 25ms/step - loss: 0.0128 - mae: 0.0885 - val_loss: 0.0202 - val_mae: 0.1138
# Epoch 18/100
# 16/16 - 0s - 26ms/step - loss: 0.0126 - mae: 0.0878 - val_loss: 0.0189 - val_mae: 0.1090
# Epoch 19/100
# 16/16 - 0s - 25ms/step - loss: 0.0122 - mae: 0.0864 - val_loss: 0.0177 - val_mae: 0.1045
# Epoch 20/100
# 16/16 - 0s - 25ms/step - loss: 0.0122 - mae: 0.0863 - val_loss: 0.0186 - val_mae: 0.1081
# Epoch 21/100
# 16/16 - 0s - 25ms/step - loss: 0.0120 - mae: 0.0856 - val_loss: 0.0192 - val_mae: 0.1110
# Epoch 22/100
# 16/16 - 0s - 26ms/step - loss: 0.0119 - mae: 0.0852 - val_loss: 0.0182 - val_mae: 0.1074
# Epoch 23/100
# 16/16 - 0s - 25ms/step - loss: 0.0119 - mae: 0.0850 - val_loss: 0.0192 - val_mae: 0.1116
# Epoch 24/100
# 16/16 - 0s - 26ms/step - loss: 0.0119 - mae: 0.0851 - val_loss: 0.0176 - val_mae: 0.1058
# Epoch 25/100
# 16/16 - 0s - 25ms/step - loss: 0.0115 - mae: 0.0838 - val_loss: 0.0183 - val_mae: 0.1087
# Epoch 26/100
# 16/16 - 0s - 25ms/step - loss: 0.0114 - mae: 0.0832 - val_loss: 0.0188 - val_mae: 0.1115
# Epoch 27/100
# 16/16 - 0s - 26ms/step - loss: 0.0111 - mae: 0.0820 - val_loss: 0.0185 - val_mae: 0.1105
# Epoch 28/100
# 16/16 - 0s - 25ms/step - loss: 0.0112 - mae: 0.0826 - val_loss: 0.0193 - val_mae: 0.1134
# Epoch 29/100
# 16/16 - 0s - 25ms/step - loss: 0.0110 - mae: 0.0817 - val_loss: 0.0181 - val_mae: 0.1096
# Epoch 30/100
# 16/16 - 0s - 26ms/step - loss: 0.0110 - mae: 0.0819 - val_loss: 0.0182 - val_mae: 0.1102
# Epoch 31/100
# 16/16 - 0s - 26ms/step - loss: 0.0107 - mae: 0.0810 - val_loss: 0.0197 - val_mae: 0.1164
# Epoch 32/100
# 16/16 - 0s - 26ms/step - loss: 0.0106 - mae: 0.0804 - val_loss: 0.0182 - val_mae: 0.1115
# Epoch 33/100
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0801 - val_loss: 0.0203 - val_mae: 0.1190
# Epoch 34/100
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0800 - val_loss: 0.0197 - val_mae: 0.1174
# Epoch 35/100
# 16/16 - 0s - 25ms/step - loss: 0.0101 - mae: 0.0785 - val_loss: 0.0191 - val_mae: 0.1159
# Epoch 36/100
# 16/16 - 0s - 25ms/step - loss: 0.0102 - mae: 0.0790 - val_loss: 0.0186 - val_mae: 0.1138
# Epoch 37/100
# 16/16 - 0s - 25ms/step - loss: 0.0101 - mae: 0.0786 - val_loss: 0.0188 - val_mae: 0.1151
# Epoch 38/100
# 16/16 - 0s - 26ms/step - loss: 0.0100 - mae: 0.0779 - val_loss: 0.0202 - val_mae: 0.1201
# Epoch 39/100
# 16/16 - 0s - 25ms/step - loss: 0.0098 - mae: 0.0772 - val_loss: 0.0179 - val_mae: 0.1126
# Run 6 - MSE: 0.017619, MAE: 0.105828
#
# ===== Run 7/10 =====
# Epoch 1/100
# 16/16 - 3s - 178ms/step - loss: 0.0886 - mae: 0.2352 - val_loss: 0.0671 - val_mae: 0.2107
# Epoch 2/100
# 16/16 - 0s - 26ms/step - loss: 0.0459 - mae: 0.1683 - val_loss: 0.0409 - val_mae: 0.1590
# Epoch 3/100
# 16/16 - 0s - 25ms/step - loss: 0.0291 - mae: 0.1320 - val_loss: 0.0269 - val_mae: 0.1259
# Epoch 4/100
# 16/16 - 0s - 26ms/step - loss: 0.0222 - mae: 0.1154 - val_loss: 0.0241 - val_mae: 0.1205
# Epoch 5/100
# 16/16 - 0s - 25ms/step - loss: 0.0183 - mae: 0.1051 - val_loss: 0.0248 - val_mae: 0.1243
# Epoch 6/100
# 16/16 - 0s - 26ms/step - loss: 0.0168 - mae: 0.1008 - val_loss: 0.0244 - val_mae: 0.1240
# Epoch 7/100
# 16/16 - 0s - 25ms/step - loss: 0.0160 - mae: 0.0983 - val_loss: 0.0251 - val_mae: 0.1278
# Epoch 8/100
# 16/16 - 0s - 26ms/step - loss: 0.0156 - mae: 0.0967 - val_loss: 0.0278 - val_mae: 0.1367
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0148 - mae: 0.0948 - val_loss: 0.0287 - val_mae: 0.1407
# Epoch 10/100
# 16/16 - 0s - 25ms/step - loss: 0.0143 - mae: 0.0930 - val_loss: 0.0304 - val_mae: 0.1455
# Epoch 11/100
# 16/16 - 0s - 25ms/step - loss: 0.0138 - mae: 0.0914 - val_loss: 0.0265 - val_mae: 0.1341
# Epoch 12/100
# 16/16 - 0s - 25ms/step - loss: 0.0132 - mae: 0.0895 - val_loss: 0.0270 - val_mae: 0.1362
# Epoch 13/100
# 16/16 - 0s - 25ms/step - loss: 0.0132 - mae: 0.0893 - val_loss: 0.0243 - val_mae: 0.1275
# Epoch 14/100
# 16/16 - 0s - 25ms/step - loss: 0.0131 - mae: 0.0892 - val_loss: 0.0263 - val_mae: 0.1349
# Epoch 15/100
# 16/16 - 0s - 25ms/step - loss: 0.0126 - mae: 0.0876 - val_loss: 0.0238 - val_mae: 0.1261
# Epoch 16/100
# 16/16 - 0s - 26ms/step - loss: 0.0127 - mae: 0.0877 - val_loss: 0.0238 - val_mae: 0.1261
# Epoch 17/100
# 16/16 - 0s - 25ms/step - loss: 0.0124 - mae: 0.0869 - val_loss: 0.0227 - val_mae: 0.1230
# Epoch 18/100
# 16/16 - 0s - 26ms/step - loss: 0.0120 - mae: 0.0855 - val_loss: 0.0247 - val_mae: 0.1301
# Epoch 19/100
# 16/16 - 0s - 25ms/step - loss: 0.0119 - mae: 0.0851 - val_loss: 0.0259 - val_mae: 0.1345
# Epoch 20/100
# 16/16 - 0s - 26ms/step - loss: 0.0115 - mae: 0.0838 - val_loss: 0.0225 - val_mae: 0.1234
# Epoch 21/100
# 16/16 - 0s - 25ms/step - loss: 0.0115 - mae: 0.0835 - val_loss: 0.0208 - val_mae: 0.1171
# Epoch 22/100
# 16/16 - 0s - 26ms/step - loss: 0.0114 - mae: 0.0836 - val_loss: 0.0239 - val_mae: 0.1283
# Epoch 23/100
# 16/16 - 0s - 25ms/step - loss: 0.0111 - mae: 0.0823 - val_loss: 0.0250 - val_mae: 0.1324
# Epoch 24/100
# 16/16 - 0s - 26ms/step - loss: 0.0112 - mae: 0.0824 - val_loss: 0.0222 - val_mae: 0.1231
# Epoch 25/100
# 16/16 - 0s - 25ms/step - loss: 0.0109 - mae: 0.0816 - val_loss: 0.0227 - val_mae: 0.1251
# Epoch 26/100
# 16/16 - 0s - 26ms/step - loss: 0.0110 - mae: 0.0822 - val_loss: 0.0198 - val_mae: 0.1146
# Epoch 27/100
# 16/16 - 0s - 25ms/step - loss: 0.0107 - mae: 0.0808 - val_loss: 0.0227 - val_mae: 0.1253
# Epoch 28/100
# 16/16 - 0s - 25ms/step - loss: 0.0105 - mae: 0.0805 - val_loss: 0.0206 - val_mae: 0.1188
# Epoch 29/100
# 16/16 - 0s - 25ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0206 - val_mae: 0.1183
# Epoch 30/100
# 16/16 - 0s - 26ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0227 - val_mae: 0.1258
# Epoch 31/100
# 16/16 - 0s - 25ms/step - loss: 0.0103 - mae: 0.0792 - val_loss: 0.0221 - val_mae: 0.1244
# Epoch 32/100
# 16/16 - 0s - 26ms/step - loss: 0.0101 - mae: 0.0784 - val_loss: 0.0235 - val_mae: 0.1285
# Epoch 33/100
# 16/16 - 0s - 25ms/step - loss: 0.0102 - mae: 0.0787 - val_loss: 0.0237 - val_mae: 0.1294
# Epoch 34/100
# 16/16 - 0s - 25ms/step - loss: 0.0100 - mae: 0.0783 - val_loss: 0.0253 - val_mae: 0.1339
# Epoch 35/100
# 16/16 - 0s - 25ms/step - loss: 0.0099 - mae: 0.0780 - val_loss: 0.0225 - val_mae: 0.1257
# Epoch 36/100
# 16/16 - 0s - 26ms/step - loss: 0.0098 - mae: 0.0773 - val_loss: 0.0223 - val_mae: 0.1249
# Epoch 37/100
# 16/16 - 0s - 25ms/step - loss: 0.0095 - mae: 0.0764 - val_loss: 0.0227 - val_mae: 0.1266
# Epoch 38/100
# 16/16 - 0s - 25ms/step - loss: 0.0096 - mae: 0.0767 - val_loss: 0.0241 - val_mae: 0.1309
# Epoch 39/100
# 16/16 - 0s - 25ms/step - loss: 0.0094 - mae: 0.0761 - val_loss: 0.0243 - val_mae: 0.1308
# Epoch 40/100
# 16/16 - 0s - 26ms/step - loss: 0.0097 - mae: 0.0769 - val_loss: 0.0249 - val_mae: 0.1332
# Epoch 41/100
# 16/16 - 0s - 25ms/step - loss: 0.0096 - mae: 0.0766 - val_loss: 0.0214 - val_mae: 0.1231
# Run 7 - MSE: 0.019792, MAE: 0.114585
#
# ===== Run 8/10 =====
# Epoch 1/100
# 16/16 - 3s - 178ms/step - loss: 0.1180 - mae: 0.2794 - val_loss: 0.1026 - val_mae: 0.2769
# Epoch 2/100
# 16/16 - 0s - 26ms/step - loss: 0.0662 - mae: 0.2090 - val_loss: 0.0637 - val_mae: 0.2054
# Epoch 3/100
# 16/16 - 0s - 25ms/step - loss: 0.0447 - mae: 0.1650 - val_loss: 0.0442 - val_mae: 0.1683
# Epoch 4/100
# 16/16 - 0s - 26ms/step - loss: 0.0302 - mae: 0.1339 - val_loss: 0.0305 - val_mae: 0.1375
# Epoch 5/100
# 16/16 - 0s - 25ms/step - loss: 0.0221 - mae: 0.1148 - val_loss: 0.0275 - val_mae: 0.1332
# Epoch 6/100
# 16/16 - 0s - 26ms/step - loss: 0.0179 - mae: 0.1037 - val_loss: 0.0226 - val_mae: 0.1182
# Epoch 7/100
# 16/16 - 0s - 25ms/step - loss: 0.0163 - mae: 0.0990 - val_loss: 0.0250 - val_mae: 0.1271
# Epoch 8/100
# 16/16 - 0s - 26ms/step - loss: 0.0152 - mae: 0.0959 - val_loss: 0.0246 - val_mae: 0.1259
# Epoch 9/100
# 16/16 - 0s - 25ms/step - loss: 0.0150 - mae: 0.0953 - val_loss: 0.0221 - val_mae: 0.1171
# Epoch 10/100
# 16/16 - 0s - 26ms/step - loss: 0.0142 - mae: 0.0929 - val_loss: 0.0209 - val_mae: 0.1127
# Epoch 11/100
# 16/16 - 0s - 26ms/step - loss: 0.0139 - mae: 0.0921 - val_loss: 0.0214 - val_mae: 0.1149
# Epoch 12/100
# 16/16 - 0s - 26ms/step - loss: 0.0132 - mae: 0.0899 - val_loss: 0.0209 - val_mae: 0.1134
# Epoch 13/100
# 16/16 - 0s - 26ms/step - loss: 0.0132 - mae: 0.0897 - val_loss: 0.0207 - val_mae: 0.1124
# Epoch 14/100
# 16/16 - 0s - 26ms/step - loss: 0.0128 - mae: 0.0884 - val_loss: 0.0218 - val_mae: 0.1172
# Epoch 15/100
# 16/16 - 0s - 26ms/step - loss: 0.0128 - mae: 0.0884 - val_loss: 0.0202 - val_mae: 0.1115
# Epoch 16/100
# 16/16 - 0s - 26ms/step - loss: 0.0127 - mae: 0.0881 - val_loss: 0.0196 - val_mae: 0.1095
# Epoch 17/100
# 16/16 - 0s - 26ms/step - loss: 0.0125 - mae: 0.0874 - val_loss: 0.0192 - val_mae: 0.1078
# Epoch 18/100
# 16/16 - 0s - 27ms/step - loss: 0.0123 - mae: 0.0867 - val_loss: 0.0196 - val_mae: 0.1096
# Epoch 19/100
# 16/16 - 0s - 26ms/step - loss: 0.0121 - mae: 0.0862 - val_loss: 0.0213 - val_mae: 0.1167
# Epoch 20/100
# 16/16 - 0s - 26ms/step - loss: 0.0122 - mae: 0.0865 - val_loss: 0.0197 - val_mae: 0.1112
# Epoch 21/100
# 16/16 - 0s - 28ms/step - loss: 0.0119 - mae: 0.0852 - val_loss: 0.0191 - val_mae: 0.1091
# Epoch 22/100
# 16/16 - 0s - 28ms/step - loss: 0.0118 - mae: 0.0851 - val_loss: 0.0183 - val_mae: 0.1064
# Epoch 23/100
# 16/16 - 0s - 26ms/step - loss: 0.0115 - mae: 0.0839 - val_loss: 0.0202 - val_mae: 0.1141
# Epoch 24/100
# 16/16 - 0s - 28ms/step - loss: 0.0113 - mae: 0.0830 - val_loss: 0.0192 - val_mae: 0.1109
# Epoch 25/100
# 16/16 - 0s - 26ms/step - loss: 0.0113 - mae: 0.0829 - val_loss: 0.0204 - val_mae: 0.1157
# Epoch 26/100
# 16/16 - 0s - 27ms/step - loss: 0.0113 - mae: 0.0833 - val_loss: 0.0179 - val_mae: 0.1066
# Epoch 27/100
# 16/16 - 0s - 27ms/step - loss: 0.0110 - mae: 0.0817 - val_loss: 0.0189 - val_mae: 0.1109
# Epoch 28/100
# 16/16 - 0s - 26ms/step - loss: 0.0109 - mae: 0.0818 - val_loss: 0.0184 - val_mae: 0.1099
# Epoch 29/100
# 16/16 - 0s - 26ms/step - loss: 0.0109 - mae: 0.0814 - val_loss: 0.0191 - val_mae: 0.1134
# Epoch 30/100
# 16/16 - 0s - 27ms/step - loss: 0.0106 - mae: 0.0805 - val_loss: 0.0192 - val_mae: 0.1141
# Epoch 31/100
# 16/16 - 0s - 26ms/step - loss: 0.0105 - mae: 0.0796 - val_loss: 0.0194 - val_mae: 0.1149
# Epoch 32/100
# 16/16 - 0s - 27ms/step - loss: 0.0105 - mae: 0.0800 - val_loss: 0.0196 - val_mae: 0.1162
# Epoch 33/100
# 16/16 - 0s - 26ms/step - loss: 0.0103 - mae: 0.0793 - val_loss: 0.0190 - val_mae: 0.1144
# Epoch 34/100
# 16/16 - 0s - 26ms/step - loss: 0.0103 - mae: 0.0790 - val_loss: 0.0226 - val_mae: 0.1265
# Epoch 35/100
# 16/16 - 0s - 27ms/step - loss: 0.0101 - mae: 0.0784 - val_loss: 0.0194 - val_mae: 0.1163
# Epoch 36/100
# 16/16 - 0s - 26ms/step - loss: 0.0101 - mae: 0.0788 - val_loss: 0.0205 - val_mae: 0.1206
# Epoch 37/100
# 16/16 - 0s - 27ms/step - loss: 0.0102 - mae: 0.0786 - val_loss: 0.0231 - val_mae: 0.1279
# Epoch 38/100
# 16/16 - 0s - 27ms/step - loss: 0.0100 - mae: 0.0781 - val_loss: 0.0203 - val_mae: 0.1199
# Epoch 39/100
# 16/16 - 0s - 26ms/step - loss: 0.0099 - mae: 0.0776 - val_loss: 0.0211 - val_mae: 0.1228
# Epoch 40/100
# 16/16 - 0s - 26ms/step - loss: 0.0097 - mae: 0.0771 - val_loss: 0.0208 - val_mae: 0.1228
# Epoch 41/100
# 16/16 - 0s - 26ms/step - loss: 0.0097 - mae: 0.0768 - val_loss: 0.0218 - val_mae: 0.1250
# Run 8 - MSE: 0.017853, MAE: 0.106630
#
# ===== Run 9/10 =====
# Epoch 1/100
# 16/16 - 3s - 175ms/step - loss: 0.1138 - mae: 0.2752 - val_loss: 0.0981 - val_mae: 0.2588
# Epoch 2/100
# 16/16 - 0s - 27ms/step - loss: 0.0677 - mae: 0.2119 - val_loss: 0.0715 - val_mae: 0.2162
# Epoch 3/100
# 16/16 - 0s - 26ms/step - loss: 0.0490 - mae: 0.1740 - val_loss: 0.0501 - val_mae: 0.1741
# Epoch 4/100
# 16/16 - 0s - 26ms/step - loss: 0.0343 - mae: 0.1423 - val_loss: 0.0358 - val_mae: 0.1454
# Epoch 5/100
# 16/16 - 0s - 26ms/step - loss: 0.0244 - mae: 0.1197 - val_loss: 0.0280 - val_mae: 0.1290
# Epoch 6/100
# 16/16 - 0s - 26ms/step - loss: 0.0198 - mae: 0.1085 - val_loss: 0.0250 - val_mae: 0.1222
# Epoch 7/100
# 16/16 - 0s - 26ms/step - loss: 0.0170 - mae: 0.1014 - val_loss: 0.0234 - val_mae: 0.1188
# Epoch 8/100
# 16/16 - 0s - 26ms/step - loss: 0.0161 - mae: 0.0990 - val_loss: 0.0288 - val_mae: 0.1387
# Epoch 9/100
# 16/16 - 0s - 26ms/step - loss: 0.0147 - mae: 0.0945 - val_loss: 0.0266 - val_mae: 0.1320
# Epoch 10/100
# 16/16 - 0s - 26ms/step - loss: 0.0144 - mae: 0.0934 - val_loss: 0.0255 - val_mae: 0.1281
# Epoch 11/100
# 16/16 - 0s - 27ms/step - loss: 0.0140 - mae: 0.0924 - val_loss: 0.0253 - val_mae: 0.1283
# Epoch 12/100
# 16/16 - 0s - 26ms/step - loss: 0.0137 - mae: 0.0913 - val_loss: 0.0260 - val_mae: 0.1306
# Epoch 13/100
# 16/16 - 0s - 26ms/step - loss: 0.0137 - mae: 0.0913 - val_loss: 0.0258 - val_mae: 0.1305
# Epoch 14/100
# 16/16 - 0s - 26ms/step - loss: 0.0134 - mae: 0.0908 - val_loss: 0.0237 - val_mae: 0.1226
# Epoch 15/100
# 16/16 - 0s - 26ms/step - loss: 0.0131 - mae: 0.0897 - val_loss: 0.0238 - val_mae: 0.1230
# Epoch 16/100
# 16/16 - 0s - 26ms/step - loss: 0.0130 - mae: 0.0891 - val_loss: 0.0212 - val_mae: 0.1134
# Epoch 17/100
# 16/16 - 0s - 27ms/step - loss: 0.0128 - mae: 0.0885 - val_loss: 0.0234 - val_mae: 0.1219
# Epoch 18/100
# 16/16 - 0s - 26ms/step - loss: 0.0128 - mae: 0.0883 - val_loss: 0.0254 - val_mae: 0.1294
# Epoch 19/100
# 16/16 - 0s - 26ms/step - loss: 0.0125 - mae: 0.0873 - val_loss: 0.0251 - val_mae: 0.1285
# Epoch 20/100
# 16/16 - 0s - 28ms/step - loss: 0.0126 - mae: 0.0876 - val_loss: 0.0226 - val_mae: 0.1190
# Epoch 21/100
# 16/16 - 0s - 26ms/step - loss: 0.0124 - mae: 0.0871 - val_loss: 0.0223 - val_mae: 0.1183
# Epoch 22/100
# 16/16 - 0s - 27ms/step - loss: 0.0119 - mae: 0.0852 - val_loss: 0.0241 - val_mae: 0.1251
# Epoch 23/100
# 16/16 - 0s - 29ms/step - loss: 0.0118 - mae: 0.0851 - val_loss: 0.0233 - val_mae: 0.1224
# Epoch 24/100
# 16/16 - 0s - 27ms/step - loss: 0.0118 - mae: 0.0851 - val_loss: 0.0253 - val_mae: 0.1293
# Epoch 25/100
# 16/16 - 0s - 27ms/step - loss: 0.0118 - mae: 0.0851 - val_loss: 0.0230 - val_mae: 0.1210
# Epoch 26/100
# 16/16 - 0s - 26ms/step - loss: 0.0116 - mae: 0.0842 - val_loss: 0.0226 - val_mae: 0.1198
# Epoch 27/100
# 16/16 - 0s - 26ms/step - loss: 0.0115 - mae: 0.0839 - val_loss: 0.0217 - val_mae: 0.1170
# Epoch 28/100
# 16/16 - 0s - 26ms/step - loss: 0.0115 - mae: 0.0839 - val_loss: 0.0202 - val_mae: 0.1111
# Epoch 29/100
# 16/16 - 0s - 26ms/step - loss: 0.0113 - mae: 0.0831 - val_loss: 0.0196 - val_mae: 0.1091
# Epoch 30/100
# 16/16 - 0s - 27ms/step - loss: 0.0112 - mae: 0.0831 - val_loss: 0.0221 - val_mae: 0.1188
# Epoch 31/100
# 16/16 - 1s - 35ms/step - loss: 0.0111 - mae: 0.0823 - val_loss: 0.0205 - val_mae: 0.1132
# Epoch 32/100
# 16/16 - 1s - 39ms/step - loss: 0.0110 - mae: 0.0822 - val_loss: 0.0181 - val_mae: 0.1044
# Epoch 33/100
# 16/16 - 1s - 32ms/step - loss: 0.0107 - mae: 0.0811 - val_loss: 0.0214 - val_mae: 0.1166
# Epoch 34/100
# 16/16 - 1s - 32ms/step - loss: 0.0108 - mae: 0.0814 - val_loss: 0.0209 - val_mae: 0.1151
# Epoch 35/100
# 16/16 - 1s - 32ms/step - loss: 0.0106 - mae: 0.0807 - val_loss: 0.0218 - val_mae: 0.1191
# Epoch 36/100
# 16/16 - 1s - 33ms/step - loss: 0.0106 - mae: 0.0804 - val_loss: 0.0196 - val_mae: 0.1120
# Epoch 37/100
# 16/16 - 1s - 35ms/step - loss: 0.0104 - mae: 0.0799 - val_loss: 0.0204 - val_mae: 0.1151
# Epoch 38/100
# 16/16 - 1s - 32ms/step - loss: 0.0102 - mae: 0.0792 - val_loss: 0.0201 - val_mae: 0.1144
# Epoch 39/100
# 16/16 - 1s - 33ms/step - loss: 0.0103 - mae: 0.0795 - val_loss: 0.0194 - val_mae: 0.1126
# Epoch 40/100
# 16/16 - 1s - 33ms/step - loss: 0.0102 - mae: 0.0792 - val_loss: 0.0172 - val_mae: 0.1048
# Epoch 41/100
# 16/16 - 1s - 33ms/step - loss: 0.0101 - mae: 0.0789 - val_loss: 0.0185 - val_mae: 0.1099
# Epoch 42/100
# 16/16 - 1s - 33ms/step - loss: 0.0100 - mae: 0.0784 - val_loss: 0.0188 - val_mae: 0.1118
# Epoch 43/100
# 16/16 - 1s - 32ms/step - loss: 0.0097 - mae: 0.0773 - val_loss: 0.0215 - val_mae: 0.1218
# Epoch 44/100
# 16/16 - 1s - 32ms/step - loss: 0.0097 - mae: 0.0773 - val_loss: 0.0211 - val_mae: 0.1203
# Epoch 45/100
# 16/16 - 1s - 32ms/step - loss: 0.0096 - mae: 0.0766 - val_loss: 0.0199 - val_mae: 0.1177
# Epoch 46/100
# 16/16 - 1s - 33ms/step - loss: 0.0095 - mae: 0.0766 - val_loss: 0.0206 - val_mae: 0.1199
# Epoch 47/100
# 16/16 - 1s - 42ms/step - loss: 0.0096 - mae: 0.0769 - val_loss: 0.0187 - val_mae: 0.1124
# Epoch 48/100
# 16/16 - 1s - 32ms/step - loss: 0.0096 - mae: 0.0769 - val_loss: 0.0187 - val_mae: 0.1126
# Epoch 49/100
# 16/16 - 1s - 33ms/step - loss: 0.0094 - mae: 0.0762 - val_loss: 0.0186 - val_mae: 0.1133
# Epoch 50/100
# 16/16 - 1s - 33ms/step - loss: 0.0093 - mae: 0.0755 - val_loss: 0.0213 - val_mae: 0.1223
# Epoch 51/100
# 16/16 - 1s - 34ms/step - loss: 0.0094 - mae: 0.0759 - val_loss: 0.0217 - val_mae: 0.1244
# Epoch 52/100
# 16/16 - 1s - 34ms/step - loss: 0.0094 - mae: 0.0763 - val_loss: 0.0203 - val_mae: 0.1200
# Epoch 53/100
# 16/16 - 1s - 32ms/step - loss: 0.0094 - mae: 0.0762 - val_loss: 0.0182 - val_mae: 0.1119
# Epoch 54/100
# 16/16 - 1s - 44ms/step - loss: 0.0093 - mae: 0.0760 - val_loss: 0.0188 - val_mae: 0.1143
# Epoch 55/100
# 16/16 - 1s - 33ms/step - loss: 0.0091 - mae: 0.0748 - val_loss: 0.0209 - val_mae: 0.1219
# Run 9 - MSE: 0.017231, MAE: 0.104825
#
# ===== Run 10/10 =====
# Epoch 1/100
# 16/16 - 7s - 456ms/step - loss: 0.1174 - mae: 0.2715 - val_loss: 0.0886 - val_mae: 0.2543
# Epoch 2/100
# 16/16 - 1s - 32ms/step - loss: 0.0634 - mae: 0.2028 - val_loss: 0.0544 - val_mae: 0.1885
# Epoch 3/100
# 16/16 - 1s - 32ms/step - loss: 0.0435 - mae: 0.1628 - val_loss: 0.0384 - val_mae: 0.1558
# Epoch 4/100
# 16/16 - 1s - 32ms/step - loss: 0.0300 - mae: 0.1339 - val_loss: 0.0274 - val_mae: 0.1292
# Epoch 5/100
# 16/16 - 1s - 33ms/step - loss: 0.0230 - mae: 0.1176 - val_loss: 0.0235 - val_mae: 0.1201
# Epoch 6/100
# 16/16 - 1s - 33ms/step - loss: 0.0192 - mae: 0.1073 - val_loss: 0.0216 - val_mae: 0.1147
# Epoch 7/100
# 16/16 - 1s - 42ms/step - loss: 0.0171 - mae: 0.1016 - val_loss: 0.0288 - val_mae: 0.1387
# Epoch 8/100
# 16/16 - 1s - 32ms/step - loss: 0.0162 - mae: 0.0988 - val_loss: 0.0241 - val_mae: 0.1244
# Epoch 9/100
# 16/16 - 1s - 32ms/step - loss: 0.0150 - mae: 0.0956 - val_loss: 0.0277 - val_mae: 0.1366
# Epoch 10/100
# 16/16 - 1s - 32ms/step - loss: 0.0147 - mae: 0.0947 - val_loss: 0.0282 - val_mae: 0.1387
# Epoch 11/100
# 16/16 - 1s - 32ms/step - loss: 0.0147 - mae: 0.0945 - val_loss: 0.0264 - val_mae: 0.1331
# Epoch 12/100
# 16/16 - 1s - 32ms/step - loss: 0.0139 - mae: 0.0921 - val_loss: 0.0267 - val_mae: 0.1341
# Epoch 13/100
# 16/16 - 1s - 33ms/step - loss: 0.0133 - mae: 0.0905 - val_loss: 0.0264 - val_mae: 0.1334
# Epoch 14/100
# 16/16 - 1s - 44ms/step - loss: 0.0133 - mae: 0.0903 - val_loss: 0.0231 - val_mae: 0.1221
# Epoch 15/100
# 16/16 - 1s - 33ms/step - loss: 0.0132 - mae: 0.0899 - val_loss: 0.0219 - val_mae: 0.1184
# Epoch 16/100
# 16/16 - 1s - 32ms/step - loss: 0.0131 - mae: 0.0892 - val_loss: 0.0287 - val_mae: 0.1411
# Epoch 17/100
# 16/16 - 1s - 33ms/step - loss: 0.0128 - mae: 0.0885 - val_loss: 0.0249 - val_mae: 0.1293
# Epoch 18/100
# 16/16 - 1s - 33ms/step - loss: 0.0124 - mae: 0.0870 - val_loss: 0.0239 - val_mae: 0.1260
# Epoch 19/100
# 16/16 - 1s - 32ms/step - loss: 0.0124 - mae: 0.0871 - val_loss: 0.0218 - val_mae: 0.1187
# Epoch 20/100
# 16/16 - 1s - 34ms/step - loss: 0.0122 - mae: 0.0864 - val_loss: 0.0217 - val_mae: 0.1184
# Epoch 21/100
# 16/16 - 1s - 32ms/step - loss: 0.0120 - mae: 0.0857 - val_loss: 0.0221 - val_mae: 0.1207
# Run 10 - MSE: 0.021629, MAE: 0.114749
#
# ===== Summary =====
# MSE mean: 0.018344, std: 0.001487
# MAE mean: 0.107616, std: 0.005070
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 90, 17)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encoding │ (None, 90, 17)    │          0 │ input_layer[0][0] │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 17)    │     18,193 │ positional_encod… │
# │ (MultiHeadAttentio… │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 90, 17)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 90, 17)    │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 90, 17)    │         34 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 90, 128)   │      2,304 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 90, 128)   │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 90, 17)    │      2,193 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 90, 17)    │          0 │ dense_1[0][0],    │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 17)    │         34 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 90, 17)    │     18,193 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 90, 17)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 90, 17)    │          0 │ dropout_4[0][0],  │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 17)    │         34 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 90, 128)   │      2,304 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 90, 128)   │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 90, 17)    │      2,193 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 90, 17)    │          0 │ dense_3[0][0],    │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 90, 17)    │         34 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 17)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 17)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 90)        │      1,620 │ dropout_6[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 141,410 (552.39 KB)
#  Trainable params: 47,136 (184.12 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 94,274 (368.26 KB)

# %% [markdown]
# 测试集+作图

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
df_test = pd.read_csv('data/test.csv', header=None)

# Step 2：赋完整列名（按顺序）
df_test.columns = ["DateTime"]+numeric_cols


# 数值列转换（如有非数字或缺失，转为NaN）
df_test[numeric_cols] = df_test[numeric_cols].apply(pd.to_numeric, errors='coerce')
# 显式删除不需要字段
df_test = df_test.drop(columns=columns_to_drop)
df_test['DateTime'] = pd.to_datetime(df['DateTime'], errors='coerce')
df_test['Date'] = df_test['DateTime'].dt.date

# 计算 sub_metering_remainder
df_test['sub_metering_remainder'] = (df_test['Global_active_power'] * 1000 / 60) - (
    df_test['Sub_metering_1'] + df_test['Sub_metering_2'] + df_test['Sub_metering_3'])

# 按天聚合
df_test_daily = df_test.groupby('Date').agg(daily_agg).reset_index()
if need_date_time_columns:
    df_test_daily['Date'] = pd.to_datetime(df_test_daily['Date'])
    df_test_daily['day_of_week'] = df_daily['Date'].dt.dayofweek  # 0=Monday
    df_test_daily['day_of_month'] = df_daily['Date'].dt.day
    df_test_daily['month'] = df_daily['Date'].dt.month
    df_test_daily['quarter'] = df_daily['Date'].dt.quarter
# ========== 关键修改点：丢弃含NaN的天 ==========
df_test_daily_clean = df_test_daily.dropna()
print(f"清洗后测试集天数: {len(df_test_daily_clean)}")

# 归一化（只对干净数据做）
df_test_daily_scaled = df_test_daily_clean.copy()
df_test_daily_scaled[feature_cols] = scaler.transform(df_test_daily_scaled[feature_cols])


def inverse_transform_target(scaler, feature_cols, data_1d, target_col='Global_active_power'):
    """
    把一维的目标列数据逆归一化。
    scaler: 训练时fit的Scaler
    feature_cols: 归一化时所有特征的列名列表
    data_1d: 目标列的一维归一化数据（如full_pred或full_true）
    返回：逆归一化后目标列一维数据
    """
    n = len(data_1d)
    temp = np.zeros((n, len(feature_cols)))
    # 找到目标列索引
    target_idx = feature_cols.index(target_col)
    temp[:, target_idx] = data_1d
    # 逆归一化
    inv_data = scaler.inverse_transform(temp)
    return inv_data[:, target_idx]


X_test_final, y_test_final = create_supervised_data(
    df_test_daily_scaled,
    input_window=input_window,
    output_window=output_window,
    target_col=target_col  # 一般是 'Global_active_power'
)
y_pred_final = model.predict(X_test_final)
# print("测试集天数(原始日数据):", len(df_test_daily_scaled))
# print("测试集每日特征缺失情况:\n", df_test_daily_scaled.isna().sum())
# print("预测窗口数(样本数):", len(y_pred_final))
# print("预测窗口中有缺失值样本丢弃数:", (len(df_test_daily_scaled) - input_window - output_window + 1) - len(y_pred_final))


# 初始化容器
total_days = input_window + (len(y_pred_final) - 1) + output_window
pred_sum = np.zeros(total_days)
true_sum = np.zeros(total_days)
# pred_count = np.zeros(total_days)
# true_count = np.zeros(total_days)
#
# # 多窗口预测融合
# for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
#     start_idx = input_window + i
#     end_idx = start_idx + output_window
#
#     pred_sum[start_idx:end_idx] += pred
#     pred_count[start_idx:end_idx] += 1
#
#     true_sum[start_idx:end_idx] += true
#     true_count[start_idx:end_idx] += 1
#
# # 平均融合
# pred_avg = np.zeros_like(pred_sum)
# true_avg = np.zeros_like(true_sum)
#
# pred_avg[pred_count > 0] = pred_sum[pred_count > 0] / pred_count[pred_count > 0]
# true_avg[true_count > 0] = true_sum[true_count > 0] / true_count[true_count > 0]

# 替代平均融合：取最后一次预测
for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
    start_idx = input_window + i
    end_idx = start_idx + output_window

    pred_sum[start_idx:end_idx] = pred  # 直接覆盖
    true_sum[start_idx:end_idx] = true
for i, (pred, true) in enumerate(zip(y_pred_final, y_test_final)):
    start_idx = input_window + i
    end_idx = start_idx + output_window

    for j in range(output_window):
        idx = start_idx + j
        if pred_count[idx] == 0:
            pred_sum[idx] = pred[j]
            true_sum[idx] = true[j]
            pred_count[idx] = 1
            true_count[idx] = 1
# 取预测部分
full_pred = pred_sum[input_window:]
full_true = true_sum[input_window:]

# 反归一化
full_pred_inv = inverse_transform_target(scaler, feature_cols, full_pred, target_col)
full_true_inv = inverse_transform_target(scaler, feature_cols, full_true, target_col)

# 时间轴
days = np.arange(len(full_pred))

plt.figure(figsize=(14, 5))
plt.plot(days, full_true_inv, label='Ground Truth', color='blue', linewidth=2)
plt.plot(days, full_pred_inv, label='Merged Prediction', color='orange', linewidth=2)
plt.xlabel('Day from Prediction Start')
plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
plt.title('Merged 90-day Predictions vs Ground Truth (Actual Values)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
true_values_to_show = full_true_inv
pred_values_to_show = full_pred_inv

# 打印前30天（或根据需要改）
print("Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error")
print("-" * 50)
for i in range(min(30, len(true_values_to_show))):
    true_val = true_values_to_show[i]
    pred_val = pred_values_to_show[i]
    error = abs(true_val - pred_val)
    print(f"{i:3d} | {true_val:17.4f} | {pred_val:19.4f} | {error:14.4f}")



# MSE
mse = mean_squared_error(true_values_to_show, pred_values_to_show)

# RMSE
rmse = mse ** 0.5

# MAE
mae = mean_absolute_error(true_values_to_show, pred_values_to_show)
errors = pred_values_to_show- true_values_to_show
std_dev = np.std(errors)

print(f"测试集评估指标:")
print(f"MSE : {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE : {mae:.6f}")
print(f"预测误差标准差: {std_dev:.6f}")
# Out:
# C:\Users\16693\AppData\Local\Temp\ipykernel_26884\1132660238.py:3: DtypeWarning: Columns (1,2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test = pd.read_csv('data/test.csv', header=None)
# 清洗后测试集天数: 684
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Day | Ground Truth (kW) | Merged Prediction (kW) | Absolute Error
# --------------------------------------------------
#   0 |            1.3645 |              1.3797 |         0.0152
#   1 |            1.0307 |              1.3400 |         0.3092
#   2 |            1.1437 |              1.3140 |         0.1703
#   3 |            0.9423 |              1.3274 |         0.3851
#   4 |            1.5466 |              1.3734 |         0.1732
#   5 |            0.9371 |              1.3813 |         0.4442
#   6 |            1.0013 |              1.3646 |         0.3633
#   7 |            1.0317 |              1.3582 |         0.3265
#   8 |            1.0568 |              1.3484 |         0.2916
#   9 |            1.2965 |              1.3568 |         0.0603
#  10 |            1.2550 |              1.3763 |         0.1213
#  11 |            1.8782 |              1.4098 |         0.4684
#  12 |            1.3555 |              1.4074 |         0.0519
#  13 |            1.0928 |              1.3705 |         0.2777
#  14 |            1.0722 |              1.3453 |         0.2731
#  15 |            0.8385 |              1.3295 |         0.4911
#  16 |            1.3665 |              1.3174 |         0.0491
#  17 |            1.1529 |              1.3183 |         0.1654
#  18 |            1.0313 |              1.3349 |         0.3037
#  19 |            0.8968 |              1.3460 |         0.4492
#  20 |            1.3002 |              1.3483 |         0.0482
#  21 |            1.0349 |              1.3393 |         0.3044
#  22 |            1.0774 |              1.3287 |         0.2513
#  23 |            0.7670 |              1.3037 |         0.5367
#  24 |            0.8149 |              1.3052 |         0.4903
#  25 |            1.4407 |              1.3394 |         0.1013
#  26 |            1.2046 |              1.3275 |         0.1228
#  27 |            0.9737 |              1.2920 |         0.3182
#  28 |            1.1415 |              1.2754 |         0.1339
#  29 |            1.1776 |              1.2658 |         0.0882
# 测试集评估指标:
# MSE : 0.100731
# RMSE: 0.317382
# MAE : 0.251704
# 预测误差标准差: 0.316167

# %%
# days2 = np.arange(90)
# plt.figure(figsize=(14, 5))
# plt.plot(days2, y_test_final[1], label='Ground Truth', color='blue', linewidth=2)
# plt.plot(days2, y_pred_final[1], label='Merged Prediction', color='orange', linestyle='--', linewidth=2)
# plt.xlabel('Day from Prediction Start')
# plt.ylabel('Global Active Power (kW)')  # 单位改成实际单位
# plt.title('90-day Predictions vs Ground Truth')
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
